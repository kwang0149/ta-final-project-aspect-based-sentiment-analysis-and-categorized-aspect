# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.21 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Requirement already satisfied: six>=1.5 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Count occurrences of each category
category_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:  # Check if 'category' exists and is not null
            main_category = label['category'].split('#')[0]
            if main_category not in category_counts:
                category_counts[main_category] = 0
            category_counts[main_category] += 1

# Handle null values
null_categories = 0
for entry in data:
    if not entry.get('labels'):
        null_categories += 1

if null_categories > 0:
    category_counts['NULL'] = null_categories

# Plotting
import matplotlib.pyplot as plt

categories = list(category_counts.keys())
counts = list(category_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(categories, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Category')
plt.title('Aspect Categories Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'HOTEL' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'HOTEL':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Hotel Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the '
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'SERVICE':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Service Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'ROOM' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'ROOM':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Room Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'HOTEL' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FACILITY':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Facility Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'LOCATION':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of LOCATION Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'FOOD' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FOOD':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Food Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('output_formatted_03_06_2024_less_category.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'LOCATION':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('LOCATION Category Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('output_formatted.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'HOTEL':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('HOTEL Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('output_formatted.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FOOD':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('FOOD Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('output_formatted.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FACILITY':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('FACILITY Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('output_formatted.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'SERVICE':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('SERVICE Category Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()
