# %%
import os
import warnings
import findfile
import pandas as pd
import torch
import transformers
from pyabsa import ABSAInstruction

# %%
print(transformers.__version__)
# Out:
# 4.28.0

# %%
torch.cuda.is_available()
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 4060 Ti'

# %%
pip install datasets
# Out:
# Requirement already satisfied: datasets in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (2.18.0)
# Requirement already satisfied: filelock in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (3.13.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (15.0.2)
# Requirement already satisfied: pyarrow-hotfix in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.2.0,>=2023.1.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from fsspec[http]<=2024.2.0,>=2023.1.0->datasets) (2024.2.0)
# Requirement already satisfied: aiohttp in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (0.22.2)
# Requirement already satisfied: packaging in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from requests>=2.19.0->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\hongk\documents\github\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\hongk\Documents\GitHub\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedWriter name=3>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# c:\Users\hongk\Documents\GitHub\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=4>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# c:\Users\hongk\Documents\GitHub\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages\IPython\utils\_process_win32.py:124: ResourceWarning: unclosed file <_io.BufferedReader name=5>
#   return process_handler(cmd, _system_body)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
from pyabsa import ABSAInstruction as absa_instruction
# Out:
# [2024-06-25 10:46:29] (2.4.1.post1) PyABSA(2.4.1.post1): If your code crashes on Colab, please use the GPU runtime. Then run "pip install pyabsa[dev] -U" and restart the kernel.
# Or if it does not work, you can use v1.x versions, e.g., pip install pyabsa<2.0 -U
#
#
#
#
# WARNING: When you fails to load a checkpoint, e.g., Unexpected key(s),
# Try to downgrade transformers<=4.29.0.
# C:\Users\hongk\AppData\Local\Programs\Python\Python39\lib\multiprocessing\pool.py:265: ResourceWarning: unclosed running multiprocessing pool <multiprocessing.pool.Pool state=RUN pool_size=1>
#   _warn(f"unclosed running multiprocessing pool {self!r}",
# ResourceWarning: Enable tracemalloc to get the object allocation traceback

# %%
warnings.filterwarnings("ignore")

# %%
task_name = "multitask"
experiment_name = "quadruple-ms"
# model_checkpoint = "google/flan-t5-base"
model_checkpoint = "kevinscaria/ate_tk-instruct-base-def-pos-neg-neut-combined"

# %%
print("Experiment Name: ", experiment_name)
model_out_path = "checkpoints"
model_out_path = os.path.join(
    model_out_path, task_name, f"{model_checkpoint.replace('/', '')}-{experiment_name}"
)
print("Model output path: ", model_out_path)
# Out:
# Experiment Name:  quadruple-ms
# Model output path:  checkpoints\multitask\kevinscariaate_tk-instruct-base-def-pos-neg-neut-combined-quadruple-ms

# %%
id_train_file_path = "./ABSADatasets/datasets/acos_datasets/2000.Hotel-ina"
id_test_file_path = "./ABSADatasets/datasets/acos_datasets/2000.Hotel-ina"

# %%
import json

# %%
id_tr_df = absa_instruction.data_utils.read_json(id_train_file_path,"train")
# Out:
# ./ABSADatasets/datasets/acos_datasets/2000.Hotel-ina\train.jsonl

# %%
id_tr_df
# Out:
# [{'text': 'Beautiful , comfortable and friendly hotel near the beach . Great value for the money . Good situation , next to a big mall and the beach . Rooms really comfortable , clean and no noisy . Wifi excellent .',
#   'labels': [{'aspect': 'money',
#     'opinion': 'Great value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'hotel',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'hotel',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'Beautiful',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'Rooms',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'ROOM#EXPERIENCE'},
#    {'aspect': 'Rooms',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'Rooms',
#     'opinion': 'no noisy',
#     'polarity': 'POS',
#     'category': 'ROOM#AMBIENCE'},
#    {'aspect': 'Wifi',
#     'opinion': 'excellent',
#     'polarity': 'POS',
#     'category': 'FACILITY#WIFI'},
#    {'aspect': 'beach',
#     'opinion': 'next to',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'mall',
#     'opinion': 'next to',
#     'polarity': 'POS',
#     'category': 'LOCATION#ENTERTAINMENT'}]},
#  {'text': 'Room veeeeery big , comfortable big bed , hot shower , lush garden , pool and breakfast for 130k IDR in high season : what U want more ? Ok , no towel or sheet but . .',
#   'labels': [{'aspect': 'bed',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'shower',
#     'opinion': 'hot',
#     'polarity': 'NEU',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'garden',
#     'opinion': 'lush',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'Room',
#     'opinion': 'big',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'no towel',
#     'opinion': 'Ok',
#     'polarity': 'NEU',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'pool',
#     'opinion': '130k IDR in high season',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'breakfast',
#     'opinion': '130k IDR in high season',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'}]},
#  {'text': "room without power plug point , hair dryer , water boiler , safe box and even tissue . They don ' t have any queen size bed as well . people were friend but all yr request then will not care . its very small and the wifi is totally suck here .",
#   'labels': [{'aspect': 'queen size bed',
#     'opinion': "don ' t have",
#     'polarity': 'NEG',
#     'category': 'ROOM#BED'},
#    {'aspect': 'people',
#     'opinion': 'friend',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'people',
#     'opinion': 'not care',
#     'polarity': 'NEG',
#     'category': 'SERVICE#EXPERIENCE'},
#    {'aspect': 'wifi',
#     'opinion': 'suck',
#     'polarity': 'NEG',
#     'category': 'FACILITY#WIFI'},
#    {'aspect': 'room',
#     'opinion': 'power plug point',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'hair dryer',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'room',
#     'opinion': 'water boiler',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'room',
#     'opinion': 'safe box',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'tissue',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'}]},
#  {'text': 'The accomodation was great given the price 30 $ per night i got from booking . com . the hotel was clean and two swiming pools to cool off the bali heat . The location - seminyak is great , great for a chilled out people . Very close Peti ( something ) and seminyak beach a taxi will offset you less than 3 $ .',
#   'labels': [{'aspect': 'Peti',
#     'opinion': 'close',
#     'polarity': 'NEU',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'swiming pool',
#     'opinion': 'cool off',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'hotel',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'location',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'chilled out people',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'taxi',
#     'opinion': 'less than 3 $',
#     'polarity': 'POS',
#     'category': 'FACILITY#PRICE'},
#    {'aspect': 'seminyak beach',
#     'opinion': 'close',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'}]},
#  {'text': 'For the price this hotel excellent . Rooms are large and comfortable . Pool area was a bit rundown but functional . Location suited me but a lot of building work going on in streets nearby . Overall this hotel exceeded my expectations for the money I paid .',
#   'labels': [{'aspect': 'price',
#     'opinion': 'excellent',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Rooms',
#     'opinion': 'large',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'ROOM#EXPERIENCE'},
#    {'aspect': 'Pool area',
#     'opinion': 'rundown',
#     'polarity': 'NEG',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'Pool area',
#     'opinion': 'functional',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'Location',
#     'opinion': 'suited',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'building work',
#     'opinion': 'going on',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'exceeded my expectations',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'}]},
#  {'text': 'We stayed at the Maharani with another five friends and had the best time . Staff great friendly and entertaining . Rooms light , airy and clean . They accommodated us by putting all our rooms together side by side . Great location on poppies lane 1 and beach across the road , short walk to markets and shopping . Would recommend a stay here as when we return will be staying again .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'Great',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'light',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'airy',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'Staff',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Staff',
#     'opinion': 'entertaining',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'markets and shopping',
#     'opinion': 'short walk',
#     'polarity': 'NEU',
#     'category': 'LOCATION#NEARBY_AMENITIES'}]},
#  {'text': 'This is good hotel for you stay for a while in Singaraja if you find good and cheap hotel . The view is good near of the beach and it has 1 swimming pool . The bedroom is clean and service is good . But the parking is not large enough .',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'swimming pool',
#     'opinion': '1',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'hotel',
#     'opinion': 'cheap',
#     'polarity': 'NEU',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'view',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'LOCATION#VIEW'},
#    {'aspect': 'beach',
#     'opinion': 'near',
#     'polarity': 'NEU',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'bedroom',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'service',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'parking',
#     'opinion': 'not large',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'}]},
#  {'text': "Great friendly staff awesome manager and security ! Very small pool - a glass door and window separates u from mac Donald ' s ! But u can order mc Donald ' s while sitting in the pool ! Awsome cocktails ! Breaky is not amazing but simple ! I have stayed at the Ramayana hotel kuta and I prefer that !",
#   'labels': [{'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'security',
#     'opinion': 'awesome',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'manager',
#     'opinion': 'awesome',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'pool',
#     'opinion': 'small',
#     'polarity': 'NEG',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'cocktails',
#     'opinion': 'Awsome',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Breaky',
#     'opinion': 'not amazing',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Breaky',
#     'opinion': 'simple',
#     'polarity': 'NEU',
#     'category': 'FOOD#TASTE'}]},
#  {'text': "We paid $ 40 for the deluxe room . There wasn ' t anything wrong with the room really but the photos the website shows were probably taken 15 years ago . The room is old and so is the bathroom . The king bed was just two singles pushed together . There was hot water and the place was clean though , breakfast was included and was tasty .",
#   'labels': [{'aspect': 'breakfast',
#     'opinion': 'tasty',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'place',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'photos',
#     'opinion': 'taken 15 years ago',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'anything wrong',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'bathroom',
#     'opinion': 'old',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'room',
#     'opinion': 'old',
#     'polarity': 'NEG',
#     'category': 'ROOM#GENERAL'}]},
#  {'text': 'Pro : nice staff , good breakfast , pool quiet , room was nice but had few small issues ( below ) , location was the absolute best . Cons : shower drains were clogged and shower temperature either boiling or freezing . Overall I enjoyed my stay . Would definitely recommend .',
#   'labels': [{'aspect': 'staff',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'breakfast',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'pool',
#     'opinion': 'quiet',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'room',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'issues',
#     'polarity': 'NEG',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'location',
#     'opinion': 'best',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'shower drains',
#     'opinion': 'clogged',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'shower temperature',
#     'opinion': 'boiling',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'shower temperature',
#     'opinion': 'freezing',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'stay',
#     'opinion': 'enjoyed',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'}]},
#  {'text': 'no one helped us with out luggages . we stayed here 2nights . it was really one midnight and we have to call the reception but the reply was terrible to understand that they just checked in . we never had a good sleep during our stay . it was a clean with a fast wifi and a good breakfast service though . .',
#   'labels': [{'aspect': 'reply',
#     'opinion': 'terrible',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'good sleep',
#     'opinion': 'never',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'breakfast',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'wifi',
#     'opinion': 'fast',
#     'polarity': 'POS',
#     'category': 'FACILITY#WIFI'},
#    {'aspect': 'it',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'}]},
#  {'text': 'A small hotel with a decent bed and adequate facilities . Breakfast was mediocre and the menu was the same everyday . Some changes in variety would be an improvement . Staff was friendly . There is a church nearby the hotel about 5 mins walk and a small shopping mall opposite the church . The beach is rather far and a 10 min walk . Overall an average place to stay .',
#   'labels': [{'aspect': 'Breakfast',
#     'opinion': 'mediocre',
#     'polarity': 'NEU',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'menu',
#     'opinion': 'same',
#     'polarity': 'NEU',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'bed',
#     'opinion': 'decent',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'facilities',
#     'opinion': 'adequate',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'place',
#     'opinion': 'average',
#     'polarity': 'NEU',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'Staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'we book one room with extra bed . the room was spacious and comfortable . the hotel have a pool not too big but nice . the breakfast excellent . they have rent car also rent motorcycle . near to legian street , kuta beach also another place . will recommend this place to everyone who need the hotel budget with nice facilities .',
#   'labels': [{'aspect': 'room',
#     'opinion': 'spacious',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'room',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'ROOM#EXPERIENCE'},
#    {'aspect': 'pool',
#     'opinion': 'not too big',
#     'polarity': 'NEG',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'pool',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'breakfast',
#     'opinion': 'excellent',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'}]},
#  {'text': 'No Daily Compliment water , No small refrigerator , no buffet drink and fruit for breakfast . But still clean and quite . Need to change the bed , but still oke . Overall you get what you pay .',
#   'labels': [{'aspect': 'Daily Compliment water',
#     'opinion': 'No',
#     'polarity': 'NEG',
#     'category': 'SERVICE#AMENITIES'},
#    {'aspect': 'buffet drink',
#     'opinion': 'no',
#     'polarity': 'NEG',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'fruit',
#     'opinion': 'no',
#     'polarity': 'NEG',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'bed',
#     'opinion': 'oke',
#     'polarity': 'NEU',
#     'category': 'ROOM#BED'}]},
#  {'text': 'stay for 3 nights in standard room . 2 min walk to lippo mall and 10 min walk to discovery mall . 10 min walk to kuta beach . very strategy location . lodge a report on hot condition of aircon and immediate action taken . breakfast nt much variety but tasty .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'strategy',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'aircon',
#     'opinion': 'hot',
#     'polarity': 'NEG',
#     'category': 'ROOM#AIRCON'},
#    {'aspect': 'action',
#     'opinion': 'immediate',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'breakfast',
#     'opinion': 'nt much variety',
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'breakfast',
#     'opinion': 'tasty',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'}]},
#  {'text': 'Good concept with unique design We got compliment " welcome popcorn " at restaurant . . Oxtail soup is the best menu & very recommended . . Room clean , all staff are friendly and helpful . . they have morning dance . . Love it Will definetly back . . Thank you fame hotel .',
#   'labels': [{'aspect': 'concept',
#     'opinion': 'Good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'design',
#     'opinion': 'unique',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'Oxtail soup',
#     'opinion': 'best',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Oxtail soup',
#     'opinion': 'recommended',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Room',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'Plus : Hotel staff are very nice , professional and very helpful . Minus : The hotel does not fulfill 5 star requirements . Quite expensive but poor maintenance of hotel amenities and facility . The hotel including breakfasts is opted for Chinese tour bus groups . Hope for the best , prepare for the worst . Cannot recommend this hotel .',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'Cannot recommend',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'staff',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'staff',
#     'opinion': 'professional',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'hotel',
#     'opinion': 'does not fulfill 5 star requirements',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'hotel',
#     'opinion': 'poor maintenance',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'Nice and quiet hotel . Not far from discovery or lipo mall . Close to the main kuta strip , close to the airport but without the noise from the planes . Staff are exceptionally helpful , friendly and welcoming . Room service excellent and room clean and tidy . Air - conditioning nice and cold and very big beds . Very good value !',
#   'labels': [{'aspect': 'value',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'room',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'room',
#     'opinion': 'tidy',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'Room service',
#     'opinion': 'excellent',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'Staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Staff',
#     'opinion': 'welcoming',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'hotel',
#     'opinion': 'quiet',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'Nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'A great boutique hotel that has amazing staff and service . Very relaxing here , you arrive and instantly decompress , its as if the entire resort is a spa ! The pool downstairs looks almost too beautiful to swim in , very fountain like .',
#   'labels': [{'aspect': 'boutique hotel',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'staff',
#     'opinion': 'amazing',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'service',
#     'opinion': 'amazing',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'here',
#     'opinion': 'relaxing',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'pool',
#     'opinion': 'beautiful',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'}]},
#  {'text': 'We stay here because we have plan to do trekking at Mount Batur . nice hotel located in a mountain cliff shelf that has beautiful scenery . We stayed at this hotel for 2 days with my husband . we would recommend this hotel to travelers who will come to Bali .',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'hotel',
#     'opinion': 'beautiful scenery',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'}]},
#  {'text': 'The pool is ok , gym oke . The property looks better in pictures . The rooms are ok but needs maintenance . Not much options in breakfast . poor service etiquette and communication skills by the staff , overall not good .',
#   'labels': [{'aspect': 'pool',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'gym',
#     'opinion': 'oke',
#     'polarity': 'NEU',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'property',
#     'opinion': 'better in pictures',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'rooms',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'rooms',
#     'opinion': 'needs maintenance',
#     'polarity': 'NEG',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'breakfast',
#     'opinion': 'Not much options',
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'service etiquette',
#     'opinion': 'poor',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'Last night I stayed on this hotel , their receptionis quite good , only 3minutes for check - in registration . But this hotel are full with mosquito , I must ask for mosquito repellent to their front desk . Guests must bring own toothbrush and tooth paste , because they not provide these item .',
#   'labels': [{'aspect': 'receptionis',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'hotel',
#     'opinion': 'full with mosquito',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'toothbrush',
#     'opinion': 'not provide',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'tooth paste',
#     'opinion': 'not provide',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'}]},
#  {'text': 'This hotel is in a great location and such good value for money as it is a budget hotel but it is really nice inside and the rooms were great , good aircon , comfy beds , no issues at all .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'money',
#     'opinion': 'good value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'budget hotel',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'rooms',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'aircon',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'ROOM#AIRCON'},
#    {'aspect': 'beds',
#     'opinion': 'comfy',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'}]},
#  {'text': 'its recommend hotel for buleleng area , close to mall and restaurant , but no pool under 6 years . morning bites need variation , friendly staff , non smoking room its very good choice for family , the price is worth it .',
#   'labels': [{'aspect': 'pool',
#     'opinion': 'no',
#     'polarity': 'NEG',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'morning bites',
#     'opinion': 'need variation',
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'non smoking room',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'price',
#     'opinion': 'worth it',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'}]},
#  {'text': "A nice and comfortable Hotel . Nice and helpful staf . Don ' t eat the food in the resturant though , not even the breakefast ! Very disapointing ! But there are a few good places down the road and everything else Is really good .",
#   'labels': [{'aspect': 'Hotel',
#     'opinion': 'comfortable',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'Hotel',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'staf',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staf',
#     'opinion': 'Nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'food in the resturant',
#     'opinion': 'disapointing',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'breakefast',
#     'opinion': 'disapointing',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'places down the road',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'LOCATION#ENTERTAINMENT'},
#    {'aspect': 'everything else',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'We were booked into the Aston by our travel agent . During our stay in Bali we needed to book another at a different part of our trip and decided to stay at the Aston again . We would highly reccomend it to anyone wanting to stay somewhere near the airport .',
#   'labels': [{'aspect': 'stay',
#     'opinion': 'reccomend',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'airport',
#     'opinion': 'near',
#     'polarity': 'POS',
#     'category': 'LOCATION#TRANSPORT_HUB'}]},
#  {'text': 'Wanna plan for Meeting , I will fully recommmend to stay and book your valuable meeting with Fame Sunset . Amazing food , Amazing meeting room with motivational quotes , clear LCD Projector , Boombastic Sound System . . . Satisfaction guaranteed ! ! ! !',
#   'labels': [{'aspect': 'stay',
#     'opinion': 'recommmend',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'book',
#     'opinion': 'recommmend',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'food',
#     'opinion': 'Amazing',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'meeting room',
#     'opinion': 'Amazing',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'LCD Projector',
#     'opinion': 'clear',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'Sound System',
#     'opinion': 'Boombastic',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'}]},
#  {'text': "We only stayed one night as in transit to Lembongan . It ' s a cheap place to stay . Room was clean , bed was comfy , breakfast was average . Pool area could do with some maintenance , decking in some areas lifting around pool . Pool was refreshing . Good location , close to main area of Kuta . Suited our family for a nights stay .",
#   'labels': [{'aspect': 'place',
#     'opinion': 'cheap',
#     'polarity': 'NEU',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Room',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'bed',
#     'opinion': 'comfy',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'breakfast',
#     'opinion': 'average',
#     'polarity': 'NEU',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Pool area',
#     'opinion': 'maintenance',
#     'polarity': 'NEG',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'Pool',
#     'opinion': 'refreshing',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'location',
#     'opinion': 'Good',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'}]},
#  {'text': 'My family and I were looking forward to living at this lovely hotel with the amenities and services provided . Yes , it was a perfect short stay given by this team . It also includes a location close to an exciting area in Bali . Well done .',
#   'labels': [{'aspect': 'amenities',
#     'opinion': 'provided',
#     'polarity': 'POS',
#     'category': 'SERVICE#AMENITIES'},
#    {'aspect': 'services',
#     'opinion': 'provided',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'location',
#     'opinion': 'close to an exciting area',
#     'polarity': 'POS',
#     'category': 'LOCATION#ENTERTAINMENT'}]},
#  {'text': "I stayed 3 nights at this hotel , situated right next to the airport . Location is just prefect , walk able distance to the beach , restaurants , spa ' s . best value for money . Totally worth it . i will recommend this hotel to all .",
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'recommend',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'money',
#     'opinion': 'best value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Location',
#     'opinion': 'prefect',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'beach',
#     'opinion': 'walk able distance',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'restaurants',
#     'opinion': 'walk able distance',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': "spa ' s",
#     'opinion': 'walk able distance',
#     'polarity': 'POS',
#     'category': 'LOCATION#ENTERTAINMENT'}]},
#  {'text': 'Hotel is just steps away from Kuta Beach . Big room but Breakfast need improvement and don \' t stay in room 407 as they will " Parked " that cleaning cart just beside your door . : ( Note : Free WiFi is only available in lobby . Stayed 11 to 14 Feb 2020 .',
#   'labels': [{'aspect': 'Free WiFi',
#     'opinion': 'only available in lobby',
#     'polarity': 'NEG',
#     'category': 'FACILITY#WIFI'},
#    {'aspect': 'room',
#     'opinion': 'Big',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'Breakfast',
#     'opinion': 'need improvement',
#     'polarity': 'NEG',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'room 407',
#     'opinion': "don ' t stay",
#     'polarity': 'NEG',
#     'category': 'ROOM#GENERAL'}]},
#  {'text': 'Hotel was far from main road . Room were spacy , its suitable for lil family . Breakfast were good with so many option either western or asian .',
#   'labels': [{'aspect': 'Breakfast',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Breakfast',
#     'opinion': 'many option',
#     'polarity': 'POS',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'Room',
#     'opinion': 'spacy',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'Hotel',
#     'opinion': 'far from main road',
#     'polarity': 'NEU',
#     'category': 'LOCATION#NEARBY_AMENITIES'}]},
#  {'text': 'Upgrade cleanliness for the room please . Overall a good stay in the hotel . Very close to the airport and nice facilities . For the staff , please do not smoke when you are in service with the guest . Keep it up !',
#   'labels': [{'aspect': 'staff',
#     'opinion': 'smoke',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'facilities',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'airport',
#     'opinion': 'close',
#     'polarity': 'NEU',
#     'category': 'LOCATION#TRANSPORT_HUB'},
#    {'aspect': 'hotel',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'Upgrade cleanliness',
#     'polarity': 'NEG',
#     'category': 'ROOM#CLEANLINESS'}]},
#  {'text': 'The room ok . got extra bolster . Breakfast not really good choise . The swimming pool ok . Easy to double six beach only 15 min walk or 2 min by taxi .',
#   'labels': [{'aspect': 'room',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'bolster',
#     'opinion': 'extra',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'Breakfast',
#     'opinion': 'not really good',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'swimming pool',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'FACILITY#POOL'}]},
#  {'text': 'lack options of food , BBQ even not as expected . seem like they limits their food , should asking them every time want to take meal . server also not so welcome .',
#   'labels': [{'aspect': 'food',
#     'opinion': 'lack options',
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'BBQ',
#     'opinion': 'not as expected',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'food',
#     'opinion': 'limits',
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'server',
#     'opinion': 'not so welcome',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'We found the hotel to be great but the surf waas very very crowded all day and the water not so clean .',
#   'labels': [{'aspect': 'water',
#     'opinion': 'not so clean',
#     'polarity': 'NEG',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'surf',
#     'opinion': 'crowded',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'When we arrived there was no hassle . we got our hotel cards and straight up to our rooms , which were lovely and tidy . Great for what we paid . The hotel is close to shopping destinations and right across the road fro the beach . Staff are amazing and make you feel like family . they do a lot to please you .',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'close to shopping destinations',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'rooms',
#     'opinion': 'lovely',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'rooms',
#     'opinion': 'tidy',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'Staff',
#     'opinion': 'amazing',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'I got this hotel as a package from my Bali ticket purchase from Groupon . It was a really good deal , cheap and with breakfast included . This hotel has a really nice lobby and service staff but the room they gave me was facing just a concrete wall with no scenery at all . The room feels damp / wet and was infested with mosquitoes . Never going back there again .',
#   'labels': [{'aspect': 'deal',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'deal',
#     'opinion': 'cheap',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'breakfast',
#     'opinion': 'included',
#     'polarity': 'POS',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'lobby',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'service staff',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'room',
#     'opinion': 'damp',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'room',
#     'opinion': 'wet',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'room',
#     'opinion': 'infested with mosquitoes',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'}]},
#  {'text': "Booked on a Agoda , photo ' s looked good . The whole hotel is old and dirty see my picture ' s attached . Rang agoda to get refund the Ozz Hotel manager refused . I waisted time and money on a holiday booking . It shouldnt be AVAILABLE on booking sites without upto date images .",
#   'labels': [{'aspect': 'holiday booking',
#     'opinion': 'money',
#     'polarity': 'NEG',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'holiday booking',
#     'opinion': 'waisted time',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'old',
#     'polarity': 'NEG',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'dirty',
#     'polarity': 'NEG',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': "photo ' s",
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': "Booked on a Agoda , photo ' s looked good . The whole hotel is old and dirty see my picture ' s attached . Rang agoda to get refund the Ozz Hotel manager refused . I waisted time and money on a holiday booking . It shouldnt be AVAILABLE on booking sites without upto date images .",
#   'labels': [{'aspect': 'holiday booking',
#     'opinion': 'money',
#     'polarity': 'NEG',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'holiday booking',
#     'opinion': 'waisted time',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'old',
#     'polarity': 'NEG',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'dirty',
#     'polarity': 'NEG',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': "photo ' s",
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'Going back for Our 4th time I January and this time we are taking our family . Rooms are a little dated but clean . The grounds and gardens are beautiful and well maintained and the pool is ALWAYS crystal clear .',
#   'labels': [{'aspect': 'Rooms',
#     'opinion': 'dated',
#     'polarity': 'NEG',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'Rooms',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'pool',
#     'opinion': 'crystal clear',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'gardens',
#     'opinion': 'beautiful',
#     'polarity': 'POS',
#     'category': 'FACILITY#EXPERIENCE'},
#    {'aspect': 'pool',
#     'opinion': 'crystal clear',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'gardens',
#     'opinion': 'well maintained',
#     'polarity': 'POS',
#     'category': 'FACILITY#MAINTAIN'},
#    {'aspect': 'grounds',
#     'opinion': 'beautiful',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'grounds',
#     'opinion': 'well maintained',
#     'polarity': 'POS',
#     'category': 'FACILITY#MAINTAIN'}]},
#  {'text': 'The hotel is cheap & Clean , just the location is quite far from the main happening areas at Kuta , Bali ! Breakfast is not proper prepare and the price is high , better to book the room that include breakfast !',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'cheap',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'hotel',
#     'opinion': 'Clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'location',
#     'opinion': 'far from the main happening areas',
#     'polarity': 'NEG',
#     'category': 'LOCATION#ENTERTAINMENT'},
#    {'aspect': 'Breakfast',
#     'opinion': 'not proper',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'price',
#     'opinion': 'high',
#     'polarity': 'NEG',
#     'category': 'HOTEL#PRICE'}]},
#  {'text': 'Hotel was simple but nice . Good pool to cool down in and breakfast ok . Towels provided , could do with getting new towels as ours were thread bare and had holes in . Short distance to other restaurants and if you want to go a bit further very easy to get a taxi . In walking distance to the beach .',
#   'labels': [{'aspect': 'Hotel',
#     'opinion': 'simple',
#     'polarity': 'NEU',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'Hotel',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'pool',
#     'opinion': 'Good',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'breakfast',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Towels',
#     'opinion': 'provided',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'restaurants',
#     'opinion': 'Short distance',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'Towels',
#     'opinion': 'thread bare',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'Towels',
#     'opinion': 'had holes',
#     'polarity': 'NEG',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'beach',
#     'opinion': 'In walking distance',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'}]},
#  {'text': "I spent 4 nights here and I absolutely loved the atmosphere . I had all the space I needed and the food was quite good too . It ' s located close to the airport and convenient if you are flying the day after or so . However , most of the top Bali attractions are located far from here which cost me more than I was anticipating to get there .",
#   'labels': [{'aspect': 'atmosphere',
#     'opinion': 'loved',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'food',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Bali attractions',
#     'opinion': 'far from here',
#     'polarity': 'NEG',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'located',
#     'opinion': 'close to the airport',
#     'polarity': 'NEU',
#     'category': 'LOCATION#TRANSPORT_HUB'},
#    {'aspect': 'located',
#     'opinion': 'convenient',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'}]},
#  {'text': 'We stayed for 5 nights at ibis , bali legian . the location is very good . Right in the centre of the town . Rooms are neat and clean . Service is also good . overall good value for money . Also the breakfast was good .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'neat',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'breakfast',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'money',
#     'opinion': 'good value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Service',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'}]},
#  {'text': 'It was a nice and friendly place to stay food was not flash but ok there English could have been better as it was hard to understand at times . there pool area was very basic .',
#   'labels': [{'aspect': 'pool area',
#     'opinion': 'basic',
#     'polarity': 'NEU',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'food',
#     'opinion': 'not flash',
#     'polarity': 'NEG',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'food',
#     'opinion': 'ok',
#     'polarity': 'NEU',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'place',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'place',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'We visit this hotel recomended by kilroy in mid november . Very nice staff and good hotel regarding the cost . The pool area is almost empty so we had it for our selves : ) . We had a plesent stay . Extra much thanks to the girl in the reception who let us use her motorbike to the pharmacy when my girlfriend got sick .',
#   'labels': [{'aspect': 'girl in the reception',
#     'opinion': 'thanks',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'stay',
#     'opinion': 'plesent',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'pool area',
#     'opinion': 'empty',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'hotel',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'staff',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'I was impressed with my stay at Dekuta ! The location was great and the hotel itself was nice and clean and had a great pool . I felt it was good value for money and staff were always friendly and helpful .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'hotel',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'hotel',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'pool',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'money',
#     'opinion': 'good value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': "The staff were helpful and friendly . The rooms were neat but not particularly clean . The pool was lovely . I did spot a cockroach in the bathroom but for what it costs to stay here ( cheaaaap ) it didn ' t bother me .",
#   'labels': [{'aspect': 'staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'rooms',
#     'opinion': 'neat',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'rooms',
#     'opinion': 'not particularly clean',
#     'polarity': 'NEG',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'pool',
#     'opinion': 'lovely',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'bathroom',
#     'opinion': 'spot a cockroach',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'costs',
#     'opinion': 'cheaaaap',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'}]},
#  {'text': 'Ordinary budget hotels in Bali are usually not really hygienic . But this particular budget hotel is surprisingly the utmost opposite . Especially the toilet area . . ! ! kuddos to everyday . Staffs were smiling all the time but it seems that they were having a difficult time speaking English to me . Overall . . . love it and I really am looking forward in staying again . .',
#   'labels': [{'aspect': 'Overall',
#     'opinion': 'love',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'Staffs',
#     'opinion': 'smiling',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'speaking English',
#     'opinion': 'difficult time',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'Feels like at home . Location is good . Near to sunset road . Friendly staffs . We will stay here for sure when in Bali . Cannot wait and very excited until July 2016 for next bali visit . My kids love to stay here . Minus : 2nd wooden floor is noisy when someone walk will disturb neighbour .',
#   'labels': [{'aspect': 'Location',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'staffs',
#     'opinion': 'Friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': '2nd wooden floor',
#     'opinion': 'noisy',
#     'polarity': 'NEG',
#     'category': 'ROOM#EXPERIENCE'},
#    {'aspect': 'My kids',
#     'opinion': 'love to stay',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'}]},
#  {'text': 'I have stayed there for 3 days with family . Location is very good . Hotel staffs are friendly and provide all helps and recommendation . I would recommend to stay there when you are on solo trip . You can find other better options when you are planning trip to Kuta along with family .',
#   'labels': [{'aspect': 'Location',
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'staffs',
#     'opinion': 'friendly',
#     'polarity': 'POS',
# ...
#    {'aspect': 'NULL',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'HOTEL#CLEANLINESS'},
#    {'aspect': 'NULL',
#     'opinion': 'Nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'foods',
#     'opinion': 'lots',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'restaurant',
#     'opinion': 'lots',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'coffee shop',
#     'opinion': 'lots',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'souvenirs shop',
#     'opinion': 'lots',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'Kuta beach',
#     'opinion': 'Not far',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'shopping center',
#     'opinion': 'nearby',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'catholic church',
#     'opinion': 'across the road',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'}]},
#  {'text': 'We booked 5 rooms in total for our last stay in Bali . The hotel offers great value for money . However from the 5 rooms we booked , some has problem with the floor drain in the shower , and some has smell problem from the bathroom drainage . Breakfast was great in taste and varieties .',
#   'labels': [{'aspect': 'money',
#     'opinion': 'great value',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Breakfast',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'taste',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'varieties',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'bathroom drainage',
#     'opinion': 'smell',
#     'polarity': 'POS',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'floor drain',
#     'opinion': 'has problem',
#     'polarity': 'POS',
#     'category': 'ROOM#EXPERIENCE'}]},
#  {'text': 'Very pleasant stay . Good stuff going below and beyond to be helpful . Nice rooms , very clean , nice pool and tasty breakfast although - not includes in every price . Very good location . I would be happy to return even on the Nyepi day again .',
#   'labels': [{'aspect': 'stay',
#     'opinion': 'Very pleasant',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'stuff',
#     'opinion': 'Good',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'rooms',
#     'opinion': 'Nice',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'pool',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'pool',
#     'opinion': 'very clean',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'breakfast',
#     'opinion': 'tasty',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'location',
#     'opinion': 'Very good',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'}]},
#  {'text': 'Was not nice experience . It was dingy room . Staff was reactive . Reception staff very money minded . Customer satisfaction was not really on agenda . They took lot of time to respond . Could have been much better food .',
#   'labels': [{'aspect': 'experience',
#     'opinion': 'not nice',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'Staff',
#     'opinion': 'reactive',
#     'polarity': 'NEU',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Reception staff',
#     'opinion': 'money minded',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'respond',
#     'opinion': 'took lot of time',
#     'polarity': 'NEG',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'food',
#     'opinion': 'Could have been much better',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'}]},
#  {'text': 'We really like a rooftop pool so cozy , warm and off course they have small kids pool . Breakfast so boring and the taste its too plain . Room too small . Friendly staff .',
#   'labels': [{'aspect': 'rooftop pool',
#     'opinion': 'cozy',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'rooftop pool',
#     'opinion': 'warm',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'Breakfast',
#     'opinion': 'so boring',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'taste',
#     'opinion': 'too plain',
#     'polarity': 'NEG',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'Room',
#     'opinion': 'too small',
#     'polarity': 'NEG',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'staff',
#     'opinion': 'Friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'}]},
#  {'text': 'According to my husband experience we finally decide to stay here , the price worth it ! Not so expensive for the holiday season , And the location very strategist ! You can find ck , local shops , the beach behind discovery mall by walking . The hotel interior very nice !',
#   'labels': [{'aspect': 'here',
#     'opinion': 'Not so expensive',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'the price',
#     'opinion': 'worth',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'location',
#     'opinion': 'very strategist',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'local shops',
#     'opinion': 'find',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'beach',
#     'opinion': 'walking',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'nice',
#     'opinion': 'hotel interior',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'}]},
#  {'text': 'The biggest plus point is location . Just on the market and opposite beach . Bathroom needs renovation . . it is rusted . Small spider in my room after I checked in . Water kettle was dirty called for a new one and it got replaced after 40 mins . Room is spacious but no daylight scope .',
#   'labels': [{'aspect': 'location',
#     'opinion': 'biggest plus',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'Room',
#     'opinion': 'spacious',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'Bathroom',
#     'opinion': 'needs renovation',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'Bathroom',
#     'opinion': 'it is rusted',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'Water kettle',
#     'opinion': 'dirty',
#     'polarity': 'NEG',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'Room',
#     'opinion': 'no daylight scope',
#     'polarity': 'NEG',
#     'category': 'ROOM#AMBIENCE'}]},
#  {'text': "Even the rooms are small , but its good enough . The menu ' s taste good . All you can eat breakfast , with local and western taste . There ' s many photo spots at the hotel . Really eye catching and chick . But , at the bathroom minus cottonbud , comb , hair dryer ( you will get charge ) .",
#   'labels': [{'aspect': 'rooms',
#     'opinion': 'small',
#     'polarity': 'NEU',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'rooms',
#     'opinion': 'good enough',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': "menu ' s taste",
#     'opinion': 'good',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'},
#    {'aspect': 'photo spots',
#     'opinion': 'eye catching',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'photo spots',
#     'opinion': 'chick',
#     'polarity': 'POS',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'bathroom',
#     'opinion': 'get charge',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'}]},
#  {'text': "Place was ok . Nice area , Rooms were clean . Hot water in the shower . Staff was friendly and helpful . Swimming pool was great add on but not exactly clear water . Restaurant in the hotel didn ' t have half of the food they offered . A bit far form the center . You need a scooter or bicycle to get to the down town .",
#   'labels': [{'aspect': 'Place',
#     'opinion': 'ok',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'area',
#     'opinion': 'Nice',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'Rooms',
#     'opinion': 'clean',
#     'polarity': 'POS',
#     'category': 'ROOM#CLEANLINESS'},
#    {'aspect': 'water in the shower',
#     'opinion': 'Hot',
#     'polarity': 'POS',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'Staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Staff',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'Swimming pool',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'water',
#     'opinion': 'not exactly clear',
#     'polarity': 'NEG',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'food',
#     'opinion': "didn ' t have half of the food they offered",
#     'polarity': 'NEG',
#     'category': 'FOOD#CHOICE'},
#    {'aspect': 'center',
#     'opinion': 'A bit far',
#     'polarity': 'NEG',
#     'category': 'LOCATION#CENTRAL_CITY'}]},
#  {'text': 'Hotel is normal . The price is cheap . The location acceptable . It is around 4 blocks from the beach and 20 minutes walking to Kuta . Receptionist can be more friendly . The pool is in the rooftop but it is not bar or restaurant service there . Restaurant and bar are in the ground level next to reception area .',
#   'labels': [{'aspect': 'Hotel',
#     'opinion': 'normal',
#     'polarity': 'NEU',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'The price',
#     'opinion': 'cheap',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'Kuta',
#     'opinion': '20 minutes walking',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'beach',
#     'opinion': '4 blocks',
#     'polarity': 'POS',
#     'category': 'LOCATION#ATTRACTIONS'},
#    {'aspect': 'location',
#     'opinion': 'acceptable',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'}]},
#  {'text': 'We were supposed to stay for one night but to my discuss the room was a put off . Yes cheap an nasty . The toilet was filthy an the shower was absolute turn off . We checked few hours later we checked out to a nicer cleaner hotel . . . Couldnt wait to get out of there . I truly dont recommend this hotel at all .',
#   'labels': [{'aspect': 'room',
#     'opinion': 'put off',
#     'polarity': 'NEG',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'room',
#     'opinion': 'cheap',
#     'polarity': 'NEG',
#     'category': 'HOTEL#PRICE'},
#    {'aspect': 'room',
#     'opinion': 'nasty',
#     'polarity': 'NEG',
#     'category': 'ROOM#EXPERIENCE'},
#    {'aspect': 'toilet',
#     'opinion': 'filthy',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'shower',
#     'opinion': 'turn off',
#     'polarity': 'NEG',
#     'category': 'ROOM#BATHROOM'},
#    {'aspect': 'this hotel',
#     'opinion': 'dont recommend',
#     'polarity': 'NEG',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': "Alron is fine . Cheap and an OK location if you are a walker or have a motorbike . Even though breakfast is included go to nearby warungs for better quality . Bed gave us a restfull sleep . They are about to undertake big renovations and they may be trying to be somthing they ' re not .",
#   'labels': [{'aspect': 'breakfast',
#     'opinion': 'included',
#     'polarity': 'NEU',
#     'category': 'FOOD#GENERAL'},
#    {'aspect': 'Bed',
#     'opinion': 'restfull sleep',
#     'polarity': 'POS',
#     'category': 'ROOM#BED'},
#    {'aspect': 'location',
#     'opinion': 'OK',
#     'polarity': 'POS',
#     'category': 'LOCATION#GENERAL'},
#    {'aspect': 'nearby warungs',
#     'opinion': 'no',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'Alron',
#     'opinion': 'fine',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'Alron',
#     'opinion': 'Cheap',
#     'polarity': 'POS',
#     'category': 'HOTEL#PRICE'}]},
#  {'text': "Their location is very close to Seminyak shopping area , but you still got the nature feeling in this place . When the first time I get into the room , surprisingly they had second floor , which mean it ' s spacious . The service also very nice . All I can say is great !",
#   'labels': [{'aspect': 'Seminyak shopping area',
#     'opinion': 'very close',
#     'polarity': 'POS',
#     'category': 'LOCATION#NEARBY_AMENITIES'},
#    {'aspect': 'feeling',
#     'opinion': 'nature',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'second floor',
#     'opinion': 'spacious',
#     'polarity': 'POS',
#     'category': 'ROOM#SPACE'},
#    {'aspect': 'The service',
#     'opinion': 'very nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#GENERAL'},
#    {'aspect': 'place',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'}]},
#  {'text': 'The room is nice although there is a little spot on the bed when i checked in . . . Recommend to have a room on ground floor which have access to the pool . . . If you are a smoker , just open the sliding door and easly went to the pool to smoke or for swimming . . . The staff is nice and friendly . . .',
#   'labels': [{'aspect': 'room',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'staff',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'staff',
#     'opinion': 'friendly',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'bed',
#     'opinion': 'little spot',
#     'polarity': 'NEG',
#     'category': 'ROOM#BED'}]},
#  {'text': 'Me and my husband stayed in room number 5201 , we love it ! One thing probably that annoyed us is the voice from the lobby since our room is really close to the lobby . But overall everything is amazing : ) Love the fitness center , love the swimming pool , love the food ! : ) Thank you !',
#   'labels': [{'aspect': 'room',
#     'opinion': 'love',
#     'polarity': 'POS',
#     'category': 'ROOM#GENERAL'},
#    {'aspect': 'voice from the lobby',
#     'opinion': 'annoyed',
#     'polarity': 'NEG',
#     'category': 'HOTEL#EXPERIENCE'},
#    {'aspect': 'everything',
#     'opinion': 'amazing',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'fitness center',
#     'opinion': 'Love',
#     'polarity': 'POS',
#     'category': 'FACILITY#GENERAL'},
#    {'aspect': 'swimming pool',
#     'opinion': 'love',
#     'polarity': 'POS',
#     'category': 'FACILITY#POOL'},
#    {'aspect': 'food',
#     'opinion': 'love',
#     'polarity': 'POS',
#     'category': 'FOOD#TASTE'}]},
#  {'text': 'this is a great hotel with really nice employees who are attentive to the slightest need of the customer including one in particular Agung who works particularly well who is very smiling and helpful and who remains professional . I recommend this hotel for its calm and tranquility .',
#   'labels': [{'aspect': 'hotel',
#     'opinion': 'great',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'employees',
#     'opinion': 'nice',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'employees',
#     'opinion': 'attentive',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'employees',
#     'opinion': 'smiling',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'employees',
#     'opinion': 'helpful',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'employees',
#     'opinion': 'professional',
#     'polarity': 'POS',
#     'category': 'SERVICE#HOSPITALITY'},
#    {'aspect': 'hotel',
#     'opinion': 'recommend',
#     'polarity': 'POS',
#     'category': 'HOTEL#GENERAL'},
#    {'aspect': 'hotel',
#     'opinion': 'calm',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'},
#    {'aspect': 'hotel',
#     'opinion': 'tranquility',
#     'polarity': 'POS',
#     'category': 'HOTEL#AMBIENCE'}]},
#  ...]

# %%
id_te_df = absa_instruction.data_utils.read_json(id_test_file_path, "test")
# Out:
# ./ABSADatasets/datasets/acos_datasets/2000.Hotel-ina\test.jsonl

# %%
id_tr_df = pd.DataFrame(id_tr_df)
id_tr_df
# Out:
#                                                    text  \
# 0     Beautiful , comfortable and friendly hotel nea...
# 1     Room veeeeery big , comfortable big bed , hot ...
# 2     room without power plug point , hair dryer , w...
# 3     The accomodation was great given the price 30 ...
# 4     For the price this hotel excellent . Rooms are...
# ...                                                 ...
# 1896  Over all is good , but please maintenance your...
# 1897  We arrived late and stayed at Harris before de...
# 1898  Lovely hotel . Rooms are small . The location ...
# 1899  Overall is good . Food is good . Breakfast is ...
# 1900  Located right near the airport with free airpo...
#
#                                                  labels
# 0     [{'aspect': 'money', 'opinion': 'Great value',...
# 1     [{'aspect': 'bed', 'opinion': 'comfortable', '...
# 2     [{'aspect': 'queen size bed', 'opinion': 'don ...
# 3     [{'aspect': 'Peti', 'opinion': 'close', 'polar...
# 4     [{'aspect': 'price', 'opinion': 'excellent', '...
# ...                                                 ...
# 1896  [{'aspect': 'internet', 'opinion': 'slowly', '...
# 1897  [{'aspect': 'Staff', 'opinion': 'amazing', 'po...
# 1898  [{'aspect': 'hotel', 'opinion': 'Lovely', 'pol...
# 1899  [{'aspect': 'Food', 'opinion': 'good', 'polari...
# 1900  [{'aspect': 'rooms', 'opinion': 'need a new co...
#
# [1901 rows x 2 columns]

# %%
id_te_df = pd.DataFrame(id_te_df)
id_te_df
# Out:
#                                                   text  \
# 0    The location is good in the middle of kuta tou...
# 1    Direct from the Denpasar airport we went to th...
# 2    This hotel is a great stay in Legian , Bali , ...
# 3    We stayed here for 2 nights . The staff were f...
# 4    I have stayed at Dekuta hotel for many years n...
# ..                                                 ...
# 196  Excellent stay . Great staff and variety of re...
# 197  The resort itself was pretty good , but the cu...
# 198  I ' ve been visiting this hotel minimum twice ...
# 199  No regrets at all . It was my second visit to ...
# 200  Always love coming to this hotel . Good food f...
#
#                                                 labels
# 0    [{'aspect': 'location', 'opinion': 'good', 'po...
# 1    [{'aspect': 'staff', 'opinion': 'nice', 'polar...
# 2    [{'aspect': 'hotel', 'opinion': 'great', 'pola...
# 3    [{'aspect': 'staff', 'opinion': 'friendly', 'p...
# 4    [{'aspect': 'hotel', 'opinion': 'perfect', 'po...
# ..                                                 ...
# 196  [{'aspect': 'stay', 'opinion': 'Excellent', 'p...
# 197  [{'aspect': 'resort', 'opinion': 'good', 'pola...
# 198  [{'aspect': 'hotel', 'opinion': 'visiting', 'p...
# 199  [{'aspect': 'service', 'opinion': 'Good', 'pol...
# 200  [{'aspect': 'hotel', 'opinion': 'love coming',...
#
# [201 rows x 2 columns]

# %%
loader = absa_instruction.data_utils.InstructDatasetLoader(id_tr_df, id_te_df)

# %%
if loader.train_df_id is not None:
    loader.train_df_id = loader.prepare_instruction_dataloader(loader.train_df_id)
if loader.test_df_id is not None:
    loader.test_df_id = loader.prepare_instruction_dataloader(loader.test_df_id)
if loader.train_df_ood is not None:
    loader.train_df_ood = loader.prepare_instruction_dataloader(loader.train_df_ood)
if loader.test_df_ood is not None:
    loader.test_df_ood = loader.prepare_instruction_dataloader(loader.test_df_ood)

# %%
# Create T5 utils object
t5_exp = absa_instruction.model.T5Generator(model_checkpoint)
# Out:
# [2024-06-25 11:25:37] (2.4.1.post1) ********** Available ACOS model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-06-25 11:25:37] (2.4.1.post1) ********** Available ACOS model checkpoints for Version:2.4.1.post1 (this version) **********
# [2024-06-25 11:25:37] (2.4.1.post1) Checkpoint:kevinscaria/ate_tk-instruct-base-def-pos-neg-neut-combined is not found, you can raise an issue for requesting shares of checkpoints
# [2024-06-25 11:25:37] (2.4.1.post1) No checkpoint found in Model Hub for task: kevinscaria/ate_tk-instruct-base-def-pos-neg-neut-combined

# %%
# Tokenize Dataset
id_ds, id_tokenized_ds, ood_ds, ood_tokenzed_ds = loader.create_datasets(
    t5_exp.tokenize_function_inputs
)
# Out:
#  12%|█▎        | 1897/15176 [26:46<3:07:28,  1.18it/s]
#  12%|█▎        | 1897/15176 [38:35<4:30:09,  1.22s/it]
# Map: 100%|██████████| 7587/7587 [00:00<00:00, 8072.51 examples/s]
# Map: 100%|██████████| 804/804 [00:00<00:00, 7728.74 examples/s]

# %%
id_ds, id_tokenized_ds, ood_ds, ood_tokenzed_ds = loader.create_datasets(
    t5_exp.tokenize_function_inputs
)
# Out:
# Map: 100%|██████████| 7587/7587 [00:00<00:00, 8896.83 examples/s]
# Map: 100%|██████████| 804/804 [00:00<00:00, 9442.53 examples/s]

# %%
training_args = {
    "output_dir": model_out_path,
    "evaluation_strategy": "epoch",
    "save_strategy": "epoch",
    "learning_rate": 5e-5,
    "per_device_train_batch_size": 4,
    "per_device_eval_batch_size": 16,
    "num_train_epochs": 8,
    "weight_decay": 0.01,
    "warmup_ratio": 0.1,
    "load_best_model_at_end": True,
    "push_to_hub": False,
    "eval_accumulation_steps": 1,
    "predict_with_generate": True,
    "logging_steps": 1000000000,
    "use_mps_device": False,
    # 'fp16': True,
    "fp16": False,
}

# %%
# Train model
model_trainer_default_category = t5_exp.train(id_tokenized_ds, **training_args)
# Out:
# Trainer device: cuda:0
#
# Model training started ....
#   0%|          | 0/15176 [00:00<?, ?it/s]You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#  12%|█▎        | 1897/15176 [06:51<44:24,  4.98it/s]
#
#
#
#  12%|█▎        | 1897/15176 [07:03<44:24,  4.98it/s]
# {'eval_loss': 0.31957241892814636, 'eval_runtime': 12.0317, 'eval_samples_per_second': 66.824, 'eval_steps_per_second': 4.239, 'epoch': 1.0}
#  25%|██▌       | 3794/15176 [14:06<39:28,  4.80it/s]
#
#
#
#  25%|██▌       | 3794/15176 [14:18<39:28,  4.80it/s]
# {'eval_loss': 0.2739202678203583, 'eval_runtime': 11.8079, 'eval_samples_per_second': 68.09, 'eval_steps_per_second': 4.319, 'epoch': 2.0}
#  38%|███▊      | 5691/15176 [21:21<30:37,  5.16it/s]
#
#
#
#  38%|███▊      | 5691/15176 [21:32<30:37,  5.16it/s]
# {'eval_loss': 0.2714236378669739, 'eval_runtime': 10.9456, 'eval_samples_per_second': 73.454, 'eval_steps_per_second': 4.659, 'epoch': 3.0}
#  50%|█████     | 7588/15176 [28:26<26:17,  4.81it/s]
#
#
#
#  50%|█████     | 7588/15176 [28:37<26:17,  4.81it/s]
# {'eval_loss': 0.25489920377731323, 'eval_runtime': 11.5556, 'eval_samples_per_second': 69.577, 'eval_steps_per_second': 4.413, 'epoch': 4.0}
#  62%|██████▎   | 9485/15176 [35:34<19:22,  4.89it/s]
#
#
#
#  62%|██████▎   | 9485/15176 [35:46<19:22,  4.89it/s]
# {'eval_loss': 0.2570568919181824, 'eval_runtime': 11.708, 'eval_samples_per_second': 68.671, 'eval_steps_per_second': 4.356, 'epoch': 5.0}
#  75%|███████▌  | 11382/15176 [42:47<13:46,  4.59it/s]
#
#
#
#  75%|███████▌  | 11382/15176 [42:59<13:46,  4.59it/s]
# {'eval_loss': 0.25626447796821594, 'eval_runtime': 11.7558, 'eval_samples_per_second': 68.392, 'eval_steps_per_second': 4.338, 'epoch': 6.0}
#  88%|████████▊ | 13279/15176 [49:44<06:30,  4.86it/s]
#
#
#
#  88%|████████▊ | 13279/15176 [49:55<06:30,  4.86it/s]
# {'eval_loss': 0.25570550560951233, 'eval_runtime': 10.6662, 'eval_samples_per_second': 75.379, 'eval_steps_per_second': 4.781, 'epoch': 7.0}
# 100%|██████████| 15176/15176 [56:04<00:00,  5.84it/s]
#
#
#
# 100%|██████████| 15176/15176 [56:14<00:00,  5.84it/s]
# {'eval_loss': 0.26334109902381897, 'eval_runtime': 10.3537, 'eval_samples_per_second': 77.653, 'eval_steps_per_second': 4.926, 'epoch': 8.0}
#
# 100%|██████████| 15176/15176 [56:16<00:00,  4.49it/s]
# {'train_runtime': 3376.8464, 'train_samples_per_second': 17.974, 'train_steps_per_second': 4.494, 'train_loss': 0.35152765494242555, 'epoch': 8.0}

# %%
# Get prediction labels - Training set
id_tr_pred_labels = t5_exp.get_labels(
    predictor=model_trainer_default_category,
    tokenized_dataset=id_tokenized_ds,
    sample_set="train",
    batch_size=16,
)
id_tr_labels = [i.strip() for i in id_ds["train"]["labels"]]
# Out:
# Prediction from trainer
# 100%|██████████| 475/475 [10:44<00:00,  1.36s/it]

# %%
# Get prediction labels - Training set
id_te_pred_labels = t5_exp.get_labels(
    predictor=model_trainer_default_category,
    tokenized_dataset=id_tokenized_ds,
    sample_set="test",
    batch_size=16,
)
id_te_labels = [i.strip() for i in id_ds["test"]["labels"]]
# Out:
# Prediction from trainer
# 100%|██████████| 51/51 [00:58<00:00,  1.15s/it]

# %%
metrics = t5_exp.get_classic_metrics(id_tr_labels, id_tr_pred_labels)
print("----------------------- Classic Training Set Metrics  default category-----------------------")
print(metrics)
# Out:
# Discoveryshoppingmall|rooftoppool|staff|stay
# stay|staff|rooftoppool
# Discoveryshoppingmall:POS|rooftoppool:POS|staff:POS|stay:POS
# Discoveryshoppingmall:POS|rooftoppool:POS|staff:POS|stay:POS
# Discoveryshoppingmall:close|rooftoppool:nice|staff:Lovely|stay:nice
# Discoveryshoppingmall:close|rooftoppool:nice|staff:Lovely|stay:nice
# Discoveryshoppingmall:LOCATION#ENTERTAINMENT|rooftoppool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|stay:HOTEL#GENERAL
# Discoveryshoppingmall:LOCATION#ENTERTAINMENT|rooftoppool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE
# Room|Breakfast
# location|beach|Room|Breakfast
# Room:NEG|Breakfast:POS
# Room:NEG|Room:POS|Breakfast:POS
# Room:notsobig|Breakfast:good
# Room:notsobig|Room:enough|Breakfast:good
# Room:ROOM#SPACE|Breakfast:FOOD#TASTE
# Room:ROOM#SPACE|Room:ROOM#SPACE|Breakfast:FOOD#GENERAL
# Location
# Location|Airport|Taxi|Taxi
# Location:NEG|Location:POS
# Location:NEG
# Location:bithard|Location:closetotheairport
# Location:hard
# Location:LOCATION#GENERAL|Location:LOCATION#TRANSPORT_HUB
# Location:LOCATION#TRANSPORT_HUB
# Reception|property|roomac|bathroom
# property|roomac|bathroom
# Reception:NEG|property:POS|roomac:NEG|bathroom:NEG
# Reception:NEG|property:POS|roomac:NEG|bathroom:NEG
# Reception:notaware|property:good|roomac:leaking|bathroom:stink
# Reception:notaware|property:good|roomac:leaking|bathroom:stink
# Reception:SERVICE#ASSISTANCE|property:HOTEL#GENERAL|roomac:ROOM#MAINTAIN|bathroom:ROOM#BATHROOM
# Reception:SERVICE#HOSPITALITY|property:HOTEL#GENERAL|roomac:ROOM#AIRCON|bathroom:ROOM#BATHROOM
# place|airport|restaurants|malls|differentcuisine|rooftoppool|staffs
# place|staffs|rooftoppool|restaurants|malls|deliciouscuisine
# place:POS|airport:POS|restaurants:POS|malls:POS|differentcuisine:POS|rooftoppool:POS|staffs:POS
# place:POS|airport:POS|restaurants:POS|malls:POS|differentcuisine:POS|rooftoppool:POS|staffs:POS
# place:decent|airport:near|restaurants:close|malls:close|differentcuisine:nearby|rooftoppool:Has|staffs:good|staffs:helpful
# place:decent|airport:near|restaurants:close|malls:close|differentcuisine:nearby|rooftoppool:Has|staffs:good|staffs:helpful
# place:HOTEL#GENERAL|airport:LOCATION#TRANSPORT_HUB|restaurants:LOCATION#NEARBY_AMENITIES|malls:LOCATION#ENTERTAINMENT|differentcuisine:LOCATION#NEARBY_AMENITIES|rooftoppool:FACILITY#POOL|staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY
# place:HOTEL#GENERAL|airport:LOCATION#TRANSPORT_HUB|restaurants:LOCATION#NEARBY_AMENITIES|malls:LOCATION#ENTERTAINMENT|differentcuisine:LOCATION#NEARBY_AMENITIES|rooftoppool:FACILITY#POOL|staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY
# menu|rooms|location
# menu|rooms|location|bigshoppingmalls|cab
# menu:POS|rooms:POS|location:NEU|location:POS
# menu:POS|rooms:POS|location:NEG
# menu:great|rooms:new|rooms:nice|location:awayfromeverythingtouristy|location:closetobigshoppingmalls
# menu:great|rooms:new|rooms:nice|location:awayfromeverythingtouristy|location:closetobigshoppingmalls
# menu:FOOD#GENERAL|rooms:ROOM#AMBIENCE|rooms:ROOM#GENERAL|location:LOCATION#ENTERTAINMENT|location:LOCATION#NEARBY_AMENITIES
# menu:FOOD#TASTE|rooms:ROOM#GENERAL|rooms:ROOM#GENERAL|location:LOCATION#GENERAL
# rooms|beds|beach|shoppingarea
# rooms|beds|beach|shoppingarea
# rooms:POS|beds:NEG|beach:POS|shoppingarea:POS
# rooms:POS|rooms:POS|beds:NEG|beach:POS|shoppingarea:POS
# rooms:neat|rooms:clean|beds:small|beach:near|shoppingarea:near
# rooms:neat|rooms:clean|beds:small|beach:near|shoppingarea:near
# rooms:ROOM#CLEANLINESS|rooms:ROOM#CLEANLINESS|beds:ROOM#BED|beach:LOCATION#ATTRACTIONS|shoppingarea:LOCATION#NEARBY_AMENITIES
# rooms:ROOM#CLEANLINESS|rooms:ROOM#CLEANLINESS|beds:ROOM#BED|beach:LOCATION#ATTRACTIONS|shoppingarea:LOCATION#NEARBY_AMENITIES
# pool|location|GarlicLane|shopping|beach|eateries|Room
# stay|location|GarlicLane|shopping|beach|eateries|Room
# pool:NEG|location:POS|GarlicLane:POS|shopping:POS|beach:POS|eateries:POS|Room:POS
# pool:NEG|location:POS|GarlicLane:POS|shopping:POS|beach:POS|eateries:POS|Room:POS
# pool:crowded|location:Great|GarlicLane:veryclose|shopping:veryclose|beach:veryclose|eateries:abundance|Room:clean|Room:pleasing
# pool:crowded|location:Great|GarlicLane:close|shopping:close|beach:close|eateries:close|Room:clean|Room:pleasant
# pool:FACILITY#POOL|location:LOCATION#GENERAL|GarlicLane:LOCATION#NEARBY_AMENITIES|shopping:LOCATION#NEARBY_AMENITIES|beach:LOCATION#ATTRACTIONS|eateries:LOCATION#NEARBY_AMENITIES|Room:ROOM#CLEANLINESS|Room:ROOM#AMBIENCE
# pool:FACILITY#POOL|location:LOCATION#GENERAL|GarlicLane:LOCATION#NEARBY_AMENITIES|shopping:LOCATION#NEARBY_AMENITIES|beach:LOCATION#ATTRACTIONS|eateries:LOCATION#NEARBY_AMENITIES|Room:ROOM#CLEANLINESS|Room:ROOM#EXPERIENCE
# staff|service|value|Internetspeed
# staff|service|value|Internetspeed
# staff:POS|service:POS|value:POS|Internetspeed:POS
# staff:POS|service:POS|value:POS|Internetspeed:NEG
# staff:kind|service:good|value:good|Internetspeed:shouldbeimproved
# staff:kind|service:good|value:good|Internetspeed:shouldbeimproved
# staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|value:HOTEL#PRICE|Internetspeed:FACILITY#WIFI
# staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|value:HOTEL#PRICE|Internetspeed:FACILITY#WIFI
# stayed|staff|poolarea|Rooms|bathrooms
# staff|poolarea|Rooms|bathrooms|location
# stayed:POS|staff:POS|poolarea:POS|Rooms:NEU|bathrooms:NEG
# stayed:POS|staff:POS|poolarea:POS|Rooms:NEG|bathrooms:NEG
# stayed:feelverywelcome|staff:lovely|poolarea:definitelyabonus|Rooms:verybasic|bathrooms:veryoutdated
# stayed:feelverywelcome|staff:lovely|poolarea:bonus|Rooms:basic|bathrooms:outdated
# stayed:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|poolarea:FACILITY#POOL|Rooms:ROOM#GENERAL|bathrooms:ROOM#BATHROOM
# stayed:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|poolarea:FACILITY#POOL|Rooms:ROOM#GENERAL|bathrooms:ROOM#BATHROOM
# location|Singarajacenter|thebeach|aircon|WiFi|Staff|furnishings|ordered2coffees
# location|Singarajacenter|beach|aircon|WIFI|Staff|furniture|coffees
# location:POS|Singarajacenter:POS|thebeach:POS|aircon:POS|WiFi:POS|Staff:POS|furnishings:NEU|ordered2coffees:NEG
# location:POS|Singarajacenter:POS|thebeach:POS|aircon:POS|WiFi:POS|Staff:POS|furnishings:NEU|ordered2coffees:NEG
# location:Great|Singarajacenter:close|thebeach:righton|aircon:Good|WiFi:great|Staff:nice|Staff:friendly|furnishings:Basic|ordered2coffees:nevercame
# location:Great|Singarajacenter:close|thebeach:righton|aircon:Good|WiFi:great|Staff:nice|Staff:friendly|furnishings:Basic|ordered2coffees:nevercame
# location:LOCATION#GENERAL|Singarajacenter:LOCATION#CENTRAL_CITY|thebeach:LOCATION#ATTRACTIONS|aircon:ROOM#AIRCON|WiFi:FACILITY#WIFI|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|furnishings:FACILITY#GENERAL|ordered2coffees:SERVICE#AMENITIES
# location:LOCATION#GENERAL|Singarajacenter:LOCATION#CENTRAL_CITY|thebeach:LOCATION#ATTRACTIONS|aircon:ROOM#AIRCON|WiFi:FACILITY#WIFI|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|furnishings:ROOM#FACILITY|ordered2coffees:FOOD#PRICE
# Rooms|Bar|food|Rooftoppool
# Rooms|Bar|food|Rooftoppool
# Rooms:POS|Bar:POS|food:POS|Rooftoppool:POS
# Rooms:POS|Bar:POS|food:POS|Rooftoppool:POS
# Rooms:good|Rooms:quiet|Bar:reasonablypriced|food:reasonablypriced|Rooftoppool:lovely
# Rooms:good|Rooms:quiet|Bar:reasonablypriced|food:reasonablypriced|Rooftoppool:lovely
# Rooms:ROOM#GENERAL|Rooms:ROOM#AMBIENCE|Bar:FOOD#PRICE|food:FOOD#PRICE|Rooftoppool:FACILITY#POOL
# Rooms:ROOM#GENERAL|Rooms:ROOM#EXPERIENCE|Bar:FOOD#PRICE|food:FOOD#PRICE|Rooftoppool:FACILITY#POOL
# hotel|TV|price|Rooms|staff
# hotel|interior|exterior|Rooms|staff|beach
# hotel:POS|TV:POS|price:POS|Rooms:POS|staff:POS
# hotel:POS|TV:POS|price:POS|Rooms:POS|staff:POS
# hotel:modern|TV:with|price:Half|Rooms:clean|staff:Helpful
# hotel:modern|TV:mountedflatscreen|price:half|Rooms:clean|staff:Helpful
# hotel:HOTEL#AMBIENCE|TV:ROOM#AMENITIES|price:HOTEL#PRICE|Rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY
# hotel:HOTEL#AMBIENCE|TV:ROOM#FACILITY|price:HOTEL#PRICE|Rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY
# Room|Bed|Breakfast
# Room|bed|Value
# Room:POS|Bed:POS|Breakfast:NEG
# Room:POS|Bed:POS|Breakfast:NEU
# Room:Clean|Room:Spotless|Bed:Comfortable|Breakfast:CanBeBetter
# Room:Clean|Room:Spotless|Bed:Comfortable|Breakfast:CanBeBetter
# Room:FACILITY#CLEANLINESS|Room:FACILITY#CLEANLINESS|Bed:ROOM#BED|Breakfast:FOOD#TASTE
# Room:ROOM#CLEANLINESS|Room:ROOM#SPACE|Bed:ROOM#BED|Breakfast:FOOD#TASTE
# hotel|Rooms|Location|Breakfast|Pool|Foodcourt|staff|Checkin
# hotel|Rooms|Location|Breakfast|Checkin|staff|Pricepaid|Foodcourt|Cheap
# hotel:POS|Rooms:POS|Location:POS|Breakfast:NEG|Pool:POS|Foodcourt:POS|staff:NEG|Checkin:NEG
# hotel:POS|Rooms:POS|Location:POS|Breakfast:NEG|Pool:POS|Foodcourt:POS|staff:NEG|Checkin:NEG
# hotel:clean|hotel:Decent|Rooms:spacious|Location:good|Breakfast:belowaverage|Breakfast:lessvariety|Pool:fine|Foodcourt:opposite|staff:less|Checkin:notsmooth
# hotel:Decent|Rooms:spacious|Location:good|Breakfast:belowaverage|Pool:fine|Foodcourt:opposite|staff:less|Checkin:notsmooth
# hotel:HOTEL#CLEANLINESS|hotel:HOTEL#GENERAL|Rooms:ROOM#SPACE|Location:LOCATION#GENERAL|Breakfast:FOOD#TASTE|Breakfast:FOOD#CHOICE|Pool:FACILITY#POOL|Foodcourt:LOCATION#NEARBY_AMENITIES|staff:SERVICE#HOSPITALITY|Checkin:SERVICE#HOSPITALITY
# hotel:HOTEL#CLEANLINESS|hotel:HOTEL#CLEANLINESS|Rooms:ROOM#SPACE|Location:LOCATION#GENERAL|Breakfast:FOOD#CHOICE|Breakfast:FOOD#CHOICE|Pool:FACILITY#POOL|Foodcourt:LOCATION#NEARBY_AMENITIES|staff:SERVICE#HOSPITALITY|Checkin:SERVICE#HOSPITALITY
# room|view
# furniture|room|view
# room:NEG|view:POS
# room:NEG|view:POS
# room:reallycold|view:great
# room:cold|view:great
# room:ROOM#AIRCON|view:LOCATION#VIEW
# room:ROOM#EXPERIENCE|room:ROOM#EXPERIENCE|view:LOCATION#VIEW
# hotel|Staff|room
# Staff|room
# hotel:POS|Staff:POS|room:POS
# hotel:POS|Staff:POS|room:POS
# hotel:feltlikehome|Staff:lovely|Staff:helpful|room:highstandard|room:veryclean
# hotel:feelslikehome|Staff:lovely|Staff:helpful|room:highstandard|room:clean
# hotel:HOTEL#EXPERIENCE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|room:ROOM#GENERAL|room:ROOM#CLEANLINESS
# hotel:HOTEL#EXPERIENCE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|room:ROOM#GENERAL|room:ROOM#CLEANLINESS
# beach|Kutashoppingarea|rooms|poolarea|money|place
# place|money|poolarea|rooms|Kutashoppingarea|beach
# beach:POS|Kutashoppingarea:POS|rooms:POS|poolarea:POS|money:POS|place:POS
# beach:POS|Kutashoppingarea:POS|rooms:POS|poolarea:POS|money:POS|place:POS
# beach:close|Kutashoppingarea:walkingdistance|rooms:clean|rooms:tidy|poolarea:Nice|money:value|place:Nice
# beach:close|Kutashoppingarea:walkingdistance|rooms:clean|rooms:tidy|poolarea:Nice|money:Goodvalue|place:Nice
# beach:LOCATION#ATTRACTIONS|Kutashoppingarea:LOCATION#NEARBY_AMENITIES|rooms:ROOM#CLEANLINESS|rooms:ROOM#CLEANLINESS|poolarea:FACILITY#POOL|money:HOTEL#PRICE|place:HOTEL#GENERAL
# beach:LOCATION#ATTRACTIONS|Kutashoppingarea:LOCATION#NEARBY_AMENITIES|rooms:ROOM#CLEANLINESS|rooms:ROOM#CLEANLINESS|poolarea:FACILITY#POOL|money:HOTEL#PRICE|place:HOTEL#GENERAL
# loation|staff
# staff|shoppingmall|traditionalmarket|staff
# loation:POS|staff:POS
# loation:POS|staff:POS
# loation:nearshoppingmall|staff:friendly|staff:competence
# loation:beachfront|staff:friendly|staff:competence
# loation:LOCATION#NEARBY_AMENITIES|staff:SERVICE#HOSPITALITY|staff:SERVICE#GENERAL
# loation:LOCATION#VIEW|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# Hotel|restaurant|IndonesianCuisines|price
# Hotel|restaurant|rice|hotel
# Hotel:POS|restaurant:POS|IndonesianCuisines:POS|price:POS
# Hotel:POS|restaurant:POS|IndonesianCuisines:POS|price:POS
# Hotel:Unique|restaurant:good|IndonesianCuisines:variant|price:affordable|Hotel:Recommended
# Hotel:Unique|restaurant:good|IndonesianCuisines:variant|price:affordable
# Hotel:HOTEL#AMBIENCE|restaurant:LOCATION#GENERAL|IndonesianCuisines:FOOD#CHOICE|price:HOTEL#PRICE|Hotel:HOTEL#GENERAL
# Hotel:HOTEL#AMBIENCE|restaurant:FOOD#GENERAL|IndonesianCuisines:FOOD#CHOICE|price:HOTEL#PRICE
# Overall|Staffs|speakingEnglish
# budgethotels|toiletarea|Staffs
# Overall:POS|Staffs:POS|speakingEnglish:NEG
# Overall:POS|Staffs:POS|speakingEnglish:NEG
# Overall:love|Staffs:smiling|speakingEnglish:difficulttime
# Overall:love|Staffs:smiling|speakingEnglish:difficulttime
# Overall:HOTEL#GENERAL|Staffs:SERVICE#HOSPITALITY|speakingEnglish:SERVICE#HOSPITALITY
# Overall:HOTEL#GENERAL|Staffs:SERVICE#HOSPITALITY|speakingEnglish:SERVICE#HOSPITALITY
# price|photo|place
# price|photo|place
# price:POS|photo:POS|place:NEG
# price:POS|photo:POS|place:NEG
# price:good|photo:nice|place:surroundedbywall
# price:good|photo:nice|place:surroundedbywall
# price:HOTEL#PRICE|photo:HOTEL#GENERAL|place:LOCATION#GENERAL
# price:HOTEL#PRICE|photo:HOTEL#GENERAL|place:HOTEL#GENERAL
# rate|staffs
# rate|staffs
# rate:POS|staffs:POS
# rate:POS|staffs:POS
# rate:affordable|staffs:quick
# rate:affordable|staffs:quick
# rate:HOTEL#PRICE|staffs:SERVICE#HOSPITALITY
# rate:HOTEL#PRICE|staffs:SERVICE#HOSPITALITY
# BBQdinner|staff|pool|place
# BBQdinner|staff|pool|place|ibumaydia
# BBQdinner:POS|staff:POS|pool:POS|place:POS
# BBQdinner:POS|staff:POS|pool:POS|place:POS
# BBQdinner:servedwarmly|staff:helpful|pool:enjoyed|place:nice
# BBQdinner:perfect|staff:helpful|pool:enjoyed|place:nice
# BBQdinner:FOOD#GENERAL|staff:SERVICE#HOSPITALITY|pool:FACILITY#POOL|place:HOTEL#GENERAL
# BBQdinner:FOOD#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|pool:FACILITY#POOL|place:HOTEL#GENERAL
# valueformoney|facilities|AC|cableTV|minifridge|toiletries|hotwater|staff
# valueformoney|room|AC|cableTV|minifridge|toiletries|hotwater|staff
# valueformoney:POS|facilities:POS|AC:POS|cableTV:POS|minifridge:POS|toiletries:POS|hotwater:POS|staff:POS
# valueformoney:POS|facilities:POS|AC:POS|cableTV:POS|minifridge:POS|toiletries:POS|hotwater:POS|staff:POS
# valueformoney:Great|facilities:equipped|AC:including|cableTV:including|minifridge:including|toiletries:including|hotwater:good|staff:friendly|staff:helpful
# valueformoney:Great|facilities:equipped|AC:equipped|cableTV:equipped|minifridge:equipped|toiletries:equipped|hotwater:good|staff:friendly|staff:helpful
# valueformoney:HOTEL#PRICE|facilities:FACILITY#GENERAL|AC:FACILITY#GENERAL|cableTV:FACILITY#GENERAL|minifridge:FACILITY#GENERAL|toiletries:ROOM#BATHROOM|hotwater:ROOM#BATHROOM|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# valueformoney:HOTEL#PRICE|facilities:FACILITY#GENERAL|AC:FACILITY#GENERAL|cableTV:FACILITY#GENERAL|minifridge:FACILITY#GENERAL|toiletries:ROOM#BATHROOM|hotwater:ROOM#BATHROOM|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# Pool|swim|Hotel|hotel|window|balcony|motorbikes|pool
# Poolarea|Hotel|priced|motorbikesnoise|swimmingpoolarea
# Pool:NEG|swim:NEG|Hotel:POS|Hotel:NEG|hotel:NEG|window:NEG|balcony:NEG|motorbikes:NEG|pool:NEG
# Pool:NEG|swim:NEG|Hotel:POS|hotel:NEG|window:NEG|balcony:NEG|motorbikes:NEG|pool:NEG
# Pool:small|Pool:dirty|swim:notpossible|Hotel:clean|Hotel:reform|hotel:expensive|window:noise|balcony:noise|motorbikes:noise|pool:little|pool:notsunny
# Pool:small|swim:notpossible|Hotel:clean|Hotel:needlittlereform|hotel:expensive|window:noise|balcony:noise|motorbikes:noise|pool:little|pool:notsunny
# Pool:FACILITY#POOL|Pool:FACILITY#POOL|swim:FACILITY#POOL|Hotel:HOTEL#CLEANLINESS|Hotel:HOTEL#MAINTAIN|hotel:HOTEL#PRICE|window:ROOM#EXPERIENCE|balcony:ROOM#EXPERIENCE|motorbikes:ROOM#EXPERIENCE|pool:FACILITY#POOL|pool:FACILITY#POOL
# Pool:FACILITY#POOL|swim:FACILITY#POOL|Hotel:HOTEL#CLEANLINESS|Hotel:HOTEL#PRICE|hotel:HOTEL#PRICE|window:ROOM#EXPERIENCE|balcony:ROOM#EXPERIENCE|motorbikes:ROOM#EXPERIENCE|pool:FACILITY#POOL
# bed|shower|garden|Room|notowel|pool|breakfast
# Room|bed|shower|garden|pool|breakfast
# bed:POS|shower:NEU|garden:POS|Room:POS|notowel:NEU|pool:POS|breakfast:POS
# bed:POS|shower:POS|garden:POS|Room:POS|notowel:NEG|pool:POS|breakfast:POS
# bed:comfortable|shower:hot|garden:lush|Room:big|notowel:Ok|pool:130kIDRinhighseason|breakfast:130kIDRinhighseason
# bed:comfortable|shower:hot|garden:lush|Room:big|notowel:no|pool:130kIDR|breakfast:130kIDR
# bed:ROOM#BED|shower:ROOM#BATHROOM|garden:FACILITY#GENERAL|Room:ROOM#SPACE|notowel:FACILITY#GENERAL|pool:FACILITY#POOL|breakfast:HOTEL#PRICE
# bed:ROOM#BED|shower:ROOM#BATHROOM|garden:FACILITY#GENERAL|Room:ROOM#SPACE|notowel:ROOM#BATHROOM|pool:FACILITY#POOL|breakfast:FOOD#GENERAL
# gardens|Restaurant|Rooms|Staff
# gardens|pools|Staff|Restaurant|food|Rooms
# gardens:POS|Restaurant:POS|Rooms:POS|Staff:POS
# gardens:POS|Restaurant:POS|Rooms:POS|Staff:POS
# gardens:beautiful|Restaurant:goodcuisine|Rooms:spacious|Staff:friendly|Staff:helpful
# gardens:beautiful|Restaurant:goodcuisine|Rooms:spacious|Staff:friendly|Staff:helpful|Staff:flexible
# gardens:FACILITY#GENERAL|Restaurant:FOOD#TASTE|Rooms:ROOM#SPACE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# gardens:FACILITY#GENERAL|Restaurant:FOOD#TASTE|Rooms:ROOM#SPACE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# place|fridge|iron|staff|location
# place|fridge|iron|staff|location
# place:POS|fridge:NEG|iron:NEG|staff:POS|location:POS
# place:POS|fridge:NEG|iron:NEG|staff:POS|location:POS
# place:loved|fridge:doesnthave|iron:doesnthave|staff:friendly|location:perfect
# place:loved|fridge:doesnthave|iron:doesnthave|staff:Fabulous|location:perfect
# place:LOCATION#GENERAL|fridge:ROOM#FACILITY|iron:ROOM#FACILITY|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL
# place:HOTEL#EXPERIENCE|fridge:FACILITY#GENERAL|iron:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL
# hotel|staff|facilities|Room
# hotel|staff|facilities|checkingin|out|Room
# hotel:POS|staff:POS|facilities:POS|Room:POS
# hotel:POS|staff:POS|facilities:POS|Room:POS
# hotel:Excellent|staff:Excellent|facilities:Excellent|Room:clean|facilities:excellent
# hotel:Excellent|staff:Excellent|facilities:Excellent|Room:clean|facilities:excellent
# hotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|facilities:FACILITY#GENERAL|Room:ROOM#CLEANLINESS|facilities:FACILITY#GENERAL
# hotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|facilities:FACILITY#GENERAL|Room:ROOM#CLEANLINESS|facilities:FACILITY#GENERAL
# valueformoney|breakfast|tea|coffee|stay
# valueformoney|roomsize|breakfast|friendlliness|service
# valueformoney:POS|breakfast:NEG|tea:NEG|coffee:NEG|stay:POS
# valueformoney:POS|breakfast:NEG|tea:NEG|coffee:NEG|stay:POS
# valueformoney:handsdown|breakfast:limited|tea:no|coffee:no|stay:great
# valueformoney:handsdown|breakfast:limited|tea:no|coffee:no|stay:great
# valueformoney:HOTEL#PRICE|breakfast:FOOD#CHOICE|tea:SERVICE#GENERAL|coffee:SERVICE#GENERAL|stay:HOTEL#EXPERIENCE
# valueformoney:HOTEL#PRICE|breakfast:FOOD#CHOICE|tea:FACILITY#GENERAL|coffee:FACILITY#GENERAL|stay:HOTEL#EXPERIENCE|service:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE
# service|food|airport|experience|rooms|beds|sofa
# experience|rooms|beds|sofa|loacation|food|service
# service:NEU|food:NEU|airport:POS|experience:POS|rooms:POS|beds:POS|sofa:POS
# service:NEU|food:NEU|airport:POS|experience:POS|rooms:POS|beds:POS|sofa:POS
# service:selfservice|food:boththechoice|airport:near|experience:nice|rooms:amazing|beds:large|sofa:large
# service:selfservice|food:veg|airport:near|experience:nice|rooms:amazing|beds:large|sofa:large
# service:SERVICE#GENERAL|food:FOOD#CHOICE|airport:LOCATION#TRANSPORT_HUB|experience:HOTEL#EXPERIENCE|rooms:ROOM#GENERAL|beds:ROOM#BED|sofa:ROOM#FACILITY
# service:SERVICE#GENERAL|food:FOOD#CHOICE|airport:LOCATION#TRANSPORT_HUB|experience:HOTEL#EXPERIENCE|rooms:ROOM#GENERAL|beds:ROOM#BED|sofa:ROOM#BED
# breakfast|place|wifi|fridge|Aircon|generally|everything|staff
# staff|aircon|rooms|fridge|wifi|place|breakfast|price
# breakfast:POS|place:POS|wifi:POS|fridge:POS|Aircon:POS|generally:POS|everything:POS|staff:POS
# breakfast:NEG|place:POS|wifi:POS|fridge:POS|Aircon:POS|generally:POS|everything:POS|staff:POS
# breakfast:cheap|place:Great|wifi:worked|fridge:worked|Aircon:inrooms|generally:tidy|everything:central|staff:Welcoming
# breakfast:cheap|place:Great|wifi:workedwell|fridge:workedwell|Aircon:workedwell|generally:tidy|everything:central|staff:Welcoming
# breakfast:FOOD#PRICE|place:HOTEL#GENERAL|wifi:FACILITY#WIFI|fridge:FACILITY#GENERAL|Aircon:FACILITY#GENERAL|generally:ROOM#CLEANLINESS|everything:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY
# breakfast:FOOD#PRICE|place:HOTEL#GENERAL|place:HOTEL#CLEANLINESS|place:HOTEL#CLEANLINESS|wifi:FACILITY#WIFI|fridge:FACILITY#GENERAL|Aircon:FACILITY#GENERAL|Aircon:FACILITY#GENERAL|generally:HOTEL#CLEANLINESS|everything:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY
# Kutabeach|Rooms|Bathroom|Stafff|food|Room318
# Kutabeach|Rooms|Bathroom|Swimmingpool|food|Stafff
# Kutabeach:POS|Rooms:POS|Bathroom:POS|Stafff:POS|food:POS|Room318:POS
# Kutabeach:POS|Rooms:NEU|Rooms:POS|Bathroom:POS|Stafff:POS|food:POS|Room318:POS
# Kutabeach:3minwalk|Rooms:simple|Rooms:clean|Bathroom:walkinnshower|Stafff:friendly|food:nice|Room318:quiet
# Kutabeach:3minwalk|Rooms:simple|Rooms:clean|Bathroom:walkinnshower|Stafff:friendly|food:nice|Room318:quiet
# Kutabeach:LOCATION#ATTRACTIONS|Rooms:HOTEL#GENERAL|Rooms:ROOM#CLEANLINESS|Bathroom:ROOM#BATHROOM|Stafff:SERVICE#HOSPITALITY|food:FOOD#TASTE|Room318:ROOM#AMBIENCE
# Kutabeach:LOCATION#ATTRACTIONS|Rooms:ROOM#GENERAL|Rooms:ROOM#CLEANLINESS|Bathroom:ROOM#BATHROOM|Stafff:SERVICE#HOSPITALITY|food:FOOD#TASTE|Room318:ROOM#EXPERIENCE
# location|pool|breakfast|staff|Rooms|start
# location|pool|breakfast|staff|Rooms|start
# location:POS|pool:POS|breakfast:POS|staff:POS|Rooms:NEU|Rooms:POS|start:POS
# location:POS|pool:POS|breakfast:POS|staff:POS|Rooms:NEG|start:POS
# location:Cool|pool:nice|breakfast:free|staff:nice|Rooms:olderstyle|Rooms:beachfront|start:great
# location:Cool|pool:nice|breakfast:free|staff:nice|Rooms:olderstyle|start:great
# location:LOCATION#GENERAL|pool:FACILITY#POOL|breakfast:FOOD#PRICE|staff:SERVICE#HOSPITALITY|Rooms:ROOM#AMBIENCE|Rooms:ROOM#VIEW|start:HOTEL#GENERAL
# location:LOCATION#GENERAL|pool:FACILITY#POOL|breakfast:FOOD#GENERAL|staff:SERVICE#HOSPITALITY|Rooms:ROOM#AMBIENCE|Rooms:ROOM#AMBIENCE|start:HOTEL#EXPERIENCE
# hotel|service|internet|place|mahimahifishdish|massage
# hotel|service|internet|place
# hotel:POS|service:POS|internet:NEG|place:POS|mahimahifishdish:POS|massage:POS
# hotel:POS|service:POS|internet:NEG|place:POS|mahimahifishdish:POS|massage:POS
# hotel:lovely|service:excellent|service:veryclean|internet:wasntparticularlygreat|place:excellet|mahimahifishdish:recommend|massage:recommend
# hotel:lovely|service:excellent|internet:wasntparticularlygreat|place:excellet|mahimahifishdish:recommend|massage:recommend
# hotel:HOTEL#GENERAL|service:SERVICE#GENERAL|service:SERVICE#GENERAL|internet:FACILITY#WIFI|place:LOCATION#GENERAL|mahimahifishdish:FOOD#TASTE|massage:FACILITY#EXPERIENCE
# hotel:HOTEL#GENERAL|service:SERVICE#GENERAL|service:SERVICE#GENERAL|internet:FACILITY#WIFI|place:HOTEL#GENERAL|mahimahifishdish:FOOD#TASTE|massage:FACILITY#EXPERIENCE
# pool|Rooms|beach
# pool|staff|Rooms|privatebeach
# pool:POS|Rooms:POS|beach:POS
# pool:POS|Rooms:POS|beach:POS
# pool:wins|Rooms:great|beach:beautiful
# pool:wins|Rooms:great|beach:quiet
# pool:FACILITY#POOL|Rooms:ROOM#GENERAL|beach:LOCATION#ATTRACTIONS
# pool:FACILITY#POOL|Rooms:ROOM#GENERAL|beach:LOCATION#ATTRACTIONS
# money|located
# money|located
# money:POS|located:POS
# money:POS|located:POS
# money:value|located:well
# money:value|located:well
# money:HOTEL#PRICE|located:LOCATION#GENERAL
# money:HOTEL#PRICE|located:LOCATION#GENERAL
# hotelroom|bed|breakfast
# hotelroom|bed|swimmingpool|room'sbathroom|breakfastquality
# hotelroom:POS|bed:POS|breakfast:NEU
# hotelroom:POS|bed:POS|breakfast:NEU
# hotelroom:stylish|bed:good|breakfast:basic
# hotelroom:stylish|bed:good|breakfast:basic
# hotelroom:ROOM#AMBIENCE|bed:ROOM#BED|breakfast:FOOD#TASTE
# hotelroom:ROOM#AMBIENCE|bed:ROOM#BED|breakfast:FOOD#TASTE
# Nive|location|staff
# moneyexchange|moneyexchange
# Nive:POS|location:POS|staff:POS
# Nive:POS|location:POS|staff:POS
# Nive:buffetbreakfast|location:good|staff:nice
# Nive:buffetbreakfast|location:good|staff:nice
# Nive:FOOD#GENERAL|location:LOCATION#GENERAL|staff:SERVICE#GENERAL
# Nive:FOOD#GENERAL|location:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY|Nive:FOOD#GENERAL
# shoppingcenter|airport|location
# location
# shoppingcenter:POS|airport:POS|location:POS
# shoppingcenter:POS|airport:POS|location:POS
# shoppingcenter:near|airport:near|location:strategic
# shoppingcenter:near|airport:near|location:strategic
# shoppingcenter:LOCATION#NEARBY_AMENITIES|airport:LOCATION#TRANSPORT_HUB|location:LOCATION#GENERAL
# shoppingcenter:LOCATION#NEARBY_AMENITIES|airport:LOCATION#TRANSPORT_HUB|location:LOCATION#GENERAL
# this|hotel|needes
# hotel
# this:POS|hotel:POS|needes:POS
# this:POS|hotel:POS|needes:POS
# this:nice|hotel:clean|needes:provided
# this:nice|hotel:clean|needes:provided
# this:HOTEL#GENERAL|hotel:HOTEL#CLEANLINESS|needes:SERVICE#AMENITIES
# this:HOTEL#GENERAL|hotel:HOTEL#CLEANLINESS|hotel:HOTEL#CLEANLINESS|needes:HOTEL#GENERAL
# breakfast|valueformoney|questions|staff
# communication|money|staff|taxis|breakfast
# breakfast:POS|valueformoney:POS|questions:POS|staff:POS
# breakfast:POS|valueformoney:POS|questions:POS|staff:POS
# breakfast:varietyofoptions|valueformoney:good|questions:helped|staff:friendly|staff:helpful
# breakfast:varietyofoptions|valueformoney:good|questions:helped|staff:friendly
# breakfast:FOOD#CHOICE|valueformoney:HOTEL#PRICE|questions:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# breakfast:FOOD#CHOICE|valueformoney:HOTEL#PRICE|questions:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# breakfast|location
# location|goodthings|breakfast
# breakfast:NEG|location:POS
# breakfast:NEG|location:POS
# breakfast:terrible|location:good
# breakfast:terrible|location:good
# breakfast:FOOD#TASTE|location:LOCATION#GENERAL
# breakfast:FOOD#GENERAL|location:LOCATION#GENERAL
# rooms|poolsideview|place
# rooms|poolsideview|place
# rooms:NEG|poolsideview:POS|place:NEU
# rooms:NEG|poolsideview:POS|place:POS
# rooms:depressing|poolsideview:enjoy|rooms:belowground|rooms:havenowindows|place:OK
# rooms:depressing|rooms:belowground|rooms:havenowindows|poolsideview:enjoy|place:OK
# rooms:HOTEL#EXPERIENCE|poolsideview:ROOM#VIEW|rooms:HOTEL#AMBIENCE|rooms:ROOM#WINDOW|place:HOTEL#GENERAL
# rooms:ROOM#GENERAL|rooms:ROOM#WINDOW|poolsideview:LOCATION#VIEW|place:HOTEL#GENERAL
# place|staff|breakfast
# place|staff|location|breakfast
# place:POS|staff:POS|breakfast:NEU
# place:POS|staff:POS|breakfast:NEU
# place:clean|place:comfortable|place:quiet|place:safe|staff:helping|breakfast:average|place:recommended
# place:clean|place:comfortable|place:quiet|place:safe|staff:helping|breakfast:average
# place:HOTEL#CLEANLINESS|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|breakfast:FOOD#TASTE|place:HOTEL#GENERAL
# place:HOTEL#CLEANLINESS|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EXPERIENCE|place:HOTEL#EX
# Located|room|hotel
# room|hotel
# Located:POS|room:POS|hotel:POS
# Located:POS|room:POS|hotel:POS
# Located:intheheartoftourismactivities|room:clean|room:good|hotel:Recomendeedforbackpackers.
# Located:intheheartoftourismactivities|room:clean|room:good|hotel:Recomendeed
# Located:LOCATION#CENTRAL_CITY|room:ROOM#CLEANLINESS|room:ROOM#GENERAL|hotel:HOTEL#EXPERIENCE
# Located:LOCATION#TRANSPORT_HUB|room:ROOM#CLEANLINESS|room:ROOM#GENERAL|hotel:HOTEL#GENERAL
# pool|staff|bathrooms|internet
# pool|staff|cleaning|roomservice|rooms|bathrooms|internet
# pool:POS|staff:POS|bathrooms:POS|internet:NEG
# pool:POS|staff:POS|bathrooms:POS|internet:NEG
# pool:amazing|staff:friendly|bathrooms:good|internet:inconsistent
# pool:amazing|staff:friendly|bathrooms:good|internet:inconsistent
# pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|bathrooms:ROOM#BATHROOM|internet:FACILITY#WIFI
# pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|bathrooms:ROOM#BATHROOM|internet:FACILITY#WIFI
# breakfast|staff|spot|Chef
# breakfast|freeactivities|staff|spot
# breakfast:POS|staff:POS|spot:POS|Chef:POS
# breakfast:POS|staff:POS|spot:POS|Chef:POS
# breakfast:great|staff:friendly|spot:Fabulous|Chef:thanks
# breakfast:great|staff:friendly|spot:Fabulous|Chef:Thanks
# breakfast:FOOD#TASTE|staff:SERVICE#HOSPITALITY|spot:LOCATION#GENERAL|Chef:SERVICE#GENERAL
# breakfast:FOOD#TASTE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|spot:LOCATION#GENERAL|Chef:SERVICE#HOSPITALITY
# Check|room|staffs|Location|interestingareas|Foods|coffeemachine
# Checkin|room|staffs|Location|Foods|coffeemachine
# Check:POS|room:POS|staffs:POS|Location:POS|interestingareas:POS|Foods:NEU|coffeemachine:NEG
# Check:POS|room:POS|staffs:POS|Location:POS|interestingareas:POS|Foods:NEU|coffeemachine:NEG
# Check:efficient|Check:comfort|room:clean|staffs:welcoming|Location:strategic|interestingareas:close|interestingareas:walkingrange|Foods:ok|coffeemachine:disappointed
# Check:efficient|Check:comfort|room:clean|staffs:welcoming|Location:strategic|interestingareas:close|Foods:ok|coffeemachine:disappointed
# Check:SERVICE#HOSPITALITY|Check:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|staffs:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|interestingareas:LOCATION#ATTRACTIONS|interestingareas:LOCATION#ATTRACTIONS|Foods:FOOD#TASTE|coffeemachine:FACILITY#GENERAL
# Check:SERVICE#GENERAL|Check:SERVICE#GENERAL|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|staffs:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|interestingareas:LOCATION#ATTRACTIONS|Foods:FOOD#TASTE|coffeemachine:FOOD#TASTE
# pool|breakfast|service|staff
# poolambience|breakfast|staff|service
# pool:POS|breakfast:POS|service:POS|staff:POS
# pool:POS|breakfast:POS|service:POS|staff:POS
# pool:Amazing|breakfast:fantasticspread|service:nice|staff:nice
# pool:Amazing|breakfast:fantasticspread|service:nice|staff:nice
# pool:FACILITY#POOL|breakfast:FOOD#GENERAL|service:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# pool:FACILITY#POOL|breakfast:FOOD#GENERAL|service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY
# ibis|bars|beach|tourists|Breakfast|Other|IbisStyles|breakfast
# ibis|bars|beach|IbisStyles|Breakfast
# ibis:POS|bars:POS|beach:POS|tourists:NEU|Breakfast:NEU|Other:POS|IbisStyles:NEG|breakfast:POS
# ibis:POS|bars:POS|beach:POS|tourists:POS|Breakfast:NEG|Other:POS|IbisStyles:POS|breakfast:POS
# ibis:ok|bars:nearby|beach:nearby|tourists:hugecrowds|Breakfast:mightbecharged|Other:ok|IbisStyles:better-morestylish|breakfast:free
# ibis:ok|bars:nearby|beach:nearby|tourists:don'treallymind|Breakfast:charged|Other:ok|IbisStyles:better-morestylish|breakfast:free
# ibis:HOTEL#GENERAL|bars:LOCATION#ENTERTAINMENT|beach:LOCATION#NEARBY_AMENITIES|tourists:LOCATION#GENERAL|Breakfast:HOTEL#PRICE|Other:HOTEL#GENERAL|IbisStyles:HOTEL#AMBIENCE|breakfast:FOOD#PRICE
# ibis:HOTEL#GENERAL|bars:LOCATION#ENTERTAINMENT|beach:LOCATION#ATTRACTIONS|tourists:LOCATION#ENTERTAINMENT|Breakfast:FOOD#PRICE|Other:HOTEL#GENERAL|IbisStyles:HOTEL#AMBIENCE|breakfast:FOOD#PRICE
# design|hotel|wifi|showercap|breakfast
# design|wifi|breakfast|management
# design:POS|hotel:POS|wifi:NEG|showercap:NEG|breakfast:NEG
# design:POS|hotel:POS|wifi:NEG|showercap:NEG|breakfast:NEG
# design:good|hotel:budget|wifi:poor|showercap:didn'thave|breakfast:notinclude
# design:good|hotel:budget|wifi:poor|showercap:didn'thave|breakfast:notinclude
# design:ROOM#GENERAL|hotel:HOTEL#PRICE|wifi:FACILITY#WIFI|showercap:ROOM#BATHROOM|breakfast:FOOD#GENERAL
# design:HOTEL#AMBIENCE|hotel:HOTEL#PRICE|wifi:FACILITY#WIFI|showercap:ROOM#BATHROOM|breakfast:FOOD#PRICE
# previousvisitors|cleanliness|Pool
# Hotel|wall|Igarettes|Pool
# previousvisitors:NEG|cleanliness:NEG|Pool:NEG
# previousvisitors:NEG|cleanliness:NEG|Pool:NEG
# previousvisitors:vomit|cleanliness:poor|Pool:renovation
# previousvisitors:vomit|cleanliness:poor|Pool:needssomeseriousrenovation
# previousvisitors:HOTEL#EXPERIENCE|cleanliness:HOTEL#CLEANLINESS|Pool:FACILITY#POOL
# previousvisitors:SERVICE#HOSPITALITY|cleanliness:HOTEL#CLEANLINESS|Pool:FACILITY#POOL
# stay|service|Manager|location|room|pool
# service|Manager|location|room|pool
# stay:POS|service:POS|Manager:POS|location:POS|room:POS|pool:POS
# stay:POS|service:POS|Manager:POS|location:POS|room:POS|pool:POS
# stay:like|service:excellent|Manager:Kindfull|Manager:responsible|location:good|room:havegarden|pool:near
# stay:like|service:excellent|Manager:Kindfull|Manager:responsible|location:good|room:havegarden|pool:near
# stay:HOTEL#EXPERIENCE|service:SERVICE#GENERAL|Manager:SERVICE#HOSPITALITY|Manager:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|room:ROOM#FACILITY|pool:FACILITY#POOL
# stay:HOTEL#EXPERIENCE|service:SERVICE#GENERAL|Manager:SERVICE#HOSPITALITY|Manager:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|room:ROOM#FACILITY|pool:FACILITY#POOL
# staff|towels|sheets|airconditioner
# staff|towels|bathroom|sheets|airconditioner
# staff:POS|towels:NEG|sheets:NEG|airconditioner:NEG
# staff:POS|towels:NEG|sheets:NEG|airconditioner:NEG
# staff:friendly|towels:small|towels:stained|sheets:notchanged|airconditioner:sohot
# staff:friendly|towels:small|towels:stained|sheets:notchanged|airconditioner:setto24
# staff:SERVICE#HOSPITALITY|towels:ROOM#BATHROOM|towels:ROOM#BATHROOM|sheets:ROOM#BED|airconditioner:ROOM#AIRCON
# staff:SERVICE#HOSPITALITY|towels:ROOM#BATHROOM|towels:ROOM#BATHROOM|sheets:ROOM#BED|airconditioner:ROOM#AIRCON
# calledbyrestaurant
# cellularreception
# calledbyrestaurant:NEG
# calledbyrestaurant:NEG
# calledbyrestaurant:Dontlike
# calledbyrestaurant:Dontlike
# calledbyrestaurant:FOOD#GENERAL
# calledbyrestaurant:SERVICE#HOSPITALITY
# Room|breakfast|stay|roomattendant|thishotel
# Room|breakfast|Staff|roomattendant
# Room:POS|breakfast:POS|stay:POS|roomattendant:POS|thishotel:POS
# Room:POS|breakfast:POS|stay:POS|roomattendant:POS|thishotel:POS
# Room:clean|breakfast:good|stay:enjoyable|roomattendant:friendly|roomattendant:helpful|thishotel:recommend
# Room:clean|breakfast:good|stay:enjoyable|roomattendant:friendly|roomattendant:helpful|thishotel:recommend
# Room:ROOM#CLEANLINESS|breakfast:FOOD#GENERAL|stay:HOTEL#EXPERIENCE|roomattendant:SERVICE#HOSPITALITY|roomattendant:SERVICE#ASSISTANCE|thishotel:HOTEL#EXPERIENCE
# Room:ROOM#CLEANLINESS|breakfast:FOOD#TASTE|stay:HOTEL#EXPERIENCE|roomattendant:SERVICE#HOSPITALITY|roomattendant:SERVICE#HOSPITALITY|thishotel:HOTEL#GENERAL
# rooms|room
# rooms|room|noiseisolation
# rooms:NEG|room:NEG
# rooms:NEG|room:NEG
# rooms:Tired|rooms:haventhadrenovation|room:didntfeelclean
# rooms:Tired|rooms:haventhadrenovation|room:didntfeelclean|room:noiseisolation
# rooms:ROOM#AMBIENCE|rooms:ROOM#MAINTAIN|room:ROOM#EXPERIENCE
# rooms:ROOM#GENERAL|rooms:ROOM#CLEANLINESS|room:ROOM#EXPERIENCE
# staff|position|waterfromthetaps|buffetbreakfast|water|hotwater
# staff|position|waterfromthetaps|buffetbreakfast|water
# staff:POS|position:POS|waterfromthetaps:NEG|buffetbreakfast:NEG|water:NEG|hotwater:NEG
# staff:POS|position:POS|waterfromthetaps:NEG|buffetbreakfast:NEU|buffetbreakfast:NEG|water:NEG|hotwater:NEG
# staff:wonderful|position:great|waterfromthetaps:saltwaterfromtheocean|buffetbreakfast:ordinary|buffetbreakfast:samethingeveryday|water:undrinkableevenafterboiling|hotwater:notrectifieduntilthenextday
# staff:wonderful|position:great|waterfromthetaps:saltwater|buffetbreakfast:ordinary|buffetbreakfast:thesamethingeveryday|buffetbreakfast:boring|water:undrinkable|hotwater:notrectified
# staff:SERVICE#HOSPITALITY|position:LOCATION#GENERAL|waterfromthetaps:ROOM#AMBIENCE|buffetbreakfast:FOOD#CHOICE|buffetbreakfast:FOOD#CHOICE|water:ROOM#AMBIENCE|hotwater:ROOM#AMENITIES
# staff:SERVICE#HOSPITALITY|position:LOCATION#GENERAL|waterfromthetaps:ROOM#BATHROOM|buffetbreakfast:FOOD#CHOICE|buffetbreakfast:FOOD#CHOICE|water:ROOM#BATHROOM|hotwater:ROOM#BATHROOM
# service|staff|breakfast|facilities|shuttle|galeria
# service|staff|breakfast|facilities
# service:POS|staff:POS|breakfast:POS|facilities:POS|shuttle:POS|galeria:POS
# service:POS|staff:POS|breakfast:POS|facilities:POS|shuttle:POS|galeria:POS
# service:satisfied|staff:Friendly|breakfast:delicious|facilities:complete|shuttle:free|galeria:near
# service:satisfied|staff:Friendly|breakfast:delicious|facilities:complete|shuttle:free|galeria:near
# service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY|breakfast:FOOD#TASTE|facilities:FACILITY#GENERAL|shuttle:SERVICE#ASSISTANCE|galeria:LOCATION#ATTRACTIONS
# service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY|breakfast:FOOD#TASTE|facilities:FACILITY#GENERAL|shuttle:SERVICE#ASSISTANCE|galeria:LOCATION#ATTRACTIONS
# bathroomcleanliness|badcovercleanliness
# bathroomcleanliness|covercleanliness
# bathroomcleanliness:NEG|badcovercleanliness:NEG
# bathroomcleanliness:NEG|badcovercleanliness:NEG
# bathroomcleanliness:poor|badcovercleanliness:poor
# bathroomcleanliness:poor|badcovercleanliness:poor
# bathroomcleanliness:ROOM#CLEANLINESS|badcovercleanliness:ROOM#CLEANLINESS
# bathroomcleanliness:ROOM#CLEANLINESS|badcovercleanliness:ROOM#CLEANLINESS
# rooms|Location|airport|beach|shoppingcentre|Breakfast|staff
# hotel|rooms|Location|airport|beach|shoppingcentre|Breakfast|staff|service
# rooms:POS|Location:POS|airport:POS|beach:POS|shoppingcentre:POS|Breakfast:POS|staff:POS
# rooms:POS|Location:POS|airport:POS|beach:POS|shoppingcentre:POS|Breakfast:POS|staff:POS
# rooms:new|Location:perfect|airport:close|beach:close|shoppingcentre:close|Breakfast:good|staff:friendly
# rooms:new|Location:perfect|airport:close|beach:close|shoppingcentre:close|Breakfast:good|staff:friendly
# rooms:ROOM#AMBIENCE|Location:LOCATION#GENERAL|airport:LOCATION#TRANSPORT_HUB|beach:LOCATION#ATTRACTIONS|shoppingcentre:LOCATION#NEARBY_AMENITIES|Breakfast:FOOD#TASTE|staff:SERVICE#HOSPITALITY
# rooms:ROOM#AMBIENCE|Location:LOCATION#GENERAL|airport:LOCATION#TRANSPORT_HUB|beach:LOCATION#ATTRACTIONS|shoppingcentre:LOCATION#NEARBY_AMENITIES|Breakfast:FOOD#TASTE|staff:SERVICE#HOSPITALITY
# bathroom|wall|hallway|stay|feels
# bathroom|wall|hotels|deal
# bathroom:NEG|wall:NEG|hallway:NEG|stay:NEG|feels:NEG
# bathroom:NEG|wall:NEG|hallway:NEG|stay:NEG|feels:NEG
# bathroom:smells|wall:faecessmeared|hallway:faecessmeared|stay:mistake|feels:gross
# bathroom:smells|wall:faecessmeared|hallway:faecessmeared|stay:mistake|feels:gross
# bathroom:ROOM#BATHROOM|wall:HOTEL#CLEANLINESS|hallway:HOTEL#CLEANLINESS|stay:HOTEL#EXPERIENCE|feels:HOTEL#EXPERIENCE
# bathroom:ROOM#CLEANLINESS|wall:ROOM#CLEANLINESS|hallway:ROOM#CLEANLINESS|stay:HOTEL#EXPERIENCE|feels:HOTEL#EXPERIENCE
# placetostay|hotel|shops
# place|shops|hotwater|coveredwalkway
# placetostay:POS|hotel:POS|shops:NEG
# placetostay:POS|hotel:POS|shops:NEG
# placetostay:nice|hotel:Idon'tmindreturning|shops:Notmany
# placetostay:nice|hotel:don'tmindreturning|shops:Notmany
# placetostay:HOTEL#EXPERIENCE|hotel:HOTEL#EXPERIENCE|shops:LOCATION#NEARBY_AMENITIES
# placetostay:HOTEL#EXPERIENCE|hotel:HOTEL#GENERAL|shops:LOCATION#NEARBY_AMENITIES
# Hotel|staf|foodintheresturant|breakefast|placesdowntheroad|everythingelse
# Hotel|staf|food|breakefast|places
# Hotel:POS|staf:POS|foodintheresturant:NEG|breakefast:NEG|placesdowntheroad:POS|everythingelse:POS
# Hotel:POS|staf:POS|foodintheresturant:NEG|breakefast:NEG|placesdowntheroad:POS|everythingelse:POS
# Hotel:comfortable|Hotel:nice|staf:helpful|staf:Nice|foodintheresturant:disapointing|breakefast:disapointing|placesdowntheroad:good|everythingelse:good
# Hotel:nice|Hotel:comfortable|staf:Nice|staf:helpful|foodintheresturant:Don'teat|breakefast:Don'teat|placesdowntheroad:good|everythingelse:good
# Hotel:HOTEL#EXPERIENCE|Hotel:HOTEL#GENERAL|staf:SERVICE#HOSPITALITY|staf:SERVICE#HOSPITALITY|foodintheresturant:FOOD#TASTE|breakefast:FOOD#TASTE|placesdowntheroad:LOCATION#ENTERTAINMENT|everythingelse:HOTEL#GENERAL
# Hotel:HOTEL#EXPERIENCE|Hotel:HOTEL#EXPERIENCE|staf:SERVICE#HOSPITALITY|staf:SERVICE#HOSPITALITY|foodintheresturant:FOOD#GENERAL|breakefast:FOOD#GENERAL|placesdowntheroad:LOCATION#GENERAL|everythingelse:HOTEL#GENERAL
# breakfast|place|photos|room|bathroom
# room|bathroom|kingbed|place|breakfast
# breakfast:POS|place:POS|photos:NEG|room:POS|bathroom:NEG|room:NEG
# breakfast:POS|place:POS|photos:NEG|room:NEG|bathroom:NEG
# breakfast:tasty|place:clean|photos:taken15yearsago|room:anythingwrong|bathroom:old|room:old
# breakfast:tasty|place:clean|photos:taken15yearsago|room:old|bathroom:old
# breakfast:FOOD#TASTE|place:HOTEL#CLEANLINESS|photos:HOTEL#GENERAL|room:ROOM#GENERAL|bathroom:ROOM#BATHROOM|room:ROOM#GENERAL
# breakfast:FOOD#TASTE|place:HOTEL#CLEANLINESS|photos:HOTEL#AMBIENCE|room:ROOM#AMBIENCE|room:ROOM#MAINTAIN|bathroom:ROOM#BATHROOM
# electricwater|bathroom|bed
# electricwaterboiler|bathroom|bed
# electricwater:POS|bathroom:NEG|bed:POS|bathroom:POS
# electricwater:POS|bathroom:NEG|bed:POS
# electricwater:availability|bathroom:small|bed:comfortable|bathroom:functional
# electricwater:available|bathroom:small|bathroom:functional|bed:comfortable
# electricwater:FACILITY#GENERAL|bathroom:ROOM#BATHROOM|bed:ROOM#BED|bathroom:ROOM#BATHROOM
# electricwater:FACILITY#GENERAL|bathroom:ROOM#BATHROOM|bathroom:ROOM#BATHROOM|bed:ROOM#BED
# hotel|price|Room
# hotel|price|staff|security|Room|connectingdoor
# hotel:POS|price:POS|Room:POS|Room:NEG
# hotel:POS|price:POS|Room:POS|Room:NEG
# hotel:fancy|price:affordable|Room:nice|Room:clean|Room:noisyfromnextdoor
# hotel:newfancy|price:affordable|Room:nice|Room:clean|Room:noisy
# hotel:HOTEL#AMBIENCE|price:HOTEL#PRICE|Room:ROOM#GENERAL|Room:ROOM#CLEANLINESS|Room:ROOM#AMBIENCE
# hotel:HOTEL#AMBIENCE|price:HOTEL#PRICE|Room:ROOM#GENERAL|Room:ROOM#CLEANLINESS|Room:ROOM#EXPERIENCE
# hotel|staff|mystay
# hotel|staff|stay
# hotel:POS|staff:POS|mystay:POS
# hotel:POS|staff:POS|mystay:POS
# hotel:wellinsulated|hotel:quiet|staff:helpful|mystay:perfect
# hotel:quiet|hotel:wellinsulated|staff:helpful|mystay:perfect
# hotel:HOTEL#GENERAL|hotel:HOTEL#AMBIENCE|staff:SERVICE#HOSPITALITY|mystay:HOTEL#EXPERIENCE
# hotel:HOTEL#EXPERIENCE|hotel:HOTEL#EXPERIENCE|hotel:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|mystay:HOTEL#EXPERIENCE
# Room|bed
# Room|money|aircon|safe|bed
# Room:POS|bed:POS
# Room:POS|bed:POS
# Room:great|Room:safeweregreat|bed:bigcomfy
# Room:great|Room:bestmoneyspentaircon|safe:great|bed:bigcomfy
# Room:ROOM#GENERAL|Room:ROOM#AMENITIES|bed:ROOM#BED
# Room:ROOM#GENERAL|Room:ROOM#AIRCON|Room:ROOM#EXPERIENCE|bed:ROOM#BED
# parking|rooms|Staff
# parking|rooms|Staff
# parking:NEG|rooms:POS|Staff:POS
# parking:NEG|rooms:POS|rooms:POS|Staff:POS
# parking:limited|rooms:nice|rooms:simple|rooms:functional|rooms:comfortable|Staff:friendly|Staff:helpful
# parking:limited|rooms:nice|rooms:simple|rooms:functional|rooms:comfortable|Staff:friendly|Staff:helpful
# parking:FACILITY#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#EXPERIENCE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# parking:FACILITY#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#EXPERIENCE|rooms:ROOM#EXPERIENCE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# experience|room|pool|staff
# experience|room|loodpool|staff|breakfast|Marsmallowparty
# experience:POS|room:POS|pool:POS|staff:POS
# experience:POS|room:POS|pool:POS|staff:POS
# experience:great|room:clean|pool:warm|staff:friendly
# experience:great|room:clean|room:comfort|pool:warm|staff:helpful|staff:friendly
# experience:HOTEL#EXPERIENCE|room:ROOM#CLEANLINESS|pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY
# experience:HOTEL#EXPERIENCE|room:ROOM#CLEANLINESS|room:ROOM#EXPERIENCE|pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# hotelroom|staff|friendly|food|breakfast
# hotelroom|staff|food
# hotelroom:POS|staff:POS|friendly:POS|food:NEG|breakfast:NEG
# hotelroom:POS|staff:POS|friendly:POS|food:NEG|breakfast:NEG
# hotelroom:nice|hotelroom:tidy|staff:helpful|friendly:She|staff:friendly|food:needtobeimprove|breakfast:time
# hotelroom:nice|hotelroom:tidy|staff:helpful|friendly:She|food:needtobeimprove|breakfast:time
# hotelroom:ROOM#GENERAL|hotelroom:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|friendly:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|food:FOOD#GENERAL|breakfast:HOTEL#GENERAL
# hotelroom:ROOM#GENERAL|hotelroom:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|friendly:SERVICE#HOSPITALITY|food:FOOD#GENERAL|breakfast:FOOD#GENERAL
# hotel|shower|rubbermats|Location|service
# hotel|showerfloors|Location|service
# hotel:POS|shower:NEG|rubbermats:NEG|Location:POS|service:POS
# hotel:POS|shower:NEG|rubbermats:NEG|Location:POS|service:POS
# hotel:love|shower:slippery|rubbermats:need|Location:great|service:great
# hotel:love|shower:slippery|rubbermats:need|Location:great|service:great
# hotel:HOTEL#GENERAL|shower:ROOM#BATHROOM|rubbermats:ROOM#BATHROOM|Location:LOCATION#GENERAL|service:SERVICE#GENERAL
# hotel:HOTEL#GENERAL|shower:ROOM#BATHROOM|rubbermats:ROOM#BATHROOM|Location:LOCATION#GENERAL|service:SERVICE#GENERAL
# place|views|service|rooms|smallwaters
# place|views|service|rooms
# place:POS|views:POS|service:POS|rooms:POS|smallwaters:NEG
# place:POS|views:POS|service:POS|rooms:POS|smallwaters:NEG
# place:Great|views:great|service:good|rooms:clean|smallwaters:minus
# place:Great|views:great|service:good|rooms:clean|smallwaters:minus
# place:HOTEL#GENERAL|views:LOCATION#VIEW|service:SERVICE#GENERAL|rooms:ROOM#CLEANLINESS|smallwaters:ROOM#CLEANLINESS
# place:HOTEL#GENERAL|views:LOCATION#VIEW|service:SERVICE#GENERAL|rooms:ROOM#CLEANLINESS|smallwaters:ROOM#CLEANLINESS
# room|lounge|it|Staff
# room|lounge|Staff
# room:POS|lounge:NEG|it:NEG|Staff:POS
# room:POS|lounge:NEG|it:NEG|Staff:POS
# room:clean|lounge:old|lounge:worn|it:holes|lounge:holes|Staff:friendly|Staff:helpful
# room:clean|lounge:old|lounge:worn|it:holes|Lounge:holes|Staff:friendly|Staff:helpful
# room:ROOM#CLEANLINESS|lounge:HOTEL#MAINTAIN|lounge:HOTEL#MAINTAIN|it:HOTEL#MAINTAIN|lounge:HOTEL#MAINTAIN|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# room:ROOM#CLEANLINESS|lounge:ROOM#FACILITY|lounge:ROOM#FACILITY|it:ROOM#FACILITY|lounge:ROOM#FACILITY|it:ROOM#FACILITY|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY
# location|Rooms
# location|Rooms|windows|view
# location:POS|Rooms:NEU|Rooms:NEG
# location:POS|Rooms:NEG
# location:Best|Rooms:ok|Rooms:wouldntgothereagain|Rooms:noneview
# location:Best|Rooms:ok|Rooms:nowindows|Rooms:noneview
# location:LOCATION#GENERAL|Rooms:ROOM#GENERAL|Rooms:ROOM#GENERAL|Rooms:ROOM#VIEW
# location:LOCATION#GENERAL|Rooms:ROOM#GENERAL|Rooms:ROOM#VIEW
# experience|facilities
# experience|facilities
# experience:POS|facilities:POS
# experience:POS|facilities:POS
# experience:fantastic|facilities:great
# experience:fantastic|facilities:great
# experience:HOTEL#EXPERIENCE|facilities:FACILITY#GENERAL
# experience:HOTEL#EXPERIENCE|facilities:FACILITY#GENERAL
# Things|hotel|noise
# deal|Amenities|Things|noise|ttouts
# Things:POS|Things:NEG|hotel:POS|noise:POS
# Things:NEU|Things:NEG|hotel:POS|noise:POS
# Things:simple|Things:rough|hotel:gooddeal|noise:far
# Things:simple|Things:rough|hotel:budget|noise:far
# Things:HOTEL#EXPERIENCE|Things:HOTEL#EXPERIENCE|hotel:HOTEL#PRICE|noise:HOTEL#AMBIENCE
# Things:HOTEL#GENERAL|Things:HOTEL#GENERAL|Things:HOTEL#GENERAL|hotel:HOTEL#PRICE|noise:HOTEL#EXPERIENCE
# loaction|malls|restaurants|room|services|parkingspace|breakfast
# loaction|malls|restaurants|room|services|parkingspace|breakfast
# loaction:POS|malls:POS|restaurants:POS|room:POS|services:POS|parkingspace:POS|breakfast:POS
# loaction:POS|malls:POS|restaurants:POS|room:POS|services:POS|parkingspace:POS|breakfast:POS
# loaction:great|malls:nearby|restaurants:nearby|room:good|services:good|parkingspace:good|breakfast:delicious
# loaction:great|malls:nearby|restaurants:nearby|room:good|services:good|parkingspace:good|breakfast:delicious
# loaction:LOCATION#GENERAL|malls:LOCATION#ENTERTAINMENT|restaurants:LOCATION#NEARBY_AMENITIES|room:ROOM#GENERAL|services:SERVICE#GENERAL|parkingspace:FACILITY#GENERAL|breakfast:FOOD#TASTE
# loaction:LOCATION#GENERAL|malls:LOCATION#ENTERTAINMENT|restaurants:LOCATION#NEARBY_AMENITIES|room:ROOM#GENERAL|services:SERVICE#GENERAL|parkingspace:FACILITY#GENERAL|breakfast:FOOD#TASTE
# hotel|convenientstore|room|experience|apologize
# hotelexperience|room|bathroom
# hotel:POS|convenientstore:POS|room:NEU|experience:NEG|apologize:NEG
# hotel:POS|convenientstore:POS|room:NEU|experience:NEG|apologize:NEG
# hotel:modern|convenientstore:10-15minwalk|room:ok|experience:blackouttwice|apologize:no
# hotel:modern|convenientstore:10-15minwalk|room:ok|experience:blackouttwice|apologize:no
# hotel:HOTEL#AMBIENCE|convenientstore:HOTEL#AMBIENCE|room:ROOM#GENERAL|experience:HOTEL#EXPERIENCE|apologize:SERVICE#HOSPITALITY
# hotel:HOTEL#AMBIENCE|convenientstore:LOCATION#NEARBY_AMENITIES|room:ROOM#GENERAL|experience:HOTEL#EXPERIENCE|apologize:SERVICE#HOSPITALITY
# surprise|location|budgethotel|staff
# location|budgethotel|staff
# surprise:POS|location:POS|budgethotel:POS|staff:POS
# surprise:POS|location:POS|budgethotel:POS|staff:POS
# surprise:pleasant|location:great|budgethotel:great|staff:wonderful
# surprise:pleasant|location:great|budgethotel:great|staff:wonderful
# ...
# ambience:HOTEL#AMBIENCE|hotel:HOTEL#AMBIENCE|room:ROOM#GENERAL|stay:HOTEL#EXPERIENCE|food:FOOD#TASTE|television:FACILITY#WIFI|bed:ROOM#BED
# hotel|aircond|lift
# hotel|aircond|lift|shops|streets|breakfast
# hotel:POS|aircond:POS|lift:NEG
# hotel:POS|aircond:POS|lift:NEG
# hotel:comfortable|aircond:cool|hotel:satisfied|lift:broken
# hotel:comfortable|aircond:cool|lift:broken
# hotel:HOTEL#EXPERIENCE|aircond:ROOM#AIRCON|hotel:HOTEL#EXPERIENCE|lift:FACILITY#MAINTAIN
# hotel:HOTEL#EXPERIENCE|aircond:ROOM#AIRCON|lift:FACILITY#GENERAL
# Hotel|Location|bars|restaurants|Staff|Breakfast|price|Food
# Hotel|Location|bars|restaurants|Staff|Swimmingpool|Breakfast|price|Food
# Hotel:NEU|Location:POS|bars:POS|restaurants:POS|Staff:POS|Breakfast:POS|price:POS|Food:POS
# Hotel:POS|Location:POS|bars:POS|restaurants:POS|Staff:POS|Breakfast:NEU|price:POS|Food:POS
# Hotel:simple|Location:perfect|bars:walkingdistance|restaurants:walkingdistance|Staff:friendly|Breakfast:average|price:awesome|Food:nice|Food:affordable
# Hotel:simple|Location:perfect|bars:walkingdistance|restaurants:walkingdistance|Staff:friendly|Breakfast:average|price:awesome|Food:nice|Food:affordable
# Hotel:HOTEL#GENERAL|Location:LOCATION#GENERAL|bars:LOCATION#ENTERTAINMENT|restaurants:LOCATION#NEARBY_AMENITIES|Staff:SERVICE#HOSPITALITY|Breakfast:FOOD#GENERAL|price:HOTEL#PRICE|Food:FOOD#TASTE|Food:FOOD#PRICE
# Hotel:HOTEL#GENERAL|Location:LOCATION#GENERAL|bars:LOCATION#ENTERTAINMENT|restaurants:LOCATION#NEARBY_AMENITIES|Staff:SERVICE#HOSPITALITY|Breakfast:FOOD#TASTE|price:HOTEL#PRICE|Food:FOOD#TASTE|Food:FOOD#PRICE
# location|rooms|linen|breakfast|Staff|hotel
# location|rooms|linen|rooms|breakfast|Staff
# location:POS|rooms:POS|linen:POS|rooms:NEG|breakfast:POS|Staff:POS|hotel:POS
# location:POS|rooms:POS|linen:POS|breakfast:POS|Staff:POS|hotel:POS
# location:Good|rooms:Clean|linen:Clean|rooms:spacious|rooms:minimumspace|breakfast:Enjoyed|Staff:friendly|Staff:helpful|hotel:liked
# location:Good|rooms:Clean|linen:Clean|rooms:spacious|breakfast:Enjoyed|Staff:friendly|Staff:helpful|hotel:liked
# location:LOCATION#GENERAL|rooms:ROOM#CLEANLINESS|linen:ROOM#CLEANLINESS|rooms:ROOM#SPACE|rooms:ROOM#SPACE|breakfast:FOOD#TASTE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|hotel:HOTEL#GENERAL
# location:LOCATION#GENERAL|rooms:ROOM#CLEANLINESS|linen:ROOM#CLEANLINESS|rooms:ROOM#SPACE|rooms:ROOM#SPACE|breakfast:FOOD#TASTE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|hotel:HOTEL#GENERAL
# view|foodquality|Theservice
# view|foodquality|service
# view:POS|foodquality:POS|Theservice:NEU
# view:POS|foodquality:POS|Theservice:NEU
# view:simplybreathtaking|foodquality:satisfactory|Theservice:average
# view:beautiful|foodquality:satisfactory|Theservice:average
# view:LOCATION#VIEW|foodquality:FOOD#TASTE|Theservice:SERVICE#GENERAL
# view:LOCATION#VIEW|foodquality:FOOD#TASTE|Theservice:SERVICE#GENERAL
# room|breakfastmenu|facility
# value|room|breakfastmenu|checkin|facility
# room:POS|breakfastmenu:POS|facility:POS
# room:POS|breakfastmenu:POS|facility:POS
# room:Niceclean|breakfastmenu:Good|facility:Onetimeafternoonsnacks|facility:Earlycheckin&morecountlessfacility
# room:Niceclean|breakfastmenu:Good|facility:morecountless
# room:ROOM#CLEANLINESS|breakfastmenu:FOOD#TASTE|facility:FACILITY#GENERAL|facility:FACILITY#GENERAL
# room:ROOM#CLEANLINESS|breakfastmenu:FOOD#TASTE|facility:FACILITY#GENERAL
# deal|hospitality|staffs|livemusic
# deal|staffs|livemusic|deal
# deal:POS|hospitality:NEG|staffs:NEG|livemusic:POS
# deal:POS|hospitality:NEG|staffs:NEG|livemusic:POS
# deal:good|hospitality:lack|staffs:amateur|livemusic:Nice
# deal:good|hospitality:lack|staffs:amateur|livemusic:Nice
# deal:HOTEL#PRICE|hospitality:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|livemusic:HOTEL#EXPERIENCE
# deal:HOTEL#PRICE|hospitality:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|livemusic:HOTEL#EXPERIENCE
# stayingthere|swimmingpool|Location|near
# swimmingpool|Location|Krisna|eatingarea
# stayingthere:POS|swimmingpool:POS|swimmingpool:NEU|Location:POS|near:POS
# stayingthere:POS|swimmingpool:POS|Location:POS|near:POS
# stayingthere:loves|swimmingpool:Love|swimmingpool:nottoobig|Location:great|near:Krisna|near:eatingarea
# stayingthere:loves|swimmingpool:Love|swimmingpool:nottoobig|Location:great|near:Krisna|eatingarea:near
# stayingthere:HOTEL#EXPERIENCE|swimmingpool:FACILITY#POOL|swimmingpool:FACILITY#POOL|Location:LOCATION#GENERAL|near:LOCATION#NEARBY_AMENITIES|near:LOCATION#NEARBY_AMENITIES
# stayingthere:HOTEL#EXPERIENCE|swimmingpool:FACILITY#POOL|swimmingpool:FACILITY#POOL|Location:LOCATION#GENERAL|near:LOCATION#NEARBY_AMENITIES
# IbisLegianCity|room|amenitiesandcoffeefacilities|staff|roofswimmingpool|roomservice|food|location
# room|amenities|coffeefacilities|staff|roomservice|food|location
# IbisLegianCity:POS|room:POS|amenitiesandcoffeefacilities:POS|staff:POS|roofswimmingpool:POS|roomservice:POS|food:POS|location:POS
# IbisLegianCity:POS|room:POS|amenitiesandcoffeefacilities:POS|staff:POS|roofswimmingpool:POS|roomservice:POS|food:POS|location:POS
# IbisLegianCity:nice|room:clean|amenitiesandcoffeefacilities:fill|staff:friendly|roofswimmingpool:Nice|roomservice:quitefast|food:delicious|location:good|location:easytoaccess
# IbisLegianCity:nice|room:clean|amenitiesandcoffeefacilities:fill|staff:friendly|roofswimmingpool:Nice|roomservice:quitefast|food:delicious|location:good
# IbisLegianCity:HOTEL#GENERAL|room:ROOM#CLEANLINESS|amenitiesandcoffeefacilities:ROOM#AMENITIES|staff:SERVICE#HOSPITALITY|roofswimmingpool:FACILITY#POOL|roomservice:SERVICE#AMENITIES|food:FOOD#TASTE|location:LOCATION#GENERAL|location:LOCATION#GENERAL
# IbisLegianCity:HOTEL#EXPERIENCE|room:ROOM#CLEANLINESS|amenitiesandcoffeefacilities:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY|roofswimmingpool:FACILITY#POOL|roomservice:SERVICE#GENERAL|food:FOOD#TASTE|location:LOCATION#GENERAL
# location|rooms|food|staff
# location|shops|resturants|food|staff
# location:POS|rooms:POS|food:POS|staff:POS
# location:POS|rooms:POS|food:POS|staff:POS
# location:Great|rooms:Beautifullycleaned|food:Great|staff:Amazing
# location:Great|rooms:Beautifullycleaned|food:Great|staff:Amazing
# location:LOCATION#GENERAL|rooms:ROOM#CLEANLINESS|food:FOOD#TASTE|staff:SERVICE#HOSPITALITY
# location:LOCATION#GENERAL|rooms:ROOM#CLEANLINESS|food:FOOD#TASTE|staff:SERVICE#HOSPITALITY
# poolarea|breakfast|staff
# poolarea|breakfast|staff
# poolarea:POS|breakfast:POS|staff:POS
# poolarea:POS|breakfast:POS|staff:POS
# poolarea:Good|breakfast:good|staff:good
# poolarea:Good|breakfast:good|staff:good
# poolarea:FACILITY#POOL|breakfast:FOOD#GENERAL|staff:SERVICE#HOSPITALITY
# poolarea:FACILITY#POOL|breakfast:FOOD#TASTE|staff:SERVICE#HOSPITALITY
# Rooms|room|Fridge|towels
# Rooms|doorsclosing|toiletsflushing|room|Fridge|towels|Rooftoppool
# Rooms:NEG|room:NEG|Fridge:NEG|towels:NEG|room:POS|Fridge:POS|towels:POS
# Rooms:NEG|room:NEG|room:POS|Fridge:NEG|towels:NEG
# Rooms:noise|room:smelt|room:musty|Fridge:didn'twork|towels:notclean|room:spacious|room:clean|Fridge:quicklyfixed|towels:changed
# Rooms:needmoresoundproofing|room:musty|room:spacious|room:clean|Fridge:didn'twork|towels:notclean|towels:changed
# Rooms:ROOM#EXPERIENCE|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|Fridge:ROOM#FACILITY|towels:ROOM#BATHROOM|room:ROOM#SPACE|room:ROOM#CLEANLINESS|Fridge:SERVICE#ASSISTANCE|towels:ROOM#BATHROOM
# Rooms:ROOM#EXPERIENCE|room:ROOM#CLEANLINESS|room:ROOM#SPACE|room:ROOM#CLEANLINESS|Fridge:ROOM#FACILITY|towels:ROOM#CLEANLINESS|towels:ROOM#CLEANLINESS
# view|hotel|vegetarianfood|experience
# view|food|experience|food
# view:POS|hotel:NEG|vegetarianfood:NEG|experience:NEG
# view:POS|hotel:NEG|vegetarianfood:NEG|experience:NEG
# view:nice|hotel:nottochoose|vegetarianfood:don'thaveaproper|experience:worst
# view:nice|hotel:nottochoose|vegetarianfood:don'thave|experience:worst
# view:ROOM#VIEW|hotel:HOTEL#GENERAL|vegetarianfood:FOOD#GENERAL|experience:HOTEL#EXPERIENCE
# view:ROOM#VIEW|hotel:HOTEL#GENERAL|vegetarianfood:FOOD#GENERAL|experience:HOTEL#EXPERIENCE
# stay|room|staff|menu|souvenirshops|beautycenters|restaurants
# stay|room|staff|menu|souvenirshops|beautycenters|restaurants
# stay:POS|room:POS|staff:POS|menu:POS|souvenirshops:POS|beautycenters:POS|restaurants:POS
# stay:POS|room:POS|staff:POS|menu:POS|souvenirshops:POS|beautycenters:POS|restaurants:POS
# stay:loved|room:cozy|room:clean|staff:nice|staff:helpful|menu:diverse|menu:rich|souvenirshops:surrounded|beautycenters:surrounded|restaurants:surrounded
# stay:loved|room:cozy|room:clean|staff:nice|staff:helpful|menu:diverse|menu:rich|souvenirshops:surrounded|beautycenters:surrounded|restaurants:surrounded
# stay:HOTEL#EXPERIENCE|room:ROOM#AMBIENCE|room:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|menu:FOOD#CHOICE|menu:FOOD#CHOICE|souvenirshops:LOCATION#NEARBY_AMENITIES|beautycenters:LOCATION#NEARBY_AMENITIES|restaurants:LOCATION#NEARBY_AMENITIES
# stay:HOTEL#EXPERIENCE|room:ROOM#EXPERIENCE|room:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|menu:FOOD#CHOICE|menu:FOOD#CHOICE|souvenirshops:LOCATION#NEARBY_AMENITIES|beautycenters:LOCATION#NEARBY_AMENITIES|restaurants:LOCATION#NEARBY_AMENIT
# breakfast|rooms|booking|airport
# rooms|airport
# breakfast:NEG|rooms:POS|booking:NEG|airport:POS
# breakfast:NEG|rooms:POS|booking:NEG|airport:POS
# breakfast:pay|rooms:nice|booking:takecare|rooms:clean|airport:only700m
# breakfast:free|rooms:nice|rooms:clean|booking:takecare|airport:700m
# breakfast:FOOD#GENERAL|rooms:ROOM#GENERAL|booking:SERVICE#HOSPITALITY|rooms:ROOM#CLEANLINESS|airport:LOCATION#TRANSPORT_HUB
# breakfast:FOOD#GENERAL|rooms:ROOM#GENERAL|rooms:ROOM#CLEANLINESS|booking:SERVICE#GENERAL|airport:LOCATION#TRANSPORT_HUB
# room|location|staff|Breakfast
# room|location|staff|Breakfast
# room:POS|location:POS|staff:POS|Breakfast:NEG
# room:POS|location:POS|staff:POS|Breakfast:NEG
# room:Clean|location:good|staff:friendly|Breakfast:limited
# room:Clean|location:good|staff:friendly|Breakfast:limited
# room:ROOM#CLEANLINESS|location:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY|Breakfast:FOOD#TASTE
# room:ROOM#CLEANLINESS|location:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY|Breakfast:FOOD#CHOICE
# wifi|valueformoney|quality|roomsandals|view
# quality|valueformoney|view|wifi
# wifi:POS|valueformoney:POS|quality:NEU|roomsandals:NEG|view:POS
# wifi:POS|valueformoney:POS|quality:NEU|roomsandals:NEG|view:POS
# wifi:fast|valueformoney:good|quality:Average|roomsandals:needtoprovide|view:good
# wifi:fast|valueformoney:good|quality:Average|roomsandals:needtoprovide|view:good
# wifi:FACILITY#WIFI|valueformoney:HOTEL#PRICE|quality:HOTEL#GENERAL|roomsandals:FACILITY#GENERAL|view:LOCATION#VIEW
# wifi:FACILITY#WIFI|valueformoney:HOTEL#PRICE|quality:HOTEL#GENERAL|roomsandals:ROOM#BED|view:LOCATION#VIEW
# touristattractions|city|privatebeach|experience|food
# experience|food|city|othertouristattractions
# touristattractions:NEG|city:NEG|privatebeach:POS|experience:POS|food:POS
# touristattractions:NEG|city:NEG|privatebeach:POS|experience:POS|food:POS
# touristattractions:away|city:away|privatebeach:has|experience:good|food:good
# touristattractions:away|city:away|privatebeach:had|experience:good|food:good
# touristattractions:LOCATION#ATTRACTIONS|city:LOCATION#CENTRAL_CITY|privatebeach:LOCATION#ATTRACTIONS|experience:HOTEL#EXPERIENCE|food:FOOD#TASTE
# touristattractions:LOCATION#ATTRACTIONS|city:LOCATION#ATTRACTIONS|privatebeach:FACILITY#POOL|experience:HOTEL#EXPERIENCE|food:FOOD#TASTE
# staff|shower|Breakfast|quality|hotel
# staff|Breakfast|quality
# staff:POS|shower:POS|Breakfast:POS|quality:POS|hotel:POS
# staff:POS|shower:POS|Breakfast:POS|quality:POS|hotel:POS
# staff:friendly|staff:happy|shower:free|Breakfast:delicious|Breakfast:good|quality:good|hotel:highlyrecommend
# staff:friendly|shower:free|Breakfast:delicious|quality:good|hotel:highlyrecommend
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|shower:ROOM#BATHROOM|Breakfast:FOOD#TASTE|Breakfast:FOOD#TASTE|quality:HOTEL#GENERAL|hotel:HOTEL#GENERAL
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|shower:ROOM#BATHROOM|Breakfast:FOOD#TASTE|quality:FOOD#TASTE|hotel:HOTEL#GENERAL
# boutiquehotel|staff|service|here|pool
# boutiquehotel|staff|service|pool
# boutiquehotel:POS|staff:POS|service:POS|here:POS|pool:POS
# boutiquehotel:POS|staff:POS|service:POS|here:POS|pool:POS
# boutiquehotel:great|staff:amazing|service:amazing|here:relaxing|pool:beautiful
# boutiquehotel:great|staff:amazing|service:amazing|here:relaxing|pool:beautiful
# boutiquehotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|here:HOTEL#EXPERIENCE|pool:FACILITY#POOL
# boutiquehotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|here:HOTEL#EXPERIENCE|pool:FACILITY#POOL
# MercureHarvestlandKuta|aspect|roomtoilet|foulsmell|staff|restaurant
# MercureHarvestlandKuta|Everyaspect|roomtoilet|airconditioning|staff|service
# MercureHarvestlandKuta:POS|aspect:POS|roomtoilet:NEG|foulsmell:NEG|staff:POS|restaurant:POS
# MercureHarvestlandKuta:POS|aspect:POS|roomtoilet:NEG|foulsmell:NEG|staff:POS|restaurant:POS
# MercureHarvestlandKuta:pleased|aspect:excellent|roomtoilet:foulsmell|foulsmell:airconditioning|staff:servicewithasmile|restaurant:servicewithasmile
# MercureHarvestlandKuta:pleasant|aspect:excellent|roomtoilet:foulsmell|foulsmell:airconditioning|staff:providesservicewithasmile|restaurant:satisfied
# MercureHarvestlandKuta:HOTEL#GENERAL|aspect:HOTEL#EXPERIENCE|roomtoilet:ROOM#BATHROOM|foulsmell:ROOM#AIRCON|staff:SERVICE#HOSPITALITY|restaurant:SERVICE#HOSPITALITY
# MercureHarvestlandKuta:HOTEL#GENERAL|aspect:HOTEL#GENERAL|roomtoilet:ROOM#BATHROOM|foulsmell:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|restaurant:FOOD#GENERAL
# room|teammembers|hygiene|Breakfast
# room|teammembers|healthmeasures|Breakfast|restaurant
# room:POS|teammembers:POS|hygiene:POS|Breakfast:POS
# room:POS|teammembers:POS|hygiene:POS|Breakfast:POS
# room:spacious|teammembers:friendly|hygiene:seriously|Breakfast:delicious
# room:spacious|teammembers:friendly|teammembers:knowledged|hygiene:seriously|Breakfast:delicious|Breakfast:differentvariety
# room:ROOM#SPACE|teammembers:SERVICE#GENERAL|hygiene:ROOM#CLEANLINESS|Breakfast:FOOD#TASTE
# room:ROOM#SPACE|teammembers:SERVICE#HOSPITALITY|teammembers:SERVICE#HOSPITALITY|hygiene:ROOM#CLEANLINESS|Breakfast:FOOD#CHOICE
# staff|Location|conveniencestrore|atmcenter|giftshop|restaurants|shuttlebus|money
# staff|Location|conveniencestrore|atmcenter|giftshop|restaurants|shuttlebus|money
# staff:POS|Location:POS|conveniencestrore:POS|atmcenter:POS|giftshop:POS|restaurants:POS|shuttlebus:POS|money:POS
# staff:POS|Location:POS|conveniencestrore:POS|atmcenter:POS|giftshop:POS|restaurants:POS|shuttlebus:POS|money:POS
# staff:friendly|staff:helpful|Location:good|conveniencestrore:close|atmcenter:5minuteswalk|giftshop:5minuteswalk|restaurants:5minuteswalk|shuttlebus:have|money:goodvalue
# staff:friendly|staff:helpful|Location:good|conveniencestrore:close|atmcenter:5minuteswalk|giftshop:5minuteswalk|restaurants:5minuteswalk|shuttlebus:5minuteswalk|money:goodvalue
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|conveniencestrore:LOCATION#NEARBY_AMENITIES|atmcenter:LOCATION#NEARBY_AMENITIES|giftshop:LOCATION#NEARBY_AMENITIES|restaurants:LOCATION#NEARBY_AMENITIES|shuttlebus:SERVICE#AMENITIES|money:HOTEL#PRICE
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|conveniencestrore:LOCATION#NEARBY_AMENITIES|atmcenter:LOCATION#NEARBY_AMENITIES|giftshop:LOCATION#NEARBY_AMENITIES|restaurants:LOCATION#NEARBY_AMENITIES|shuttlebus:SER
# room
# staff|cleanliness|facilities
# room:POS
# room:POS
# room:cleanliness|room:facilities
# room:cleanliness|room:facilities
# room:ROOM#CLEANLINESS|room:ROOM#FACILITY
# room:ROOM#CLEANLINESS
# location
# location|shops|placestoeat
# location:POS
# location:POS
# location:perfect
# location:perfect
# location:LOCATION#GENERAL
# location:LOCATION#GENERAL
# ----------------------- Classic Training Set Metrics  default category-----------------------
# {'accuracy': 0.3818373533676025, 'precision': 0.23379916187541835, 'recall': 0.2338817560530856, 'f1': 0.2336482039822995}

# %%
metrics = t5_exp.get_classic_metrics(id_te_labels, id_te_pred_labels)
print("----------------------- Classic Testing Set Metrics -----------------------")
print(metrics)
# Out:
# location|noise|cockroaches|staff
# location|room|staff
# location:POS|noise:NEG|cockroaches:NEG|staff:POS
# location:POS|noise:NEG|cockroaches:NEG|staff:POS
# location:good|noise:lotof|cockroaches:plenty|staff:friendly|staff:helpful
# location:good|noise:lot|cockroaches:plenty|staff:friendly|staff:helpful
# location:LOCATION#GENERAL|noise:ROOM#AMBIENCE|cockroaches:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# location:LOCATION#GENERAL|noise:ROOM#EXPERIENCE|cockroaches:ROOM#EXPERIENCE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# staff|Hotel|location
# staff|location
# staff:POS|Hotel:POS|location:POS
# staff:POS|Hotel:POS|location:POS
# staff:nice|staff:kind|Hotel:Clean|Hotel:comfortable|location:Convenient
# staff:nice|staff:kind|Hotel:Clean|Hotel:comfortable|location:Convenient
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|Hotel:HOTEL#CLEANLINESS|Hotel:HOTEL#EXPERIENCE|location:LOCATION#GENERAL
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|Hotel:HOTEL#CLEANLINESS|Hotel:HOTEL#EXPERIENCE|location:LOCATION#GENERAL
# hotel|service|rooms|location|shopping|Spas|beachclubs|staff
# hotel|service|rooms|location|shopping|Spas|beachclubs|receptionstaff
# hotel:POS|service:POS|rooms:POS|location:POS|shopping:POS|Spas:POS|beachclubs:POS|staff:NEG
# hotel:POS|service:POS|rooms:POS|location:POS|shopping:POS|Spas:POS|beachclubs:POS|staff:POS
# hotel:great|service:great|rooms:clean|location:convenient|shopping:convenient|Spas:nearby|beachclubs:nearby|staff:cannotdoenough
# hotel:great|service:great|rooms:clean|location:convenient|shopping:convenient|Spas:convenient|beachclubs:convenient|staff:candoenough
# hotel:HOTEL#GENERAL|service:SERVICE#GENERAL|rooms:ROOM#CLEANLINESS|location:LOCATION#GENERAL|shopping:LOCATION#NEARBY_AMENITIES|Spas:LOCATION#NEARBY_AMENITIES|beachclubs:LOCATION#NEARBY_AMENITIES|staff:SERVICE#ASSISTANCE
# hotel:HOTEL#GENERAL|service:SERVICE#GENERAL|rooms:ROOM#CLEANLINESS|location:LOCATION#GENERAL|shopping:LOCATION#NEARBY_AMENITIES|Spas:LOCATION#NEARBY_AMENITIES|beachclubs:LOCATION#NEARBY_AMENITIES|staff:SERVICE#HOSPITALITY
# staff|meal|bathroom|wifi
# staff|meal|location|airport|atm|minimarket|bathroom|wifi
# staff:POS|meal:POS|bathroom:POS|wifi:NEG
# staff:POS|meal:POS|bathroom:POS|wifi:NEG
# staff:friendly|meal:good|bathroom:clean|wifi:notreallyfast
# staff:friendly|meal:good|bathroom:clean|wifi:notreallyfast
# staff:SERVICE#HOSPITALITY|meal:FOOD#TASTE|bathroom:ROOM#BATHROOM|wifi:FACILITY#WIFI
# staff:SERVICE#HOSPITALITY|meal:FOOD#PRICE|bathroom:ROOM#BATHROOM|wifi:FACILITY#WIFI
# hotel|trip|rooms|staff|stay
# hotel|rooms|staff
# hotel:POS|trip:POS|rooms:POS|staff:POS|stay:POS
# hotel:POS|trip:POS|rooms:POS|staff:POS|stay:POS
# hotel:perfect|trip:relaxing|trip:quiet|rooms:clean|staff:great|staff:kind|stay:perfect
# hotel:perfect|trip:quiet|rooms:clean|staff:great|stay:perfect
# hotel:HOTEL#GENERAL|trip:HOTEL#EXPERIENCE|trip:HOTEL#EXPERIENCE|rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE
# hotel:HOTEL#GENERAL|trip:HOTEL#EXPERIENCE|rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE
# location|Staff|room|breakfast
# location|Staff|room|buffetbreakfast|bar
# location:POS|Staff:POS|room:POS|breakfast:POS
# location:POS|Staff:POS|room:POS|breakfast:POS
# location:Great|Staff:friendly|Staff:helpful|Staff:alwayssmiling|room:cleaned|breakfast:good
# location:Great|Staff:friendly|Staff:helpful|Staff:smiling|room:clean|breakfast:good
# location:LOCATION#GENERAL|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|breakfast:FOOD#GENERAL
# location:LOCATION#TRANSPORT_HUB|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|breakfast:FOOD#TASTE
# rooms|staff|shuttleservice|movement|meals|variety
# rooms|staff|shuttleservice|meals
# rooms:POS|staff:POS|shuttleservice:POS|movement:POS|meals:NEG|variety:NEG
# rooms:POS|staff:POS|shuttleservice:POS|movement:POS|meals:NEG|variety:NEG
# rooms:Clean|staff:friendly|shuttleservice:great|shuttleservice:efficient|movement:easy|meals:concern|variety:concern
# rooms:Clean|staff:friendly|shuttleservice:great|shuttleservice:verefficient|movement:easy|meals:needimproving|variety:provided
# rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|shuttleservice:LOCATION#TRANSPORT_HUB|shuttleservice:LOCATION#TRANSPORT_HUB|movement:LOCATION#GENERAL|meals:FOOD#CHOICE|variety:FOOD#CHOICE
# rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|shuttleservice:SERVICE#ASSISTANCE|shuttleservice:SERVICE#ASSISTANCE|movement:HOTEL#EXPERIENCE|meals:FOOD#GENERAL|variety:FOOD#GENERAL
# hotel|Breakfast|room|staff|prices|service
# hotel|Breakfast|room|staff|pricedservice
# hotel:POS|Breakfast:POS|room:POS|staff:POS|prices:POS|service:POS
# hotel:POS|Breakfast:POS|room:POS|staff:POS|prices:NEG|service:POS
# hotel:lovely|Breakfast:excellent|Breakfast:spacious|room:spacious|staff:friendly|prices:cheap|service:excellent
# hotel:lovely|Breakfast:excellent|room:spacious|staff:friendly|prices:cheap|service:excellent
# hotel:HOTEL#GENERAL|Breakfast:FOOD#TASTE|Breakfast:FOOD#GENERAL|room:ROOM#SPACE|staff:SERVICE#HOSPITALITY|prices:HOTEL#PRICE|service:SERVICE#GENERAL
# hotel:HOTEL#GENERAL|Breakfast:FOOD#TASTE|room:ROOM#SPACE|staff:SERVICE#HOSPITALITY|prices:HOTEL#PRICE|service:SERVICE#GENERAL
# budgethotel|price|Staff|Room
# budgethotel|Staff|Room
# budgethotel:POS|price:POS|Staff:POS|Room:NEG
# budgethotel:POS|price:POS|Staff:POS|Room:NEG
# budgethotel:Great|price:Great|Staff:friendly|Staff:welcoming|Room:mouldy
# budgethotel:Great|price:Great|Staff:friendly|Staff:welcoming|Room:mouldy
# budgethotel:HOTEL#PRICE|price:HOTEL#PRICE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Room:ROOM#CLEANLINESS
# budgethotel:HOTEL#PRICE|price:HOTEL#PRICE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Room:ROOM#CLEANLINESS
# restuarant|location|Pool
# restuarant|breakfast|location|airport|taxi|Kutashopping|Poolarea
# restuarant:NEG|location:POS|Pool:NEG
# restuarant:NEG|location:POS|Pool:NEG
# restuarant:crowdedwithheavysmokers|location:Good|location:closetoairport|Pool:noisey|Pool:notthatgoodforfamilies
# restuarant:crowded|location:Good|Pool:noisy|Pool:notthatgood
# restuarant:FACILITY#GENERAL|location:LOCATION#GENERAL|location:LOCATION#TRANSPORT_HUB|Pool:FACILITY#POOL|Pool:FACILITY#POOL
# restuarant:FOOD#GENERAL|location:LOCATION#GENERAL|Pool:FACILITY#POOL
# hotel|staff|location|room
# hotel|staff|location|airport|places|room
# hotel:POS|staff:POS|location:POS|room:NEU|room:POS
# hotel:POS|staff:POS|location:POS|room:NEG
# hotel:Nice|staff:friendly|location:strategic|room:old|room:affordable
# hotel:Nice|staff:friendly|location:strategic|room:old|room:suitable|room:price|room:affordable
# hotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|room:ROOM#GENERAL|room:HOTEL#PRICE
# hotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|room:ROOM#AMBIENCE|room:ROOM#PRICE|room:ROOM#PRICE
# beaches|travel|Food|People
# beaches|Food|People|placestochill|sceneries|city
# beaches:POS|travel:POS|Food:POS|People:POS
# beaches:POS|travel:POS|Food:POS|People:POS
# beaches:Best|travel:safe|Food:tasty|People:friendly|People:welcoming
# beaches:Best|travel:safe|Food:tasty|People:friendly|People:welcoming|People:supportive
# beaches:LOCATION#NEARBY_AMENITIES|travel:LOCATION#GENERAL|Food:FOOD#TASTE|People:SERVICE#HOSPITALITY|People:SERVICE#HOSPITALITY
# beaches:LOCATION#ATTRACTIONS|travel:HOTEL#EXPERIENCE|Food:FOOD#TASTE|People:SERVICE#HOSPITALITY|People:SERVICE#HOSPITALITY|People:SERVICE#HOSPITALITY
# pool
# pool|staff|motorscooters|restaurants|massagelocations|Hotels
# pool:POS
# pool:POS
# pool:clean
# pool:painteddark|pool:clean
# pool:FACILITY#POOL
# pool:FACILITY#POOL
# room|facilities|wifi|Menu
# room|facilities|wifi|Menurestaurant|foods
# room:NEU|room:POS|facilities:POS|wifi:POS|Menu:POS
# room:NEG|room:POS|facilities:POS|wifi:POS|Menu:POS
# room:small|room:clean|facilities:good|wifi:Free|Menu:delicious|Menu:varietyofcuisines
# room:small|room:clean|facilities:good|wifi:Free|Menu:delicious
# room:ROOM#AMBIENCE|room:ROOM#CLEANLINESS|facilities:FACILITY#GENERAL|wifi:FACILITY#WIFI|Menu:FOOD#TASTE|Menu:FOOD#CHOICE
# room:ROOM#SPACE|room:ROOM#CLEANLINESS|facilities:FACILITY#GENERAL|facilities:FACILITY#GENERAL|wifi:FACILITY#WIFI|Menu:FOOD#CHOICE
# Room|showerhead|Staff|Pool
# Room|bathroom|showerhead|Staff|restaurantfood
# Room:POS|Room:NEG|showerhead:NEG|Staff:POS|Pool:POS
# Room:POS|showerhead:NEG|Staff:POS|Pool:POS
# Room:clean|Room:paintpeeling|showerhead:break|Staff:lovely|Staff:pleasant|Pool:lovely|Pool:cool
# Room:clean|showerhead:broken|Staff:lovely|Staff:pleasant|Pool:lovely|Pool:cool
# Room:ROOM#CLEANLINESS|Room:ROOM#CLEANLINESS|showerhead:ROOM#BATHROOM|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Pool:FACILITY#POOL|Pool:FACILITY#POOL
# Room:ROOM#CLEANLINESS|showerhead:ROOM#BATHROOM|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Pool:FACILITY#POOL|Pool:FACILITY#POOL
# rooms|staff|breakfast|bookingascooter
# rooms|staff|breakfast|choice|hotel
# rooms:POS|staff:POS|breakfast:POS|bookingascooter:NEG
# rooms:POS|staff:POS|breakfast:POS|bookingascooter:NEG
# rooms:big|rooms:Clean|staff:hearty|breakfast:good|breakfast:widechoice|bookingascooter:odissey
# rooms:big|rooms:Clean|staff:hearty|breakfast:good|bookingascooter:odissey
# rooms:ROOM#SPACE|rooms:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|breakfast:FOOD#GENERAL|breakfast:FOOD#CHOICE|bookingascooter:SERVICE#ASSISTANCE
# rooms:ROOM#SPACE|rooms:ROOM#SPACE|staff:SERVICE#HOSPITALITY|breakfast:FOOD#TASTE|bookingascooter:SERVICE#ASSISTANCE
# bartender|manager|location|rooms
# Eka|bartender|service|manager|experience|location|rooms
# bartender:POS|manager:POS|location:POS|rooms:POS
# bartender:POS|manager:POS|location:POS|rooms:POS
# bartender:kind|bartender:helpful|manager:welcome|manager:professional|location:Wonderful|rooms:Big|rooms:clean|rooms:beautiful
# bartender:kind|manager:helpful|manager:loved|location:Wonderful|rooms:Big|rooms:clean|rooms:beautiful
# bartender:SERVICE#HOSPITALITY|bartender:SERVICE#HOSPITALITY|manager:SERVICE#HOSPITALITY|manager:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|rooms:ROOM#SPACE|rooms:ROOM#CLEANLINESS|rooms:ROOM#AMBIENCE
# bartender:SERVICE#HOSPITALITY|manager:SERVICE#HOSPITALITY|manager:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|rooms:ROOM#SPACE|rooms:ROOM#CLEANLINESS
# smell|jam|Bed|pool
# smell|breaky|jam|Bed|Rooftoppool|ambiance
# smell:NEG|jam:NEG|Bed:POS|pool:POS
# smell:NEG|jam:NEG|Bed:POS|pool:POS
# smell:unpleasant|jam:old|Bed:comfortable|pool:great
# smell:unpleasant|jam:old|Bed:comfortable|pool:great|pool:needsmaintenance
# smell:ROOM#AMBIENCE|jam:ROOM#CLEANLINESS|Bed:ROOM#BED|pool:FACILITY#POOL
# smell:ROOM#CLEANLINESS|jam:ROOM#MAINTAIN|Bed:ROOM#BED|pool:FACILITY#POOL
# room|bedsize|Aircon|stay|breakfast
# room|bed|Aircon|breakfast
# room:POS|bedsize:POS|Aircon:NEG|stay:NEU|breakfast:NEG
# room:POS|bedsize:POS|Aircon:NEG|stay:POS|breakfast:NEG
# room:pleased|bedsize:pleased|Aircon:didn'twork|stay:okay|breakfast:boring
# room:pleasant|bedsize:pleasant|Aircon:didn'twork|stay:okay|breakfast:don'tbother
# room:ROOM#EXPERIENCE|bedsize:ROOM#BED|Aircon:ROOM#AIRCON|stay:HOTEL#EXPERIENCE|breakfast:FOOD#CHOICE
# room:ROOM#GENERAL|bedsize:ROOM#BED|Aircon:ROOM#AIRCON|stay:HOTEL#EXPERIENCE|breakfast:FOOD#TASTE
# stay|staff|spa|food|facilities
# stay|staff|spatreatments|food|facilities
# stay:POS|staff:POS|spa:POS|food:POS|facilities:POS
# stay:POS|staff:POS|spa:POS|food:POS|facilities:POS
# stay:Fantastic|staff:lovely|spa:Fantastic|food:Great|facilities:amazing
# stay:Fantastic|staff:lovely|spa:Fantastic|food:Great|facilities:amazing
# stay:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|spa:SERVICE#AMENITIES|food:FOOD#TASTE|facilities:FACILITY#GENERAL
# stay:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|spa:SERVICE#AMENITIES|food:FOOD#TASTE|facilities:FACILITY#GENERAL
# location|room|shower|toilet|rooftopbar|bardownstairs|snacks
# location|Hotel|room|shower|toilet|swimming|pools|bar
# location:POS|room:NEG|shower:NEG|toilet:NEG|rooftopbar:POS|bardownstairs:POS|snacks:NEU
# location:POS|room:NEG|shower:NEG|toilet:NEG|rooftopbar:POS|bardownstairs:POS|snacks:NEU
# location:Great|room:small|room:weirdwindow|shower:weirdsetup|toilet:weirdsetup|rooftopbar:views|bardownstairs:breeze|snacks:ok
# location:Great|room:small|room:worstwindow|shower:worstsetup|toilet:worstsetup|rooftopbar:goodviews|bardownstairs:nicebreeze|snacks:ok
# location:LOCATION#GENERAL|room:ROOM#AMBIENCE|room:ROOM#AMBIENCE|shower:ROOM#BATHROOM|toilet:ROOM#BATHROOM|rooftopbar:LOCATION#VIEW|bardownstairs:LOCATION#GENERAL|snacks:FOOD#GENERAL
# location:LOCATION#GENERAL|room:ROOM#SPACE|room:ROOM#VIEW|shower:ROOM#BATHROOM|toilet:ROOM#BATHROOM|rooftopbar:LOCATION#VIEW|bardownstairs:LOCATION#VIEW|snacks:FOOD#TASTE
# room
# hotelroom|swimmingpool
# room:NEG|room:NEU
# room:NEU
# room:smaller|room:okay
# room:smaller|room:okay
# room:ROOM#SPACE|room:ROOM#GENERAL
# room:ROOM#SPACE|room:ROOM#SPACE
# room
# breakfast|sleepquality|breakfast
# room:NEG
# room:NEG
# room:small
# room:small|room:fitenough
# room:ROOM#AMBIENCE
# room:ROOM#SPACE|room:ROOM#SPACE
# hotel|room|shower
# hotel|receptionist|room|shower
# hotel:POS|room:POS|shower:POS
# hotel:POS|room:POS|shower:POS
# hotel:good|room:good|shower:good
# hotel:good|room:good|shower:good
# hotel:HOTEL#GENERAL|room:ROOM#GENERAL|shower:ROOM#BATHROOM
# hotel:HOTEL#GENERAL|room:ROOM#GENERAL|shower:ROOM#BATHROOM
# location|roomspace
# location|Kutabeach|Others|roomspace|view|hotel
# location:POS|roomspace:NEU|roomspace:NEG
# location:POS|roomspace:NEU
# location:strategic|roomspace:ok|roomspace:noview
# location:strategic|roomspace:ok|roomspace:noview|roomspace:locatedinthebasement
# location:LOCATION#GENERAL|roomspace:ROOM#SPACE|roomspace:ROOM#VIEW
# location:LOCATION#GENERAL|roomspace:ROOM#GENERAL|roomspace:ROOM#VIEW
# staff|location|food|signage
# staff|location|beach|shoppingarea|localfood|frontdesk|standbystaff
# staff:POS|location:POS|food:POS|signage:POS
# staff:POS|location:POS|food:POS|signage:POS
# staff:warm|staff:Nice|location:great|food:great|signage:helpful
# staff:warm|location:great|food:great|signage:helpful
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|food:FOOD#TASTE|signage:SERVICE#ASSISTANCE
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|location:LOCATION#GENERAL|food:FOOD#TASTE|signage:SERVICE#ASSISTANCE
# hotel|sizerooms|staff|food|prices
# hotel|rooms|staff|kutabeach|restaurant|priced
# hotel:POS|sizerooms:NEU|staff:POS|food:POS|prices:POS
# hotel:POS|sizerooms:POS|staff:POS|food:POS|prices:POS
# hotel:clean|sizerooms:decent|staff:friendly|food:great|prices:great
# hotel:greatclean|hotel:clean|sizerooms:decent|staff:friendly|food:great|prices:great
# hotel:HOTEL#CLEANLINESS|sizerooms:ROOM#SPACE|staff:SERVICE#HOSPITALITY|food:FOOD#TASTE|prices:HOTEL#PRICE
# hotel:HOTEL#CLEANLINESS|hotel:HOTEL#CLEANLINESS|sizerooms:ROOM#SPACE|staff:SERVICE#HOSPITALITY|food:FOOD#TASTE|prices:HOTEL#PRICE
# rooms|bathroom|toiletseatcover|room|sheetpillowcases
# rooms|bathroom|bathroom|sheetpillowcases
# rooms:NEG|bathroom:NEG|toiletseatcover:NEG|room:NEG|sheetpillowcases:NEG
# rooms:NEG|bathroom:NEG|toiletseatcover:NEG|toiletseatcover:NEG|room:NEG|sheetpillowcases:NEG
# rooms:disgusting|bathroom:old|bathroom:dirty|toiletseatcover:damaged|room:disgusting|toiletseatcover:old|room:old|sheetpillowcases:dirty
# rooms:disgusting|bathroom:old|bathroom:dirty|toiletseatcover:damaged|toiletseatcover:old|room:disgusting|sheetpillowcases:bad
# rooms:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|bathroom:ROOM#BATHROOM|toiletseatcover:ROOM#BATHROOM|room:ROOM#CLEANLINESS|toiletseatcover:ROOM#BATHROOM|room:ROOM#GENERAL|sheetpillowcases:ROOM#CLEANLINESS
# rooms:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|bathroom:ROOM#BATHROOM|toiletseatcover:ROOM#BATHROOM|toiletseatcover:ROOM#BATHROOM|room:ROOM#CLEANLINESS|sheetpillowcases:ROOM#CLEANLINESS
# Room
# Room|Cleanness|Location
# Room:NEG|Room:NEU
# Room:NEU
# Room:Small|Room:ok
# Room:Small|Room:ok|Cleanness:ok
# Room:ROOM#SPACE|Room:ROOM#GENERAL
# Room:ROOM#SPACE|Room:ROOM#CLEANLINESS
# hotel|location|babycot|breakfast
# hotel|breakfast|location|shuttlebus|room|babycot
# hotel:NEG|location:NEG|babycot:NEG|breakfast:NEG
# hotel:NEG|location:NEG|babycot:NEG|breakfast:NEG
# hotel:small|location:farfromthebeach|babycot:dirty|breakfast:notmuchvariety
# hotel:small|location:farfromthebeach|babycot:dirty|breakfast:notmuchvariety
# hotel:HOTEL#GENERAL|location:LOCATION#NEARBY_AMENITIES|babycot:ROOM#CLEANLINESS|breakfast:FOOD#CHOICE
# hotel:HOTEL#GENERAL|location:LOCATION#GENERAL|babycot:ROOM#BED|breakfast:FOOD#CHOICE
# location|localfood|Kutasunsetbeach
# location|localfood|Kutasunsetbeach|towel
# location:POS|localfood:POS|Kutasunsetbeach:POS
# location:POS|localfood:POS|Kutasunsetbeach:POS
# location:nice|localfood:easytofind|Kutasunsetbeach:withindistance
# location:nice|localfood:easytofind|Kutasunsetbeach:withindistance
# location:LOCATION#GENERAL|localfood:FOOD#GENERAL|Kutasunsetbeach:LOCATION#NEARBY_AMENITIES
# location:LOCATION#GENERAL|localfood:LOCATION#NEARBY_AMENITIES|Kutasunsetbeach:LOCATION#ATTRACTIONS
# Room|pool
# building|pool|Room|Hotel
# Room:POS|pool:NEG
# Room:POS|pool:NEG
# Room:functional|pool:chilly|Room:clean
# Room:clean|Room:functional|pool:doesn'tgetalotofsun|pool:chilly
# Room:ROOM#GENERAL|pool:FACILITY#POOL|Room:ROOM#CLEANLINESS
# Room:ROOM#CLEANLINESS|Room:ROOM#EXPERIENCE|pool:FACILITY#POOL
# location|view|food|hotel
# location|food|hotel|night
# location:POS|view:POS|food:POS|hotel:NEG
# location:POS|view:POS|food:POS|hotel:NEG
# location:good|view:wholelake|food:tasty|hotel:old
# location:good|view:biglake|food:tasty|food:nice|hotel:old|hotel:wellmaintaned
# location:LOCATION#GENERAL|view:ROOM#VIEW|food:FOOD#TASTE|hotel:HOTEL#AMBIENCE
# location:LOCATION#GENERAL|view:LOCATION#VIEW|food:FOOD#TASTE|food:FOOD#TASTE|hotel:HOTEL#MAINTAIN|hotel:HOTEL#MAINTAIN
# Staff|Rooms|rooftoppool
# Staff|Rooms|rooftoppool
# Staff:POS|Rooms:POS|rooftoppool:POS
# Staff:POS|Rooms:POS|rooftoppool:POS
# Staff:friendly|Rooms:clean|Rooms:regularlycleaned|rooftoppool:abovestandards|rooftoppool:comfortable
# Staff:friendly|Staff:willingtohookyouupwithgooddeals|Staff:recommend|Rooms:clean|Rooms:recommend|rooftoppool:beyondstandards|rooftoppool:comfortable
# Staff:SERVICE#HOSPITALITY|Rooms:ROOM#CLEANLINESS|Rooms:ROOM#CLEANLINESS|rooftoppool:FACILITY#POOL|rooftoppool:FACILITY#POOL
# Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Rooms:ROOM#CLEANLINESS|Rooms:ROOM#CLEANLINESS|rooftoppool:FACILITY#POOL
# room|staff|breakfast
# room|place|staff|breakfastmenu|taste|swimmingpool
# room:POS|staff:POS|breakfast:POS
# room:POS|staff:POS|breakfast:POS
# room:Clean|staff:friendly|staff:helpful|breakfast:taste
# room:Clean|place:quite|staff:friendly|staff:helpful|breakfast:good
# room:ROOM#CLEANLINESS|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|breakfast:FOOD#TASTE
# room:ROOM#CLEANLINESS|place:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|breakfast:FOOD#CHOICE|breakfast:FOOD#TASTE
# kitchen|staff
# room|staff
# kitchen:NEG|staff:NEG
# kitchen:NEG|staff:NEG
# kitchen:noisy|staff:loud
# kitchen:noisy|staff:chitchat
# kitchen:ROOM#AMBIENCE|staff:SERVICE#HOSPITALITY
# kitchen:ROOM#EXPERIENCE|staff:SERVICE#HOSPITALITY
# hotel
# hotel|breakfast|staff|breakfast
# hotel:POS|hotel:NEG
# hotel:POS
# hotel:clean|hotel:crowded
# hotel:clean|hotel:crowded
# hotel:HOTEL#CLEANLINESS|hotel:HOTEL#SPACE
# hotel:HOTEL#CLEANLINESS|hotel:HOTEL#EXPERIENCE|hotel:HOTEL#EXPERIENCE
# hotel|staff|hygiene|healthstandards
# hotel|staff|hygiene|healthstandards
# hotel:NEG|staff:NEG|hygiene:NEG|healthstandards:NEG
# hotel:NEG|staff:NEG|hygiene:NEG|healthstandards:NEG
# hotel:notmaintained|staff:didnotseemtocaremuch|hygiene:poorquality|healthstandards:poorquality
# hotel:badstate|staff:didnotseemtocare|hygiene:poorquality|healthstandards:poor
# hotel:HOTEL#MAINTAIN|staff:SERVICE#HOSPITALITY|hygiene:HOTEL#CLEANLINESS|healthstandards:HOTEL#CLEANLINESS
# hotel:HOTEL#GENERAL|hotel:HOTEL#MAINTAIN|staff:SERVICE#HOSPITALITY|hygiene:HOTEL#CLEANLINESS|healthstandards:HOTEL#CLEANLINESS
# pool|Wifi|breakfast|restaurant|restaurants
# poolarea|airport|Wifi|breakfast|style|hotel|restaurantfood|beach
# pool:POS|Wifi:POS|breakfast:NEU|restaurant:NEG|restaurants:POS
# pool:POS|Wifi:POS|breakfast:POS|restaurant:POS|restaurants:POS
# pool:Nice|Wifi:good|breakfast:notbad|restaurant:boring|restaurants:good
# pool:Nice|Wifi:good|breakfast:notbad|restaurant:boring|restaurants:good
# pool:FACILITY#POOL|Wifi:FACILITY#WIFI|breakfast:FOOD#TASTE|restaurant:FOOD#TASTE|restaurants:FOOD#TASTE
# pool:FACILITY#POOL|Wifi:FACILITY#WIFI|breakfast:FOOD#TASTE|restaurant:FOOD#TASTE|restaurants:LOCATION#NEARBY_AMENITIES
# stay|room|breakfast
# room|area|food|place|KutaBeach|souvenirshops
# stay:POS|room:POS|breakfast:POS
# stay:POS|room:POS|breakfast:POS
# stay:comfort|stay:quite|room:clean|breakfast:good
# stay:comfort|room:clean|breakfast:good
# stay:ROOM#EXPERIENCE|stay:ROOM#GENERAL|room:ROOM#CLEANLINESS|breakfast:FOOD#GENERAL
# stay:HOTEL#EXPERIENCE|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|breakfast:FOOD#TASTE
# rooms|pool|Agus
# rooms|pool|man
# rooms:POS|pool:POS|Agus:POS
# rooms:POS|pool:POS|Agus:POS
# rooms:clean|pool:lovely|pool:nice|Agus:lovely|Agus:friendly|Agus:great
# rooms:clean|rooms:nice|pool:lovely|Agus:friendly
# rooms:ROOM#CLEANLINESS|pool:FACILITY#POOL|pool:FACILITY#POOL|Agus:SERVICE#HOSPITALITY|Agus:SERVICE#HOSPITALITY|Agus:SERVICE#HOSPITALITY
# rooms:ROOM#CLEANLINESS|rooms:ROOM#GENERAL|pool:FACILITY#POOL|Agus:SERVICE#HOSPITALITY
# service|staff|restaurant|khrisna
# hotel|service|staff|restaurant|bar
# service:POS|staff:POS|restaurant:POS|khrisna:POS
# service:POS|staff:POS|restaurant:POS|khrisna:POS
# service:Excellent|staff:polite|restaurant:good|staff:best|khrisna:bestcustomerservice
# service:Excellent|staff:polite|restaurant:good|khrisna:bestcustomerservice
# service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY|restaurant:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY|khrisna:SERVICE#HOSPITALITY
# service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY|restaurant:FOOD#GENERAL|khrisna:SERVICE#HOSPITALITY
# Room|sheets|towels|bathroom|Fan|pool|staff
# Room|sheets|towels|bathroom|Fan|staff
# Room:POS|sheets:NEG|towels:NEG|bathroom:NEG|Fan:NEG|pool:POS|staff:NEU
# Room:NEG|sheets:NEG|towels:NEG|bathroom:NEG|Fan:NEG|pool:POS|staff:POS
# Room:dusty|sheets:dirty|sheets:stinky|towels:dirty|towels:stinky|bathroom:old|bathroom:fullofmosquitos|Fan:doesn'twork|pool:nice|pool:big|staff:ok
# Room:dusty|sheets:dirty|towels:dirty|towels:stinky|bathroom:old|bathroom:fullofmosquitos|Fan:doesn'twork|pool:nice|pool:big|staff:ok
# Room:ROOM#CLEANLINESS|sheets:ROOM#BED|sheets:ROOM#CLEANLINESS|towels:ROOM#CLEANLINESS|towels:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|bathroom:ROOM#BATHROOM|Fan:ROOM#AMBIENCE|pool:FACILITY#POOL|pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY
# Room:ROOM#CLEANLINESS|sheets:ROOM#CLEANLINESS|towels:ROOM#CLEANLINESS|towels:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|Fan:ROOM#FACILITY|pool:FACILITY#POOL|pool:FACILITY#POOL|staff:SERVICE#HOSPITALITY
# brekky|lawns|Aircon|receptionstaff
# brekky|lawns|Aircon|receptionstaff|charge
# brekky:NEU|lawns:POS|Aircon:POS|receptionstaff:POS
# brekky:POS|lawns:POS|Aircon:POS|receptionstaff:POS
# brekky:Decent|lawns:nice|Aircon:great|receptionstaff:friendly
# brekky:Decent|lawns:nicemanicured|Aircon:great|receptionstaff:mostlyfriendly
# brekky:FOOD#GENERAL|lawns:LOCATION#GENERAL|Aircon:ROOM#AIRCON|receptionstaff:SERVICE#HOSPITALITY
# brekky:FOOD#TASTE|lawns:FACILITY#GENERAL|Aircon:ROOM#AIRCON|receptionstaff:SERVICE#HOSPITALITY
# staff|hotel
# budgethotel|staff|place|beach
# staff:POS|hotel:POS
# staff:POS|hotel:POS
# staff:polite|staff:kind|hotel:lookedhighend
# staff:polite|staff:kind|hotel:budget
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|hotel:HOTEL#AMBIENCE
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|hotel:HOTEL#PRICE
# stay|wifi
# stay|wif
# stay:POS|wifi:NEG
# stay:POS|wifi:NEG
# stay:memorable|wifi:didn'twork|wifi:disappointed
# stay:memorable|wifi:didn'twork
# stay:HOTEL#EXPERIENCE|wifi:FACILITY#WIFI|wifi:FACILITY#WIFI
# stay:HOTEL#EXPERIENCE|wifi:FACILITY#WIFI
# hotel|rooms|hotwater|linens|breakfast
# hotwater|rooms|breakfastmenu
# hotel:POS|rooms:NEU|hotwater:NEG|linens:NEG|breakfast:NEG
# hotel:POS|rooms:NEU|hotwater:NEG|linens:NEG|breakfast:NEG
# hotel:neartoKutabeach|rooms:ok|hotwater:notworking|linens:don'tchange|breakfast:notverycreative
# hotel:neartoKutabeach|rooms:ok|hotwater:notworkingproperly|linens:don'tchange|breakfast:notverycreative
# hotel:LOCATION#NEARBY_AMENITIES|rooms:ROOM#GENERAL|hotwater:ROOM#BATHROOM|linens:ROOM#CLEANLINESS|breakfast:FOOD#TASTE
# hotel:LOCATION#ATTRACTIONS|rooms:ROOM#GENERAL|hotwater:ROOM#BATHROOM|linens:ROOM#BATHROOM|breakfast:FOOD#CHOICE
# Staff|hotel|breakfast
# Staff|hotel|breakfast
# Staff:POS|hotel:POS|breakfast:NEG
# Staff:POS|hotel:POS|breakfast:NEG
# Staff:friendly|hotel:clean|breakfast:salty
# Staff:friendly|hotel:clean|breakfast:salty
# Staff:SERVICE#HOSPITALITY|hotel:HOTEL#CLEANLINESS|breakfast:FOOD#TASTE
# Staff:SERVICE#HOSPITALITY|hotel:HOTEL#CLEANLINESS|breakfast:FOOD#TASTE
# hotel|staff
# hotel|money|staff|Breakfast|centralpool
# hotel:POS|staff:POS
# hotel:POS|staff:POS
# hotel:valueformoney|staff:friendly|staff:helpful
# hotel:new|staff:friendly|staff:helpful
# hotel:HOTEL#PRICE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# hotel:HOTEL#GENERAL|hotel:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# hotel
# hotel|chairs
# hotel:NEU
# hotel:POS
# hotel:noissues
# hotel:noissues
# hotel:HOTEL#GENERAL
# hotel:HOTEL#GENERAL
# place|room|location|breakfast
# place|room|location|breakfast
# place:POS|room:POS|location:POS|breakfast:POS
# place:POS|room:POS|location:POS|breakfast:POS
# place:nice|room:clean|room:fresh|location:goanywherebywalkingdistance|breakfast:good
# place:nice|room:clean|room:fresh|location:intheheartofkuta|breakfast:good
# place:HOTEL#GENERAL|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|location:LOCATION#GENERAL|breakfast:FOOD#GENERAL
# place:HOTEL#GENERAL|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|location:LOCATION#GENERAL|breakfast:FOOD#TASTE
# place|pool
# place|swimmingpool|breakfast
# place:POS|pool:POS
# place:POS|pool:POS
# place:Great|place:relax|pool:lovely
# place:Great|pool:lovely
# place:HOTEL#GENERAL|place:HOTEL#AMBIENCE|pool:FACILITY#POOL
# place:HOTEL#GENERAL|pool:FACILITY#POOL
# they
# stuff|inhumanity|surfer|bathroom|hotel
# they:NEG
# they:NEG
# they:inhumanity|they:Rude
# they:Rudestuff|they:inhumanity
# they:SERVICE#HOSPITALITY|they:SERVICE#HOSPITALITY
# they:HOTEL#EXPERIENCE
# staff|drainagesystem|airvents
# staff|room|airvents|changeofroom
# staff:POS|drainagesystem:NEG|airvents:NEG
# staff:POS|drainagesystem:NEG|airvents:NEG
# staff:courteous|drainagesystem:problem|airvents:notfunctioning
# staff:courteous|drainagesystem:problem|airvents:notfunctioning
# staff:SERVICE#HOSPITALITY|drainagesystem:ROOM#MAINTAIN|airvents:ROOM#MAINTAIN
# staff:SERVICE#HOSPITALITY|drainagesystem:ROOM#BATHROOM|airvents:ROOM#AIRCON
# Rooms|Pool|beach
# stuff|Rooms|shower|toilet|Pool|smells
# Rooms:NEG|Pool:POS|beach:NEG
# Rooms:NEG|Pool:POS|beach:NEG
# Rooms:weird|Pool:good|beach:Dirty|beach:smellsbad
# Rooms:worst|Rooms:plastic|Pool:good|beach:Dirty|Pool:smellsbad
# Rooms:ROOM#AMBIENCE|Pool:FACILITY#POOL|beach:HOTEL#CLEANLINESS|beach:HOTEL#CLEANLINESS
# Rooms:ROOM#GENERAL|Rooms:ROOM#CLEANLINESS|Pool:FACILITY#POOL|beach:LOCATION#ATTRACTIONS
# money|food|breakfast|WiFi|location
# valueformoney|food|breakfast|WiFi|location
# money:POS|food:NEU|breakfast:POS|WiFi:NEG|location:POS
# money:POS|food:NEU|breakfast:NEU|WiFi:NEG|location:POS
# money:greatvalue|food:average|breakfast:cheap|WiFi:unstable|WiFi:wastesomuchtime|location:nearairport
# money:greatvalue|food:average|breakfast:cheap|WiFi:unstable|location:Good
# money:HOTEL#PRICE|food:FOOD#TASTE|breakfast:FOOD#PRICE|WiFi:FACILITY#WIFI|WiFi:FACILITY#WIFI|location:LOCATION#TRANSPORT_HUB
# money:HOTEL#PRICE|food:FOOD#PRICE|breakfast:FOOD#PRICE|WiFi:FACILITY#WIFI|location:LOCATION#TRANSPORT_HUB
# staffs
# staffs|service
# staffs:POS
# staffs:POS
# staffs:welcome|staffs:greathelp
# staffs:welcoming|staffs:greathelp
# staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY
# staffs:SERVICE#HOSPITALITY
# hotel|location|stay|staffs|Mr.Hendra|service
# hotel|location|shoppingmall|beach|conveniencestore|stay|staffs|service
# hotel:POS|location:POS|stay:POS|staffs:POS|Mr.Hendra:POS|service:POS
# hotel:POS|location:POS|stay:POS|staffs:POS|Mr.Hendra:POS|service:POS
# hotel:nice|hotel:Strategic|location:great|location:neartoshoppingmall|stay:Pleasant|staffs:Friendly|Mr.Hendra:helpful|Mr.Hendra:handy|service:Good
# hotel:Strategic|location:great|stay:Pleasant|staffs:Friendly|Mr.Hendra:helpful|staffs:helpful|Mr.Hendra:helpful|service:Good
# hotel:HOTEL#GENERAL|hotel:HOTEL#GENERAL|location:LOCATION#GENERAL|location:LOCATION#NEARBY_AMENITIES|stay:ROOM#EXPERIENCE|staffs:SERVICE#HOSPITALITY|Mr.Hendra:SERVICE#HOSPITALITY|Mr.Hendra:SERVICE#HOSPITALITY|service:SERVICE#GENERAL
# hotel:HOTEL#GENERAL|location:LOCATION#GENERAL|stay:HOTEL#EXPERIENCE|staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|Mr.Hendra:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|Mr.Hendra:SERVICE#HOSPITALITY|service:SERVICE#GENERAL
# experience|rooms|pool|breakfast
# experience|rooms|pool|breakfast
# experience:POS|rooms:POS|pool:POS|breakfast:NEG
# experience:POS|rooms:POS|pool:POS|breakfast:NEG
# experience:great|rooms:Nice|pool:pretty|breakfast:couldbebetter
# experience:great|rooms:Nice|pool:pretty|breakfast:couldbebetter
# experience:HOTEL#EXPERIENCE|rooms:ROOM#GENERAL|pool:FACILITY#POOL|breakfast:FOOD#TASTE
# experience:HOTEL#EXPERIENCE|rooms:ROOM#GENERAL|pool:FACILITY#POOL|breakfast:FOOD#GENERAL
# room|amenities|bathroom|hotwater|restaurant|Food|beverages
# room|amenities|bathroom|hotwater|restaurant|Food|beverages
# room:NEU|amenities:NEU|bathroom:NEU|hotwater:NEG|restaurant:POS|Food:POS|beverages:POS
# room:NEU|amenities:POS|bathroom:NEU|hotwater:NEG|restaurant:POS|Food:POS|beverages:POS
# room:ok|amenities:ok|bathroom:ok|hotwater:didn'twork|restaurant:iconic|Food:amazing|beverages:amazing
# room:ok|amenities:ok|bathroom:ok|hotwater:didn'twork|restaurant:soooiconic|Food:amazing|beverages:amazing
# room:ROOM#GENERAL|amenities:FACILITY#GENERAL|bathroom:ROOM#BATHROOM|hotwater:ROOM#MAINTAIN|restaurant:FOOD#GENERAL|Food:FOOD#TASTE|beverages:FOOD#TASTE
# room:ROOM#GENERAL|amenities:ROOM#AMENITIES|bathroom:ROOM#BATHROOM|hotwater:ROOM#BATHROOM|restaurant:FOOD#GENERAL|Food:FOOD#TASTE|beverages:FOOD#TASTE
# scoopondeal|price
# price
# scoopondeal:NEU|price:NEU
# scoopondeal:POS|price:POS
# scoopondeal:Ok|price:Ok
# scoopondeal:OKdeal|price:OK
# scoopondeal:HOTEL#PRICE|price:HOTEL#PRICE
# scoopondeal:HOTEL#PRICE|price:HOTEL#PRICE
# people|Room|Towels|value|hotel
# people|Room|floormopped|Towels|Everything|value|vegetarianfood|Pool
# people:POS|Room:POS|Towels:POS|value:POS|hotel:NEU
# people:POS|Room:POS|Towels:POS|value:POS|hotel:NEU
# people:nice|Room:clean|Towels:good|value:Good|hotel:standard
# people:nice|Room:clean|Towels:good|value:Good|hotel:standard
# people:SERVICE#HOSPITALITY|Room:ROOM#CLEANLINESS|Towels:ROOM#CLEANLINESS|value:HOTEL#PRICE|hotel:HOTEL#GENERAL
# people:SERVICE#HOSPITALITY|people:SERVICE#HOSPITALITY|Room:ROOM#CLEANLINESS|Towels:ROOM#BATHROOM|value:HOTEL#PRICE|hotel:HOTEL#GENERAL
# money|Staff|Food
# shopping|restaurants|beach|localattractions|money|Staff|Food
# money:POS|Staff:POS|Food:POS
# money:POS|Staff:POS|Food:POS
# money:goodvalue|Staff:excellent|Staff:helpful|Food:amazing
# money:goodvalue|Staff:excellent|Staff:helpful|Food:amazing
# money:HOTEL#PRICE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Food:FOOD#TASTE
# money:HOTEL#PRICE|Staff:SERVICE#HOSPITALITY|Staff:SERVICE#HOSPITALITY|Food:FOOD#TASTE
# service|rooms|price|pool
# service|rooms|price|pool|Location
# service:POS|rooms:POS|price:POS|pool:NEU
# service:POS|rooms:POS|price:POS|pool:POS
# service:Nice|rooms:cozy|rooms:clean|price:cheap|price:good|pool:ok
# service:Nice|rooms:cozy|rooms:clean|price:cheap|pool:ok
# service:SERVICE#GENERAL|rooms:ROOM#AMBIENCE|rooms:ROOM#CLEANLINESS|price:HOTEL#PRICE|price:HOTEL#PRICE|pool:FACILITY#POOL
# service:SERVICE#GENERAL|rooms:ROOM#CLEANLINESS|rooms:ROOM#CLEANLINESS|price:HOTEL#PRICE|pool:FACILITY#POOL
# stay|Room|multiplepools|Restaurant|food|Staff
# stay|Room|Restaurant|food|Staff|scooter
# stay:POS|Room:POS|multiplepools:POS|Restaurant:POS|food:POS|Staff:POS
# stay:POS|Room:POS|multiplepools:POS|Restaurant:POS|food:POS|Staff:POS
# stay:fantastic|Room:fantastic|multiplepools:nice|Restaurant:greatfood|food:great|Staff:helpful
# stay:fantastic|Room:fantastic|multiplepools:nice|Restaurant:greatfood|food:great|Staff:helpful
# stay:ROOM#EXPERIENCE|Room:ROOM#GENERAL|multiplepools:FACILITY#POOL|Restaurant:FOOD#GENERAL|food:FOOD#TASTE|Staff:SERVICE#HOSPITALITY
# stay:HOTEL#EXPERIENCE|Room:ROOM#GENERAL|multiplepools:FACILITY#POOL|Restaurant:FOOD#TASTE|food:FOOD#TASTE|Staff:SERVICE#HOSPITALITY
# location
# location|waterboom|discoverymall|kutabeach|waterboom|lippomall
# location:POS
# location:POS
# location:Great
# location:Great
# location:LOCATION#GENERAL
# location:LOCATION#GENERAL
# experience|golfcourseview|staffs|Dewi|Wani|room|service|scooterrent
# experience|privateresort|golfcourseview|frontdeskstaffs|room|service|spotterrent
# experience:POS|golfcourseview:POS|staffs:POS|Dewi:POS|Wani:POS|room:POS|service:POS|scooterrent:POS
# experience:POS|golfcourseview:POS|staffs:POS|Dewi:POS|Wani:POS|room:POS|service:POS|scooterrent:POS
# experience:nice|golfcourseview:nice|staffs:helpfully|staffs:friendly|Dewi:helpfully|Wani:helpfully|room:clean|room:comfortable|service:Good|scooterrent:Easytogoanywhere
# experience:nice|golfcourseview:nice|staffs:friendly|staffs:helpfully|Dewi:helpfully|Wani:helpfully|room:clean|room:comfortable|service:Good|scooterrent:provide
# experience:HOTEL#EXPERIENCE|golfcourseview:LOCATION#VIEW|staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|Dewi:SERVICE#HOSPITALITY|Wani:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|room:ROOM#EXPERIENCE|service:SERVICE#GENERAL|scooterrent:LOCATION#TRANSPORT_HUB
# experience:HOTEL#EXPERIENCE|golfcourseview:LOCATION#VIEW|staffs:SERVICE#HOSPITALITY|staffs:SERVICE#HOSPITALITY|Dewi:SERVICE#HOSPITALITY|Wani:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|room:ROOM#EXPERIENCE|service:SERVICE#GENERAL|scooterrent:SERVICE#ASSISTANCE
# Hotel|room|staff|cleaners|stay
# Hotel|room|staff|restaurant|reception|clean|quiet|room|clean|clean|quiet|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean|clean
# Hotel:POS|room:POS|room:NEG|staff:POS|cleaners:POS|stay:POS
# Hotel:POS|room:POS|staff:POS|cleaners:POS|stay:POS
# Hotel:great|room:fresh|room:clean|room:quiet|room:small|staff:great|cleaners:friendly|cleaners:helpful|stay:comfortable|stay:safe
# Hotel:great|room:fresh|room:clean|room:quiet|staff:great|cleaners:great|cleaners:small|stay:safe|stay:comfortable
# Hotel:HOTEL#GENERAL|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|room:ROOM#AMBIENCE|room:ROOM#AMBIENCE|staff:SERVICE#HOSPITALITY|cleaners:SERVICE#HOSPITALITY|cleaners:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE|stay:ROOM#EXPERIENCE
# Hotel:HOTEL#GENERAL|room:ROOM#CLEANLINESS|room:ROOM#AMBIENCE|room:ROOM#SPACE|staff:SERVICE#HOSPITALITY|clean:ROOM#CLEANLINESS|room:ROOM#SPACE|staff:SERVICE#HOSPITALITY|cleaners:SERVICE#HOSPITALITY|cleaners:SERVICE#HOSPITALITY|stay:HOTEL#EXPERIENCE
# price|location|room|Breakfast|eggstation|drink|foods
# price|location|room|showercap|bathamenities|Breakfast|foods|drink|eggstation
# price:POS|location:POS|room:NEG|Breakfast:NEG|eggstation:NEU|drink:NEU|foods:NEG
# price:POS|location:POS|room:NEG|Breakfast:NEG|eggstation:NEG|drink:NEU|foods:NEG
# price:affordable|location:nice|location:Closetothemalls|room:noisy|Breakfast:wasn'tsatisfying|eggstation:okay|drink:okay|foods:dry
# price:affordable|location:nice|room:noisy|Breakfast:wasn'tsatisfying|eggstation:chargeextra|drink:okay|foods:Lot
# price:HOTEL#PRICE|location:LOCATION#GENERAL|location:LOCATION#NEARBY_AMENITIES|room:ROOM#EXPERIENCE|Breakfast:FOOD#TASTE|eggstation:FOOD#CHOICE|drink:FOOD#CHOICE|foods:FOOD#TASTE
# price:HOTEL#PRICE|location:LOCATION#GENERAL|room:ROOM#EXPERIENCE|room:ROOM#EXPERIENCE|Breakfast:FOOD#TASTE|eggstation:FACILITY#GENERAL|drink:FOOD#GENERAL|foods:FOOD#GENERAL
# rooms|swimmingpool|staff
# rooms|swimmingpool|staff
# rooms:POS|swimmingpool:POS|staff:POS
# rooms:POS|swimmingpool:POS|staff:POS
# rooms:quiet|rooms:fairlylarge|swimmingpool:large|staff:friendly|staff:helpful
# rooms:quiet|rooms:large|swimmingpool:large|staff:friendly|staff:helpful
# rooms:ROOM#AMBIENCE|rooms:ROOM#SPACE|swimmingpool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# rooms:ROOM#EXPERIENCE|rooms:ROOM#SPACE|swimmingpool:FACILITY#POOL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# rooms|room|In-roomfacilities
# rooms|room|facilities|telephone|safetybox|tv|kettle|refrigerator|bed
# rooms:NEG|rooms:POS|room:POS|In-roomfacilities:POS
# rooms:NEG|room:POS|In-roomfacilities:POS
# rooms:small|rooms:comfortable|room:clean|In-roomfacilities:complete
# rooms:small|rooms:comfortable|room:clean|In-roomfacilities:complete
# rooms:ROOM#SPACE|rooms:ROOM#EXPERIENCE|room:ROOM#CLEANLINESS|In-roomfacilities:ROOM#AMENITIES
# rooms:ROOM#SPACE|rooms:ROOM#EXPERIENCE|room:ROOM#CLEANLINESS|room:ROOM#CLEANLINESS|In-roomfacilities:FACILITY#GENERAL
# rooms|location|facilities|sound|Tv
# hotelrooms|location|facilities|sound
# rooms:POS|location:POS|facilities:POS|sound:NEG|Tv:NEG
# rooms:NEG|location:POS|facilities:POS|sound:NEG|Tv:NEG
# rooms:good|location:good|facilities:good|sound:doesnotwork|Tv:Onechannel
# rooms:shame|location:good|facilities:good|sound:doesnotwork|Tv:doesnotwork
# rooms:ROOM#GENERAL|location:LOCATION#GENERAL|facilities:FACILITY#GENERAL|sound:ROOM#MAINTAIN|Tv:ROOM#AMENITIES
# rooms:ROOM#GENERAL|location:LOCATION#GENERAL|facilities:FACILITY#GENERAL|sound:ROOM#EXPERIENCE|Tv:ROOM#EXPERIENCE
# location|rooms|restaurant|breakfast|service
# location|rooms|restaurant|breakfast|service
# location:POS|rooms:POS|restaurant:POS|breakfast:POS|service:POS
# location:POS|rooms:POS|restaurant:POS|breakfast:POS|service:NEG
# location:lovely|rooms:large|restaurant:goodvalue|breakfast:goodvalue|service:faultless
# location:lovely|rooms:large|restaurant:goodvalue|breakfast:goodvalue|service:faultless
# location:LOCATION#GENERAL|rooms:ROOM#SPACE|restaurant:FOOD#PRICE|breakfast:FOOD#PRICE|service:SERVICE#GENERAL
# location:LOCATION#GENERAL|rooms:ROOM#SPACE|restaurant:FOOD#PRICE|breakfast:FOOD#PRICE|service:SERVICE#GENERAL
# hotel|money|viewfrombalcony
# hotel|money|view|balcony
# hotel:POS|money:POS|viewfrombalcony:POS
# hotel:POS|money:POS|viewfrombalcony:POS
# hotel:Beautiful|money:Worth|viewfrombalcony:hotel
# hotel:Beautiful|money:Worth|viewfrombalcony:best
# hotel:HOTEL#AMBIENCE|money:HOTEL#PRICE|viewfrombalcony:LOCATION#VIEW
# hotel:HOTEL#GENERAL|money:HOTEL#PRICE|viewfrombalcony:LOCATION#VIEW
# staff|position|hotel|Breakfast
# staff|hotel|position|hotel|Breakfast
# staff:POS|position:POS|hotel:NEG|hotel:POS|Breakfast:NEG
# staff:POS|position:POS|hotel:NEG|Breakfast:NEU
# staff:approachable|staff:helpful|position:good|hotel:tired|hotel:wellmaintained|Breakfast:notsogood.|hotel:outdoorswimmingpool
# staff:attentive|staff:helpful|position:good|hotel:good|hotel:tired|Breakfast:okay|Breakfast:notsogood
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|position:HOTEL#GENERAL|hotel:HOTEL#MAINTAIN|hotel:HOTEL#MAINTAIN|Breakfast:FOOD#TASTE|hotel:FACILITY#POOL
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|position:LOCATION#GENERAL|hotel:HOTEL#GENERAL|hotel:HOTEL#MAINTAIN|Breakfast:FOOD#TASTE
# Hotel|location
# Hotel|location
# Hotel:POS|location:POS
# Hotel:POS|location:POS
# Hotel:nice|location:great|location:everythingnear
# Hotel:nice|location:great
# Hotel:HOTEL#GENERAL|location:LOCATION#GENERAL|location:LOCATION#NEARBY_AMENITIES
# Hotel:HOTEL#GENERAL|location:LOCATION#GENERAL
# restaurant|pool
# Twinroom|aircon|pool|restaurant|Staff
# restaurant:POS|pool:POS
# restaurant:POS|pool:POS
# restaurant:great|pool:fantastic
# restaurant:great|pool:fantastic
# restaurant:LOCATION#GENERAL|pool:FACILITY#POOL
# restaurant:FOOD#GENERAL|pool:FACILITY#POOL
# bed|breakfast|place|people|swimmingpool|parking|room|beach
# bed|breakfast|place|people|swimmingpool|parking|room|beach
# bed:NEG|breakfast:NEG|place:POS|people:POS|swimmingpool:POS|parking:NEG|room:NEG|beach:POS
# bed:NEG|breakfast:NEG|place:POS|people:POS|swimmingpool:POS|parking:NEG|room:NEG|room:POS|beach:POS
# bed:noisy|breakfast:Boring|place:Nice|people:Good|swimmingpool:Good|parking:Nottoenjoyed|room:noisy|beach:Near
# bed:noisy|breakfast:Boring|place:Nice|people:Good|swimmingpool:Good|parking:Nottoenjoyed|room:noisy|room:Clean|room:comfort|beach:Near
# bed:ROOM#AMBIENCE|breakfast:FOOD#TASTE|place:HOTEL#GENERAL|people:SERVICE#HOSPITALITY|swimmingpool:FACILITY#POOL|parking:FACILITY#GENERAL|room:ROOM#EXPERIENCE|beach:LOCATION#ATTRACTIONS
# bed:ROOM#BED|breakfast:FOOD#GENERAL|place:HOTEL#GENERAL|people:SERVICE#HOSPITALITY|swimmingpool:FACILITY#POOL|parking:FACILITY#GENERAL|room:ROOM#EXPERIENCE|room:ROOM#EXPERIENCE|room:ROOM#EXPERIENCE|room:ROOM#EXPERIENCE|beach:LOCATION#ATTRACTIONS
# money|Room|Swimmingpool
# value|Room|Swimmingpool|Overall
# money:POS|Room:NEU|Swimmingpool:NEU
# money:POS|Room:POS|Swimmingpool:NEU
# money:goodvalue|Room:ok|Swimmingpool:ok
# money:goodvalue|Room:ok|Swimmingpool:ok
# money:HOTEL#PRICE|Room:ROOM#GENERAL|Swimmingpool:FACILITY#POOL
# money:HOTEL#PRICE|Room:ROOM#GENERAL|Swimmingpool:FACILITY#POOL
# staff|rooms|location|rooftoppool
# staff|rooms|location|rooftoppool|food
# staff:POS|rooms:POS|location:POS|rooftoppool:NEU
# staff:POS|rooms:POS|location:POS|rooftoppool:POS
# staff:Friendly|staff:helpful|rooms:comfortable|location:good|rooftoppool:fine
# staff:Friendly|staff:helpful|rooms:comfortable|location:good|rooftoppool:fine
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|rooms:ROOM#EXPERIENCE|location:LOCATION#GENERAL|rooftoppool:FACILITY#POOL
# staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|rooms:ROOM#EXPERIENCE|location:LOCATION#GENERAL|rooftoppool:FACILITY#POOL
# Room|Staffs|Location
# Room|Staffs|Location
# Room:POS|Room:NEG|Room:NEU|Staffs:POS|Location:POS
# Room:POS|Staffs:POS|Location:POS
# Room:clean|Room:Notreallybig|Room:okayFortwopeople|Staffs:helpful|Location:strategic|Location:neartobeach
# Room:clean|Room:Notreallybig|Staffs:helpful|Location:strategic
# Room:ROOM#CLEANLINESS|Room:ROOM#SPACE|Room:ROOM#SPACE|Staffs:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|Location:LOCATION#NEARBY_AMENITIES
# Room:ROOM#CLEANLINESS|Room:ROOM#SPACE|Staffs:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL
# hotel|placed|staff|room|experience
# hotel|staff|room|property|swimmingpool|experience
# hotel:NEG|hotel:POS|placed:POS|staff:POS|room:NEG|room:POS|experience:POS
# hotel:POS|placed:POS|staff:POS|room:NEG|room:POS|experience:POS
# hotel:cozy|hotel:small|placed:well|staff:polite|staff:smiling|room:small|room:neat|room:cozy|experience:pleasant
# hotel:small|hotel:cozy|placed:well|staff:polite|staff:smiling|room:small|room:nice|room:cosy|experience:pleasant
# hotel:HOTEL#AMBIENCE|hotel:HOTEL#GENERAL|placed:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|room:ROOM#AMBIENCE|room:ROOM#CLEANLINESS|room:ROOM#AMBIENCE|experience:ROOM#EXPERIENCE
# hotel:HOTEL#AMBIENCE|hotel:HOTEL#EXPERIENCE|placed:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|room:ROOM#SPACE|room:ROOM#CLEANLINESS|room:ROOM#EXPERIENCE|experience:HOTEL#EXPERIENCE
# location|room|towel|Floor|bathroom|Aircon|Breakfast|Rooms|toilet
# location|room|Bathroom|Aircon|Breakfast|Rooms|toilet
# location:POS|room:NEG|towel:NEG|Floor:NEG|bathroom:POS|bathroom:NEG|Aircon:NEG|Breakfast:POS|Rooms:NEG|toilet:NEG
# location:POS|room:NEG|towel:NEG|Floor:NEG|bathroom:NEG|Aircon:NEG|Breakfast:POS|Rooms:NEG|toilet:NEG
# location:Lovely|room:wasn'tready|towel:Onlyone|Floor:sandy|bathroom:big|bathroom:smelly|Aircon:struggled|Breakfast:good|Rooms:needagoodclean|toilet:needssomebleach
# location:Lovely|room:wasn'tready|towel:Onlyone|Floor:sandy|bathroom:big|bathroom:smelty|Aircon:struggled|Breakfast:good|Rooms:needagoodclean|toilet:needssomebleach
# location:LOCATION#GENERAL|room:ROOM#EXPERIENCE|towel:ROOM#AMENITIES|Floor:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|bathroom:ROOM#BATHROOM|Aircon:ROOM#AIRCON|Breakfast:FOOD#TASTE|Rooms:ROOM#CLEANLINESS|toilet:ROOM#CLEANLINESS
# location:LOCATION#GENERAL|room:ROOM#GENERAL|towel:ROOM#BATHROOM|Floor:ROOM#CLEANLINESS|bathroom:ROOM#BATHROOM|bathroom:ROOM#CLEANLINESS|Aircon:ROOM#AIRCON|Breakfast:FOOD#TASTE|Rooms:ROOM#CLEANLINESS|toilet:ROOM#BATHROOM
# position|Breakfast|Pool|hotel
# position|price|Breakfast|Pool|shopping|restaurants
# position:POS|Breakfast:NEU|Pool:POS|hotel:POS
# position:POS|Breakfast:NEU|Pool:POS|hotel:POS
# position:Great|position:comfortable|Breakfast:basic|Pool:clean|Pool:closetoourroom|hotel:canwalktoreallygoodshopping
# position:Great|Breakfast:basic|Breakfast:dontexpecttoomuch|Pool:clean|hotel:goodshopping|restaurants:walk
# position:LOCATION#GENERAL|position:LOCATION#GENERAL|Breakfast:FOOD#GENERAL|Pool:FACILITY#POOL|Pool:FACILITY#POOL|hotel:LOCATION#NEARBY_AMENITIES
# position:HOTEL#GENERAL|Pool:FACILITY#POOL|hotel:HOTEL#GENERAL
# property|stay|people
# property|stay|people|beach
# property:POS|stay:POS|people:POS
# property:POS|stay:POS|people:POS
# property:great|stay:great|people:Nice
# property:great|stay:great|people:Nice
# property:HOTEL#GENERAL|stay:HOTEL#EXPERIENCE|people:SERVICE#HOSPITALITY
# property:HOTEL#GENERAL|stay:HOTEL#EXPERIENCE|people:SERVICE#HOSPITALITY
# hotel|price|interiordecorations|breakfast|showercubical|glassdoor
# hotel|price|interiordecorations|breakfast|breakfast|glassdoor
# hotel:POS|price:POS|interiordecorations:POS|breakfast:POS|showercubical:NEG|glassdoor:NEG
# hotel:POS|price:POS|interiordecorations:POS|breakfast:POS|showercubical:NEG|glassdoor:NEG
# hotel:Nice|price:minimum|interiordecorations:Creative|breakfast:good|interiordecorations:feelcomfortable|showercubical:lack|glassdoor:toohigh
# hotel:Nice|price:minimum|interiordecorations:Creative|breakfast:good|showercubical:lack|glassdoor:toohigh
# hotel:HOTEL#GENERAL|price:HOTEL#PRICE|interiordecorations:ROOM#AMBIENCE|breakfast:FOOD#GENERAL|interiordecorations:ROOM#AMBIENCE|showercubical:ROOM#BATHROOM|glassdoor:ROOM#BATHROOM
# hotel:HOTEL#GENERAL|price:HOTEL#PRICE|interiordecorations:HOTEL#AMBIENCE|breakfast:FOOD#CHOICE|showercubical:ROOM#BATHROOM|glassdoor:ROOM#BATHROOM
# rooms|staff|room|management|makeuproomsign|breakfast
# rooms|staff|room|breakfast
# rooms:NEG|staff:POS|staff:NEU|room:NEG|management:NEG|makeuproomsign:NEG|breakfast:NEG
# rooms:POS|staff:POS|room:NEG|management:NEG|makeuproomsign:NEG|breakfast:NEG
# rooms:cheerless|staff:pleasant|staff:notveryhelpful|room:uncleaned|management:uncleaned|makeuproomsign:uncleaned|breakfast:leastinspiredinBali
# rooms:cheerless|staff:pleasant|staff:notveryhelpful|room:uncleaned|management:speakingtomanagement|makeuproomsign:left|breakfast:mostinspired
# rooms:ROOM#AMBIENCE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|management:SERVICE#GENERAL|makeuproomsign:SERVICE#GENERAL|breakfast:FOOD#TASTE
# rooms:ROOM#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|management:SERVICE#HOSPITALITY|makeuproomsign:ROOM#CLEANLINESS|breakfast:FOOD#TASTE
# place|staff
# place|staff|mall|Kutabeach|nightlife|sunset|bike
# place:POS|staff:POS
# place:POS|staff:POS
# place:nice|staff:friendly
# place:nice|staff:friendly|staff:approachable
# place:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY
# place:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# rooms|wifi|selectionofenglishtelevision|housekeeping
# rooms|wifi|Englishtelevision|housekeeping|Pool
# rooms:POS|wifi:POS|selectionofenglishtelevision:POS|housekeeping:NEG
# rooms:POS|wifi:POS|selectionofenglishtelevision:POS|housekeeping:NEG
# rooms:comfortable|wifi:great|selectionofenglishtelevision:good|housekeeping:poor
# rooms:comfortable|wifi:great|selectionofenglishtelevision:good|housekeeping:poor
# rooms:ROOM#EXPERIENCE|wifi:FACILITY#WIFI|selectionofenglishtelevision:ROOM#AMENITIES|housekeeping:SERVICE#GENERAL
# rooms:ROOM#EXPERIENCE|wifi:FACILITY#WIFI|selectionofenglishtelevision:FACILITY#GENERAL|housekeeping:HOTEL#GENERAL
# place|sheetsonthebad|pool
# place|sheets|pool
# place:NEG|sheetsonthebad:NEG|pool:NEG
# place:NEG|sheetsonthebad:NEG|pool:NEG
# place:worst|place:Bad|sheetsonthebad:don'tevenchange|sheetsonthebad:dirty|pool:loud
# place:worst|sheetsonthebad:don'tevenchange|pool:soloud
# place:HOTEL#GENERAL|place:HOTEL#GENERAL|sheetsonthebad:ROOM#CLEANLINESS|sheetsonthebad:ROOM#CLEANLINESS|pool:FACILITY#GENERAL
# ...
# food|service
# day|food|service|Dani|Tya|Resi|Alep|Irsyad|Sasih|Aci
# food:POS|service:POS
# food:POS|service:POS
# food:enjoyed|service:enjoyed
# food:enjoyed|service:enjoyed
# food:FOOD#TASTE|service:SERVICE#GENERAL
# food:FOOD#TASTE|service:SERVICE#GENERAL
# AquaFit|Pilatessessions
# AquaFit|PutuAgus|guests|Smiles|fun
# AquaFit:POS|Pilatessessions:POS
# AquaFit:POS|Pilatessessions:POS
# AquaFit:loved|Pilatessessions:loved
# AquaFit:loved|Pilatessessions:loved
# AquaFit:HOTEL#GENERAL|Pilatessessions:HOTEL#GENERAL
# AquaFit:FACILITY#GENERAL|Pilatessessions:FACILITY#GENERAL
# Resort|restaurant|Chef|beach|Staff|service|activities
# Resort|restaurant|ChefBayu|ChefWayanSuarvata|beach|Staff|service|place
# Resort:POS|restaurant:POS|Chef:POS|beach:POS|Staff:POS|service:POS|activities:POS
# Resort:POS|restaurant:POS|Chef:POS|beach:POS|Staff:POS|service:POS|activities:POS
# Resort:Amazing|restaurant:best|Chef:cookthebest|beach:nicecalm|Staff:helpful|service:outstanding|activities:lot
# Resort:Amazing|restaurant:best|Chef:best|beach:nice|Staff:helpful|service:outstanding|activities:lot
# Resort:HOTEL#GENERAL|restaurant:FOOD#GENERAL|Chef:FOOD#TASTE|beach:LOCATION#GENERAL|Staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|activities:LOCATION#ENTERTAINMENT
# Resort:HOTEL#GENERAL|restaurant:FOOD#GENERAL|Chef:FOOD#TASTE|beach:LOCATION#ATTRACTIONS|Staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL|activities:LOCATION#ENTERTAINMENT
# hotel|staff|environment
# hotel|staff|environment|check-in|check-out
# hotel:POS|staff:POS|environment:POS
# hotel:POS|staff:POS|environment:POS
# hotel:Kidsfriendly|staff:wonderful|environment:pleasant
# hotel:Kidsfriendly|staff:wonderful|hotel:wellmaintained|environment:pleasant|environment:welcoming
# hotel:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY|environment:HOTEL#GENERAL
# hotel:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|hotel:HOTEL#CLEANLINESS|environment:HOTEL#EXPERIENCE|environment:HOTEL#EXPERIENCE
# facilities|staff
# facilities|staff|activitiesstaff
# facilities:POS|staff:POS
# facilities:POS|staff:POS
# facilities:Great|staff:awesome
# facilities:Great|staff:awesome
# facilities:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY
# facilities:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY
# canoeing|funwheel|paddle|game|fishfeeding
# canoeing|wheel|paddling|byecilling|Irul|Agung|fishfeeding
# canoeing:NEU|funwheel:NEU|paddle:NEU|game:POS|fishfeeding:NEU
# canoeing:POS|funwheel:POS|paddle:POS|game:POS|fishfeeding:POS
# canoeing:Have|funwheel:Have|paddle:Have|game:amzing|fishfeeding:done
# canoeing:Have|funwheel:Have|paddle:Have|game:Have|fishfeeding:Have
# canoeing:HOTEL#GENERAL|funwheel:HOTEL#GENERAL|paddle:HOTEL#GENERAL|game:LOCATION#ENTERTAINMENT|fishfeeding:HOTEL#GENERAL
# canoeing:FACILITY#GENERAL|funwheel:FACILITY#GENERAL|paddle:FACILITY#GENERAL|game:FACILITY#GENERAL|fishfeeding:FACILITY#GENERAL
# kidsclub|activities|staff|gym|restaurant
# kidsclub|staff|kidsclub|gym|restaurant
# kidsclub:POS|activities:POS|staff:POS|gym:POS|restaurant:POS
# kidsclub:POS|activities:POS|staff:POS|gym:POS|restaurant:POS
# kidsclub:best|activities:different|staff:attentivetothedetails|gym:attentivetothedetails|restaurant:attentivetothedetails
# kidsclub:best|activities:different|staff:attentive|gym:attentive|restaurant:attentive
# kidsclub:LOCATION#ENTERTAINMENT|activities:LOCATION#ENTERTAINMENT|staff:SERVICE#HOSPITALITY|gym:FACILITY#GENERAL|restaurant:FOOD#GENERAL
# kidsclub:FACILITY#GENERAL|activities:LOCATION#ENTERTAINMENT|staff:SERVICE#HOSPITALITY|gym:FACILITY#GENERAL|restaurant:FOOD#GENERAL
# place|location|views|staffs
# place|view|staffs
# place:POS|location:POS|views:POS|staffs:POS
# place:POS|location:POS|views:POS|staffs:POS
# place:Amazing|location:great|views:great|staffs:helpful
# place:Amazing|location:great|views:enjoy|staffs:helpful
# place:HOTEL#AMBIENCE|location:LOCATION#GENERAL|views:LOCATION#VIEW|staffs:SERVICE#HOSPITALITY
# place:HOTEL#GENERAL|location:LOCATION#GENERAL|views:LOCATION#VIEW|staffs:SERVICE#HOSPITALITY
# person
# court|Arcerytennis|badminton|time|court
# person:POS
# person:POS
# person:servesuswell
# person:servesuswell|person:clean|person:neat
# person:SERVICE#GENERAL
# person:SERVICE#HOSPITALITY|person:SERVICE#HOSPITALITY
# facilities|staff|food|resort
# facilities|staff|food|resort|Everyone
# facilities:POS|staff:POS|food:POS|resort:POS
# facilities:POS|staff:POS|food:POS|resort:POS
# facilities:great|staff:friendly|food:Amazing|resort:clean
# facilities:great|staff:friendly|food:Amazing|resort:clean
# facilities:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY|food:FOOD#TASTE|resort:HOTEL#CLEANLINESS
# facilities:FACILITY#GENERAL|staff:SERVICE#HOSPITALITY|food:FOOD#TASTE|resort:HOTEL#CLEANLINESS
# Facilities|Staff|Location|resort
# Facilities|Staff|Location
# Facilities:POS|Staff:POS|Location:POS|resort:POS
# Facilities:POS|Staff:POS|Location:POS|resort:POS
# Facilities:Cannotfault|Staff:Cannotfault|Location:Cannotfault|resort:Highlyrecommended
# Facilities:Facilities|Staff:Cannotfault|Location:Cannotfault|resort:Cannotfault
# Facilities:FACILITY#GENERAL|Staff:SERVICE#GENERAL|Location:LOCATION#GENERAL|resort:HOTEL#GENERAL
# Facilities:FACILITY#GENERAL|Staff:SERVICE#HOSPITALITY|Location:LOCATION#GENERAL|resort:HOTEL#GENERAL
# hotel|servise|staff
# servise|staff|kidsclub
# hotel:POS|servise:POS|staff:POS
# hotel:POS|servise:POS|staff:POS
# hotel:veryrecomended|servise:friendly|staff:friendly
# hotel:recomended|servise:recomended|staff:friendly
# hotel:HOTEL#GENERAL|servise:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# hotel:HOTEL#GENERAL|servise:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# beach|seevice
# viewvice|job
# beach:POS|seevice:POS
# beach:POS|seevice:POS
# beach:enjoy|seevice:best
# beach:enjoy|seevice:best
# beach:LOCATION#ATTRACTIONS|seevice:SERVICE#HOSPITALITY
# beach:LOCATION#ATTRACTIONS|seevice:FACILITY#GENERAL
# attention|staff|facilities|food
# staff|facilities|food|food
# attention:POS|staff:POS|facilities:POS|food:POS
# attention:POS|staff:POS|facilities:POS|food:POS
# attention:EXCELLENT|staff:attention|facilities:attention|food:attention
# attention:EXCELLENT|staff:EXCELLENT|facilities:EXCELLENT|food:EXCELLENT
# attention:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY|facilities:FACILITY#GENERAL|food:FOOD#GENERAL
# attention:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|facilities:FACILITY#GENERAL|food:FOOD#GENERAL
# room|experience|toilet|service|staff
# experience|familyroom|service|staff
# room:NEU|experience:POS|room:NEG|toilet:NEU|service:POS|staff:POS
# room:NEG|experience:POS|toilet:NEG|service:POS|staff:POS
# room:Stayed|experience:awesome|room:dated|toilet:1|service:awesome|staff:awesomeservice
# room:dated|experience:awesome|toilet:onlyhas1|service:awesome|staff:awesome
# room:ROOM#GENERAL|experience:HOTEL#EXPERIENCE|room:ROOM#AMBIENCE|toilet:FACILITY#GENERAL|service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY
# room:ROOM#AMBIENCE|experience:HOTEL#EXPERIENCE|toilet:ROOM#BATHROOM|service:SERVICE#GENERAL|staff:SERVICE#HOSPITALITY
# time|service
# time|service
# time:NEU|service:POS
# time:POS|service:POS
# time:delighted|service:caring
# time:delightful|service:kind|service:caring
# time:HOTEL#GENERAL|service:SERVICE#HOSPITALITY
# time:HOTEL#EXPERIENCE|service:SERVICE#HOSPITALITY
# staff|experience|simulator|gym
# place|staff|golfsimulator|gym
# staff:POS|experience:POS|simulator:NEU|gym:NEU
# staff:POS|experience:POS|simulator:POS|gym:POS
# staff:amazing|experience:amazing|simulator:howtouse|gym:howtouse
# staff:amazing|experience:amazing|simulator:amazing|gym:amazing
# staff:SERVICE#HOSPITALITY|experience:HOTEL#EXPERIENCE|simulator:HOTEL#GENERAL|gym:FACILITY#GENERAL
# staff:SERVICE#HOSPITALITY|experience:HOTEL#EXPERIENCE|simulator:FACILITY#GENERAL|gym:FACILITY#GENERAL
# activity|breakfast|room|staff
# activity|breakfast|room|staff
# activity:POS|breakfast:POS|room:POS|staff:POS
# activity:POS|breakfast:POS|room:POS|staff:POS
# activity:free|breakfast:Excellent|room:comfortable|staff:friendly
# activity:free|breakfast:Excellent|room:comfortable|staff:friendly|staff:helpful
# activity:LOCATION#ENTERTAINMENT|breakfast:FOOD#TASTE|room:ROOM#EXPERIENCE|staff:SERVICE#HOSPITALITY
# activity:LOCATION#ENTERTAINMENT|breakfast:FOOD#GENERAL|room:ROOM#EXPERIENCE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# activities|archery|movienight|staff
# activities|staff|staff
# activities:POS|archery:NEU|movienight:NEU|staff:POS
# activities:POS|archery:POS|movienight:POS|staff:POS
# activities:great|archery:playing|movienight:had|staff:greatjobentertaining
# activities:greattime|archery:toastedmarshmellow|movienight:had|staff:greatjob
# activities:LOCATION#ENTERTAINMENT|archery:FACILITY#GENERAL|movienight:LOCATION#GENERAL|staff:SERVICE#HOSPITALITY
# activities:LOCATION#ENTERTAINMENT|archery:FACILITY#GENERAL|movienight:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY
# place|staff
# place|staff|place
# place:POS|staff:POS
# place:POS|staff:POS
# place:great|staff:helpful
# place:great|staff:amazing|staff:helpful
# place:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY
# place:HOTEL#GENERAL|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# staff|service
# staff|KidsClub|babysittingservice
# staff:POS|service:POS
# staff:POS|service:POS
# staff:fantastic|service:fantastic
# staff:fantastic|service:fantastic
# staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL
# staff:SERVICE#HOSPITALITY|service:SERVICE#GENERAL
# fitnesscentre|sportscourts|poolareas|driver
# place|edward|edward|eddy
# fitnesscentre:POS|sportscourts:POS|poolareas:POS|driver:POS
# fitnesscentre:POS|sportscourts:POS|poolareas:POS|driver:POS
# fitnesscentre:amazing|sportscourts:amazing|poolareas:amazing|driver:aboveandbeyond
# fitnesscentre:Edmund|sportscourts:amazing|poolareas:amazing|driver:personal
# fitnesscentre:FACILITY#GENERAL|sportscourts:FACILITY#GENERAL|poolareas:FACILITY#POOL|driver:SERVICE#ASSISTANCE
# fitnesscentre:FACILITY#GENERAL|sportscourts:FACILITY#POOL|poolareas:FACILITY#POOL|driver:SERVICE#HOSPITALITY
# pool|beach|service|Staff
# holiday|pool|service|Staff|Reresti
# pool:POS|beach:POS|service:POS|Staff:POS
# pool:POS|beach:POS|service:POS|Staff:POS
# pool:fun|beach:fun|service:outstanding|Staff:aboveandbeyond
# pool:fun|beach:fun|service:outstanding|Staff:beautiful
# pool:FACILITY#POOL|beach:LOCATION#ENTERTAINMENT|service:SERVICE#GENERAL|Staff:SERVICE#ASSISTANCE
# pool:FACILITY#POOL|beach:LOCATION#ATTRACTIONS|service:SERVICE#GENERAL|Staff:SERVICE#HOSPITALITY
# tour|guide
# UluwatuTemple|ephy|ephy
# tour:POS|guide:POS
# tour:POS|guide:POS
# tour:wonderful|guide:lovely
# tour:wonderful|guide:lovely|guide:polite
# tour:LOCATION#ENTERTAINMENT|guide:SERVICE#HOSPITALITY
# tour:HOTEL#EXPERIENCE|guide:SERVICE#HOSPITALITY|guide:SERVICE#HOSPITALITY
# venue|gardens|restaurants|staff|Service|hotel
# gardens|restaurants|staff|levelService
# venue:POS|gardens:POS|restaurants:POS|staff:POS|Service:POS|hotel:POS
# venue:POS|gardens:POS|restaurants:POS|staff:POS|Service:POS|hotel:POS
# venue:great|gardens:beautiful|restaurants:great|staff:helpful|Service:super|hotel:belongsinParadise
# venue:great|gardens:beautiful|restaurants:great|staff:wonderfulhelpful|Service:superLevel|hotel:Pasadise
# venue:LOCATION#ENTERTAINMENT|gardens:FACILITY#EXPERIENCE|restaurants:FOOD#GENERAL|staff:SERVICE#HOSPITALITY|Service:SERVICE#HOSPITALITY|hotel:HOTEL#GENERAL
# venue:HOTEL#GENERAL|gardens:FACILITY#GENERAL|restaurants:LOCATION#NEARBY_AMENITIES|staff:SERVICE#HOSPITALITY|Service:SERVICE#GENERAL|hotel:HOTEL#GENERAL
# club|supervisor
# supervisor|stayed
# club:POS|supervisor:POS
# club:POS|supervisor:POS
# club:HappyStayed|supervisor:helpful
# club:Happy|supervisor:nice|supervisor:helpful
# club:HOTEL#EXPERIENCE|supervisor:SERVICE#HOSPITALITY
# club:FACILITY#GENERAL|supervisor:SERVICE#HOSPITALITY|supervisor:SERVICE#HOSPITALITY
# hotel|atmosphere|staff
# hotel|atmosphere|staff|kidsclub
# hotel:POS|atmosphere:POS|staff:POS
# hotel:POS|atmosphere:POS|staff:POS
# hotel:like|atmosphere:unique|staff:friendly
# hotel:like|atmosphere:unique|staff:friendly
# hotel:HOTEL#GENERAL|atmosphere:HOTEL#AMBIENCE|staff:SERVICE#HOSPITALITY
# hotel:HOTEL#GENERAL|atmosphere:HOTEL#AMBIENCE|staff:SERVICE#HOSPITALITY
# teamofstaff|Activities|poolactivities|Service
# staff|Agus|Ryan|Agung|poolactivities|Service
# teamofstaff:POS|Activities:POS|poolactivities:POS|Service:POS
# teamofstaff:POS|Activities:POS|poolactivities:POS|Service:POS
# teamofstaff:Worldclass|Activities:topquality|poolactivities:greatfun|Service:perfect
# teamofstaff:Great|Activities:topquality|poolactivities:greatfun|Service:perfect
# teamofstaff:SERVICE#HOSPITALITY|Activities:LOCATION#ENTERTAINMENT|poolactivities:FACILITY#POOL|Service:SERVICE#HOSPITALITY
# teamofstaff:SERVICE#HOSPITALITY|Activities:SERVICE#GENERAL|poolactivities:FACILITY#POOL|Service:SERVICE#GENERAL
# stay|staff|restaurants|bars|yogainstructors|club
# stay|staff|restaurants|bars|events|Pattri|yogainstructors|kidsclub
# stay:POS|staff:POS|restaurants:POS|bars:POS|yogainstructors:POS|club:POS
# stay:POS|staff:POS|restaurants:POS|bars:POS|yogainstructors:POS|club:POS
# stay:Excellent|staff:Great|restaurants:variety|bars:variety|yogainstructors:amazing|club:good
# stay:Excellent|staff:Great|restaurants:variety|bars:variety|yogainstructors:amazing|club:good
# stay:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|restaurants:FOOD#CHOICE|bars:LOCATION#ENTERTAINMENT|yogainstructors:SERVICE#GENERAL|club:LOCATION#ENTERTAINMENT
# stay:HOTEL#EXPERIENCE|staff:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY|restaurants:LOCATION#NEARBY_AMENITIES|bars:LOCATION#ENTERTAINMENT|yogainstructors:LOCATION#ENTERTAINMENT|club:LOCATION#ENTERTAINMENT
# resort|customerservice|staff
# resort|customerservice|stay|staff
# resort:POS|customerservice:POS|staff:POS
# resort:POS|customerservice:POS|staff:POS
# resort:good|customerservice:incredible|staff:standout
# resort:good|customerservice:amazing|staff:standout
# resort:HOTEL#GENERAL|customerservice:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# resort:HOTEL#GENERAL|customerservice:SERVICE#HOSPITALITY|staff:SERVICE#HOSPITALITY
# hotel|area|services|food
# area|services|food|healthprotocols
# hotel:NEU|area:POS|services:POS|food:POS
# hotel:POS|area:POS|services:POS|food:POS
# hotel:visiting|area:Quite|services:Perfect|food:Good
# hotel:It|area:Quiet|services:Perfect|food:Good
# hotel:HOTEL#GENERAL|area:LOCATION#GENERAL|services:SERVICE#AMENITIES|food:FOOD#TASTE
# hotel:HOTEL#GENERAL|area:LOCATION#GENERAL|services:SERVICE#GENERAL|food:FOOD#TASTE
# service|environment|people|room|garden|joggingtrack|grilledkingprawn
# service|environment|people|room|garden|joggingtrack|grilledkingprawn
# service:POS|environment:POS|people:POS|room:POS|garden:POS|joggingtrack:POS|grilledkingprawn:POS
# service:POS|environment:POS|people:POS|room:POS|garden:POS|joggingtrack:POS|grilledkingprawn:POS
# service:Good|environment:good|people:nice|room:wellpreserved|garden:Niceandspacious|joggingtrack:Superb|grilledkingprawn:Great
# service:Good|environment:good|people:nice|room:Clean|room:wellpreserved|garden:Nice|joggingtrack:Superb|grilledkingprawn:Great
# service:SERVICE#GENERAL|environment:HOTEL#EXPERIENCE|people:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|garden:LOCATION#ENTERTAINMENT|joggingtrack:FACILITY#GENERAL|grilledkingprawn:FOOD#TASTE
# service:SERVICE#GENERAL|environment:HOTEL#GENERAL|people:SERVICE#HOSPITALITY|room:ROOM#CLEANLINESS|room:ROOM#GENERAL|garden:FACILITY#GENERAL|joggingtrack:FACILITY#GENERAL|grilledkingprawn:FOOD#TASTE
# hotel|food|seafoodplatter|coffee|desserts|ambience|spot
# food|restaurant|seafoodplatter|cafe|coffee|drinks|ambiance|feels
# hotel:POS|food:POS|seafoodplatter:POS|coffee:POS|desserts:POS|ambience:POS|spot:POS
# hotel:POS|food:POS|seafoodplatter:POS|coffee:POS|desserts:POS|ambience:POS|spot:POS
# hotel:lovecoming|food:Good|seafoodplatter:love|coffee:great|desserts:great|ambience:Nice|spot:Cute
# hotel:love|food:Good|seafoodplatter:love|coffee:great|desserts:great|ambience:Nice|spot:Cute
# hotel:HOTEL#GENERAL|food:FOOD#TASTE|seafoodplatter:FOOD#TASTE|coffee:FOOD#TASTE|desserts:FOOD#TASTE|ambience:HOTEL#AMBIENCE|spot:LOCATION#GENERAL
# hotel:HOTEL#GENERAL|food:FOOD#TASTE|seafoodplatter:FOOD#TASTE|coffee:FOOD#TASTE|desserts:FOOD#TASTE|ambience:HOTEL#AMBIENCE|spot:HOTEL#GENERAL
# ----------------------- Classic Testing Set Metrics -----------------------
# {'accuracy': 0.2972636815920398, 'precision': 0.17441574415744157, 'recall': 0.17453874538745387, 'f1': 0.17429274292742927}

# %%
metrics
# Out:
# {'accuracy': 0.2972636815920398,
#  'precision': 0.17441574415744157,
#  'recall': 0.17453874538745387,
#  'f1': 0.17429274292742927}

# %% [markdown]
# Menggunakan model single sentence

# %%
checkpoint_directory = "checkpoints/multitask/kevinscariaate_tk-instruct-base-def-pos-neg-neut-combined-quadruple-ss/checkpoint-17028"
generator_ss_model = ABSAInstruction.ABSAGenerator(checkpoint_directory)

# %%
# Get prediction labels - Training set

generator_ss_model = ABSAInstruction.ABSAGenerator(checkpoint_directory)

# Prepare text data from the tokenized dataset for prediction
texts = [tokenizer.decode(inputs['input_ids'], skip_special_tokens=True) for inputs in id_tokenized_ds['train']]

# Get prediction labels - Training set
id_tr_pred_labels = generator_ss_model.predict(texts, batch_size=16)
id_tr_labels = [i.strip() for i in id_ds["train"]["labels"]]
id_tr_pred_labels = t5_exp.get_labels(
    predictor = generator_ss_model,
    tokenized_dataset= id_tokenized_ds,
    sample_set="train",
    batch_size=16,
)
id_tr_labels = [i.strip() for i in id_ds["train"]["labels"]]
# Out:
# Prediction from trainer
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Get prediction labels - Training set
# ----> 2 id_tr_pred_labels = t5_exp.get_labels(
#       3     predictor = generator_ss_model,
#       4     tokenized_dataset=id_tokenized_ds,
#       5     sample_set="train",
#       6     batch_size=16,
#       7 )
#       8 id_tr_labels = [i.strip() for i in id_ds["train"]["labels"]]
#
# File c:\Users\hongk\Documents\GitHub\ta-final-project-aspect-based-sentiment-analysis-and-categorized-aspect\venv-absa-3.9\lib\site-packages\pyabsa\tasks\ABSAInstruction\model.py:198, in T5Generator.get_labels(self, tokenized_dataset, trained_model_path, predictor, batch_size, sample_set)
#     196 else:
#     197     print("Prediction from trainer")
# --> 198     output_ids = predictor.predict(
#     199         test_dataset=tokenized_dataset[sample_set]
#     200     ).predictions
#     201     predicted_output = self.tokenizer.batch_decode(
#     202         output_ids, skip_special_tokens=True
#     203     )
#     204 return predicted_output
#
# TypeError: predict() missing 1 required positional argument: 'text'
