# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib

# %%
import json

# Load data from JSONL file
file_path = 'single_sentences_hotel_ina.jsonl'
data = []
with open(file_path, 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Count the number of quadruples
quadruple_count = 0

for entry in data:
    labels = entry.get('labels', [])
    quadruple_count += len(labels)

print(f'Total number of quadruples: {quadruple_count}')
# Out:
# Total number of quadruples: 11227

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
file_path = 'single_sentences_hotel_ina.jsonl'
data = []
with open(file_path, 'r') as file:
    for line in file:
        data.append(json.loads(line))
sentiment_counts = {'POS': 0, 'NEG': 0, 'NEU': 0}

for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        # Count sentiments
        if 'polarity' in label and label['polarity']:  # Check if 'polarity' exists and is not null
            polarity = label['polarity']
            if polarity not in sentiment_counts:
                sentiment_counts[polarity] = 0
            sentiment_counts[polarity] += 1


sentiments = list(sentiment_counts.keys())
sentiment_counts_values = list(sentiment_counts.values())



# Plotting sentiments
plt.figure(figsize=(10, 6))
plt.bar(sentiments, sentiment_counts_values, color=['green', 'red', 'blue'])
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution Visualization')
plt.show()

# %%
# Plotting sentiments as a pie chart
plt.figure(figsize=(8, 8))
colors = ['green', 'red', '#FFD700']
plt.pie(sentiment_counts_values, labels=sentiments, colors=colors, autopct='%1.1f%%', startangle=140)
plt.title('Sentiment Distribution Visualization')
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Count occurrences of each category
category_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:  # Check if 'category' exists and is not null
            main_category = label['category'].split('#')[0]
            if main_category not in category_counts:
                category_counts[main_category] = 0
            category_counts[main_category] += 1

# Handle null values
null_categories = 0
for entry in data:
    if not entry.get('labels'):
        null_categories += 1

if null_categories > 0:
    category_counts['NULL'] = null_categories

# Plotting
import matplotlib.pyplot as plt

categories = list(category_counts.keys())
counts = list(category_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(categories, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Category')
plt.title('Aspect Categories Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'HOTEL' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'HOTEL':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Sub Category of Hotel Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the '
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'SERVICE':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Service Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'ROOM' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'ROOM':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Room Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'HOTEL' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FACILITY':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Facility Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'LOCATION':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of LOCATION Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'FOOD' category
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FOOD':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = 0
                hotel_context_counts[context] += 1

# Plotting
import matplotlib.pyplot as plt

contexts = list(hotel_context_counts.keys())
counts = list(hotel_context_counts.values())

plt.figure(figsize=(10, 6))
plt.barh(contexts, counts, color='skyblue')
plt.xlabel('Count')
plt.ylabel('Context')
plt.title('Second Part of Food Category Visualization')
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'LOCATION':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('LOCATION Category Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'HOTEL':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('HOTEL Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FOOD':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('FOOD Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'FACILITY':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('FACILITY Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json
import matplotlib.pyplot as plt

# Load data from JSONL file
data = []
with open('single_sentences_hotel_ina.jsonl', 'r') as file:
    for line in file:
        data.append(json.loads(line))

# Extracting and counting occurrences of the second part of the 'LOCATION' category with polarity
hotel_context_counts = {}
for entry in data:
    labels = entry.get('labels', [])
    for label in labels:
        if 'category' in label and label['category']:
            main_category, context = label['category'].split('#')
            if main_category == 'SERVICE':
                if context not in hotel_context_counts:
                    hotel_context_counts[context] = {'POS': 0, 'NEG': 0}
                polarity = label['polarity']
                if polarity in hotel_context_counts[context]:
                    hotel_context_counts[context][polarity] += 1

# Prepare data for plotting
contexts = list(hotel_context_counts.keys())
positive_counts = [hotel_context_counts[context]['POS'] for context in contexts]
negative_counts = [hotel_context_counts[context]['NEG'] for context in contexts]

# Plotting
plt.figure(figsize=(10, 6))
bar_width = 0.4

# Create bars for positive and negative counts
bar1 = plt.barh(contexts, positive_counts, color='green', edgecolor='grey', height=bar_width, label='POS')
bar2 = plt.barh(contexts, negative_counts, left=positive_counts, color='red', edgecolor='grey', height=bar_width, label='NEG')

# Adding labels
for bar in bar1:
    width = bar.get_width()
    plt.text(width - 5, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')
for bar in bar2:
    width = bar.get_width()
    plt.text(bar.get_x() + width / 2, bar.get_y() + bar.get_height() / 2, f'{int(width)}', ha='center', va='center', color='white', fontweight='bold')

plt.xlabel('Count')
plt.ylabel('Context')
plt.title('SERVICE Category Visualization with Polarity')
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
import json

# %%
# Data provided in JSONL format as a string
jsonl_data = """
{"text": "But the staff was so horrible to us .", "labels": [{"aspect": "staff", "opinion": "horrible", "polarity": "negative", "category": "NULL"}]}
{"text": "To be completely fair , the only redeeming factor was the food , which was above average , but could n't make up for all the other deficiencies of Teodora .", "labels": [{"aspect": "food", "opinion": "above average", "polarity": "positive", "category": "NULL"}]}
{"text": "The food is uniformly exceptional , with a very capable kitchen which will proudly whip up whatever you feel like eating , whether it 's on the menu or not .", "labels": [{"aspect": "food", "opinion": "exceptional", "polarity": "positive", "category": "NULL"}, {"aspect": "kitchen", "opinion": "capable", "polarity": "positive", "category": "NULL"}]}
{"text": "Our agreed favorite is the orrechiete with sausage and chicken ( usually the waiters are kind enough to split the dish in half so you get to sample both meats ) .", "labels": [{"aspect": "orrechiete with sausage and chicken", "opinion": "favorite", "polarity": "positive", "category": "NULL"}, {"aspect": "waiters", "opinion": "kind", "polarity": "positive", "category": "NULL"}]}
{"text": "The Bagels have an outstanding taste with a terrific texture , both chewy yet not gummy .", "labels": [{"aspect": "Bagels", "opinion": "outstanding", "polarity": "positive", "category": "NULL"}, {"aspect": "Bagels", "opinion": "terrific", "polarity": "positive", "category": "NULL"}, {"aspect": "Bagels", "opinion": "chewy", "polarity": "positive", "category": "NULL"}, {"aspect": "Bagels", "opinion": "gummy", "polarity": "positive", "category": "NULL"}]}
{"text": "Nevertheless the food itself is pretty good .", "labels": [{"aspect": "food", "opinion": "good", "polarity": "positive", "category": "NULL"}]}
{"text": "They did not have mayonnaise , forgot our toast , left out ingredients ( ie cheese in an omelet ) , below hot temperatures and the bacon was so over cooked it crumbled on the plate when you touched it .", "labels": [{"aspect": "toast", "opinion": "forgot", "polarity": "negative", "category": "NULL"}, {"aspect": "bacon", "opinion": "over cooked", "polarity": "negative", "category": "NULL"}, {"aspect": "cheese", "opinion": "left out", "polarity": "neutral", "category": "NULL"}, {"aspect": "ingredients", "opinion": "left out", "polarity": "negative", "category": "NULL"}, {"aspect": "plate", "opinion": "over cooked", "polarity": "neutral", "category": "NULL"}, {"aspect": "omelet", "opinion": "left out", "polarity": "neutral", "category": "NULL"}]}
{"text": "The design and atmosphere is just as good .", "labels": [{"aspect": "design", "opinion": "good", "polarity": "positive", "category": "NULL"}, {"aspect": "atmosphere", "opinion": "good", "polarity": "positive", "category": "NULL"}]}
{"text": "The seats are uncomfortable if you are sitting against the wall on wooden benches .", "labels": [{"aspect": "seats", "opinion": "uncomfortable", "polarity": "negative", "category": "NULL"}]}
{"text": "My suggestion is to eat family style because you 'll want to try the other dishes .", "labels": [{"aspect": "eat family style", "opinion": "suggestion", "polarity": "positive", "category": "NULL"}]}
"""

# Splitting the JSONL string into lines and parsing each line as JSON
data_entries = [json.loads(line) for line in jsonl_data.strip().split('\n')]

# Counting aspects for each entry
aspect_counts = [len(set(label['aspect'] for label in entry['labels'])) for entry in data_entries]

# Calculate the average number of aspects
average_aspects = sum(aspect_counts) / len(aspect_counts)

# Calculate the median number of aspects
sorted_aspect_counts = sorted(aspect_counts)
mid_index = len(sorted_aspect_counts) // 2
if len(sorted_aspect_counts) % 2 == 0:
    median_aspects = (sorted_aspect_counts[mid_index - 1] + sorted_aspect_counts[mid_index]) / 2
else:
    median_aspects = sorted_aspect_counts[mid_index]

average_aspects, median_aspects
# Out:
# (1.8, 1.0)

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Path to your JSONL file
file_path = 'single_sentences_hotel_ina.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r') as file:
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects
plt.figure(figsize=(8, 5))
plt.hist(aspect_counts, bins=range(1, max(aspect_counts)+2), density=True, alpha=0.7, color='blue')
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.xticks(range(1, max(aspect_counts)+1))
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Path to your JSONL file
file_path = 'ABSADatasets//datasets//acos_datasets//504.Restaurant16//rest16_quad_train.tsv.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r') as file:
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects
plt.figure(figsize=(8, 5))
plt.hist(aspect_counts, bins=range(1, max(aspect_counts)+2), density=True, alpha=0.7, color='blue')
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.xticks(range(1, max(aspect_counts)+1))
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Path to your JSONL file
file_path = 'ABSADatasets//datasets//acos_datasets//1000.Hotel//train.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r') as file:
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects
plt.figure(figsize=(8, 5))
plt.hist(aspect_counts, bins=range(1, max(aspect_counts)+2), density=True, alpha=0.7, color='blue')
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.xticks(range(1, max(aspect_counts)+1))
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Path to your JSONL file
file_path = 'ABSADatasets//datasets//acos_datasets//501.Laptop14//laptop_quad_train.tsv.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r', encoding='utf-8') as file:  # Specify UTF-8 encoding
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects
plt.figure(figsize=(8, 5))
plt.hist(aspect_counts, bins=range(1, max(aspect_counts)+2), density=True, alpha=0.7, color='blue')
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.xticks(range(1, max(aspect_counts)+1))
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()

# %%
import json
import matplotlib.pyplot as plt
import numpy as np

# Path to your JSONL file
file_path = 'ABSADatasets//datasets//acos_datasets//501.Laptop14//laptop_quad_train.tsv.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r') as file:
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects
plt.figure(figsize=(8, 5))
plt.hist(aspect_counts, bins=range(1, max(aspect_counts)+2), density=True, alpha=0.7, color='blue')
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.xticks(range(1, max(aspect_counts)+1))
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[24], line 11
#       9 aspect_counts = []
#      10 with open(file_path, 'r') as file:
# ---> 11     for line in file:
#      12         entry = json.loads(line)
#      13         # Counting unique aspects in each entry
#
# File ~\AppData\Local\Programs\Python\Python39\lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 7228: character maps to <undefined>

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns  # Import seaborn for kernel density estimation

# Path to your JSONL file
file_path = 'ABSADatasets//datasets//acos_datasets//504.Restaurant16//rest16_quad_train.tsv.jsonl'

# Reading JSONL data from a file
aspect_counts = []
with open(file_path, 'r') as file:
    for line in file:
        entry = json.loads(line)
        # Counting unique aspects in each entry
        aspects = set(label['aspect'] for label in entry['labels'])
        aspect_counts.append(len(aspects))

# Plotting the distribution of aspects using KDE
plt.figure(figsize=(8, 5))
sns.kdeplot(aspect_counts, bw_adjust=0.5, fill=True)  # Adjust bandwidth to smoothness preference
plt.title('Distribution of Aspect Counts')
plt.xlabel('Number of Aspects per Text')
plt.ylabel('Density')
plt.grid(axis='y', alpha=0.75)

# Show plot
plt.show()
